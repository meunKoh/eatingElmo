# %% [markdown]
# ### 데이터 불러오기
#
# - 데이터는 NE tag가 공백으로 구분되어 있다.
#
# - *read_data* 함수를 실행하면 *file_path* 에서 텍스트 데이터를 읽고 token 리스트, tag 리스트를 반환한다.

# %%
import pandas as pd, numpy as np

# %%
df = pd.read_csv('./questions/questions_corpus_bio.csv', encoding='utf-8', index_col=0)
print(df.shape)
df.head(2)
# Out:
# /anaconda3/envs/keras-test/lib/python3.6/site-packages/numpy/lib/arraysetops.py:568: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# (1678295, 3)
#                    question  \
# 0       계룡시 단체석 있는 복매운탕 알아요
# 1  사천 마미밥상 무한 리필 사람들 후기 뭐에요
#
#                                                  okt  \
# 0        ['계룡시', '단체', '석', '있는', '복', '매운탕', '알아요']
# 1  ['사천', '마미', '밥상', '무한', '리필', '사람', '들', '후기'...
#
#                                              okt_tag
# 0  ['B-LOC', 'B-ADJ', 'I-ADJ', 'I-ADJ', 'B-FOD', ...
# 1  ['B-LOC', 'B-ORG', 'I-ORG', 'B-ADJ', 'I-ADJ', ...

# %%
# 'okt', 'okt_tag' 컬럼을 list로 변경
df['okt'] = df['okt'].apply(lambda x: eval(x))
df['okt_tag'] = df['okt_tag'].apply(lambda x: eval(x))

# %%
df.head(2)
# Out:
#                    question                                     okt  \
# 0       계룡시 단체석 있는 복매운탕 알아요           [계룡시, 단체, 석, 있는, 복, 매운탕, 알아요]
# 1  사천 마미밥상 무한 리필 사람들 후기 뭐에요  [사천, 마미, 밥상, 무한, 리필, 사람, 들, 후기, 뭐, 에요]
#
#                                              okt_tag
# 0      [B-LOC, B-ADJ, I-ADJ, I-ADJ, B-FOD, I-FOD, O]
# 1  [B-LOC, B-ORG, I-ORG, B-ADJ, I-ADJ, O, O, O, O...

# %% [markdown]
# 데이터를 train과 test로 9:1의 비율로 나눈다.
#  - *train* -> 모델 훈련;
#  - *test* -> 모델 평가와 hyperparameter 조정

# %%
from sklearn.model_selection import train_test_split

train_tokens, test_tokens, train_tags, test_tags = \
    train_test_split(df['okt'].values
                    ,df['okt_tag'].values
                    ,test_size=0.1
                    ,random_state=42)

# %%
train_tokens.shape, train_tags.shape, test_tokens.shape, test_tags.shape
# Out:
# ((1510465,), (1510465,), (167830,), (167830,))

# %%
train_tokens[:3]
# Out:
# array([list(['치맥', '타운', '사람', '들', '반응', '알려줘요']),
#        list(['페리', '아', '상세', '주소', '알아보려고요']),
#        list(['키친', '홀릭', '핵', '맛있는', '평', '알', '고', '계신가요'])],
#       dtype=object)

# %%
train_tags[:3]
# Out:
# array([list(['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O']),
#        list(['B-ORG', 'I-ORG', 'O', 'O', 'O']),
#        list(['B-ORG', 'I-ORG', 'B-ADJ', 'I-ADJ', 'O', 'O', 'O', 'O'])],
#       dtype=object)

# %%
for i in range(0,2):
    for token, tag in zip(train_tokens[i], train_tags[i]):
        print('%s\t%s' % (token, tag))
# Out:
# 치맥	B-ORG
# 타운	I-ORG
# 사람	O
# 들	O
# 반응	O
# 알려줘요	O
# 페리	B-ORG
# 아	I-ORG
# 상세	O
# 주소	O
# 알아보려고요	O

# %% [markdown]
# ### 사전 준비
#
# 신경망 모델 훈련을 위해 아래 두 가지 mapping을 사용한다:
# - {token}$\to${token id}: embeddings matrix에서 해당 token의 row를 반환
# - {tag}$\to${tag id}: 신경망 출력에서 loss를 계산하기 위한 one-hot ground truth probability distribution vectors
#
# {token or tag}$\to${index}, {tag}$\to${tag id} 두 개 딕셔너리를 반환하는 함수 *build_dict*를 정의한다.

# %%
from collections import defaultdict
import numpy as np

# %%
def build_dict(tokens_or_tags, special_tokens):
    """
        tokens_or_tags: token / tag의 리스트
        special_tokens: 특이 token
    """
    
    # default 값이 0인 딕셔너리를 만든다.
    # (key/value를 따로 지정하지 않고, key만 저장하면 value는 0으로 자동 대입되는 딕셔너리)
    tok2idx = defaultdict(lambda: 0) 
    idx2tok = []
    
    idx = 0
    
    # special_tokens를 먼저 딕셔너리에 저장한다.
    for token in special_tokens:
        tok2idx[token] = idx
        idx2tok.append(token)
        idx += 1
    
    # tok2idx 딕셔너리에서 key값인 token or tag는 unique 해야 한다.
    # 따라서 tokens_or_tags에서 special_tokens에 해당하지 않는 tokens_or_tags만 새로 index를 준다.
    for token_list in tokens_or_tags:
        for token in token_list:
            if token not in tok2idx:
                tok2idx[token] = idx
                idx2tok.append(token)
                idx += 1
    
    return tok2idx, idx2tok

# %% [markdown]
# *build_dict* 함수를 이용하여 token과 tag의 딕셔너리를 만든다. 여기서 special_tokens는 아래와 같다.
#  - `<UNK>` 언어 토큰에 해당하지 않는 것 (unknown)
#  - `<PAD>` 문장에 대한 batch를 생성할 때 부여할 문장의 길이와 같은 padding 토큰

# %%
special_tokens = ['<UNK>', '<PAD>'] # unknown, padding
special_tags = ['O'] # out of tag

# 딕셔너리 생성 
token2idx, idx2token = build_dict(train_tokens, special_tokens)
tag2idx, idx2tag = build_dict(train_tags, special_tags)

# %%
token2idx
# Out:
# defaultdict(<function __main__.build_dict.<locals>.<lambda>()>,
#             {'<UNK>': 0,
#              '<PAD>': 1,
#              '치맥': 2,
#              '타운': 3,
#              '사람': 4,
#              '들': 5,
#              '반응': 6,
#              '알려줘요': 7,
#              '페리': 8,
#              '아': 9,
#              '상세': 10,
#              '주소': 11,
#              '알아보려고요': 12,
#              '키친': 13,
#              '홀릭': 14,
#              '핵': 15,
#              '맛있는': 16,
#              '평': 17,
#              '알': 18,
#              '고': 19,
#              '계신가요': 20,
#              '고색': 21,
#              '소머리국밥': 22,
#              '냉면': 23,
#              '가성': 24,
#              '비': 25,
#              '좋은': 26,
#              '솔직': 27,
#              '후기': 28,
#              '부탁': 29,
#              '해': 30,
#              '이벤트': 31,
#              '홀': 32,
#              '있는': 33,
#              '하모': 34,
#              '사시미': 35,
#              '지리는': 36,
#              '곳': 37,
#              '뭐': 38,
#              '였어요': 39,
#              '통영': 40,
#              '전망': 41,
#              '멋있는': 42,
#              '도루묵': 43,
#              '추천': 44,
#              '해줄만': 45,
#              '한': 46,
#              '데': 47,
#              '좀': 48,
#              '각설탕': 49,
#              '알려주시겠어요': 50,
#              '이쁜': 51,
#              '샷': 52,
#              '대박': 53,
#              '맛집': 54,
#              '있아요': 55,
#              '경기도': 56,
#              '이천시': 57,
#              '향': 58,
#              '긋한': 59,
#              '올갱이': 60,
#              '알려주세요': 61,
#              '강서': 62,
#              '티': 63,
#              '하우스': 64,
#              '이': 65,
#              '정말': 66,
#              '끝내주는': 67,
#              '뭔': 68,
#              '데예': 69,
#              '돈부리': 70,
#              '야': 71,
#              '리뷰': 72,
#              '뭔가': 73,
#              '요': 74,
#              '울산': 75,
#              '동구': 76,
#              '양념': 77,
#              '잘': 78,
#              '배': 79,
#              '인': 80,
#              '오지': 81,
#              '는': 82,
#              '석쇠': 83,
#              '마루': 84,
#              '어디': 85,
#              '인데': 86,
#              '경상북도': 87,
#              '예천군': 88,
#              '밥': 89,
#              '반찬': 90,
#              '예요': 91,
#              '솟구쳐': 92,
#              '차기': 93,
#              '여쭤': 94,
#              '보려구요': 95,
#              '충청남도': 96,
#              '금산군': 97,
#              '다져': 98,
#              '주는': 99,
#              '쩌': 100,
#              '물어볼라는데요': 101,
#              '서비스': 102,
#              '많이': 103,
#              '반': 104,
#              '쎄오': 105,
#              '였죠': 106,
#              '저렴하면서': 107,
#              '양': 108,
#              '많은': 109,
#              '꼬리곰탕': 110,
#              '해줘': 111,
#              '부천시': 112,
#              '청탁': 113,
#              '씹는': 114,
#              '식감': 115,
#              '보려고요': 116,
#              '장관': 117,
#              '순': 118,
#              '살': 119,
#              '치킨': 120,
#              '뭐드': 121,
#              '라': 122,
#              '아리수': 123,
#              '자세한': 124,
#              '알려주나요': 125,
#              '서울': 126,
#              '연탄': 127,
#              '갈비': 128,
#              '할': 129,
#              '있으신': 130,
#              '가요': 131,
#              '행복': 132,
#              '마을': 133,
#              '눅눅하지': 134,
#              '않은': 135,
#              '부탁드려요': 136,
#              '해원': 137,
#              '초가집': 138,
#              '궁금한데요': 139,
#              '조명': 140,
#              '너무': 141,
#              '분위기': 142,
#              '미역국': 143,
#              '궁금하네요': 144,
#              '풍': 145,
#              '납': 146,
#              '위치': 147,
#              '혀': 148,
#              '에': 149,
#              '착': 150,
#              '감기': 151,
#              '한우': 152,
#              '채끝': 153,
#              '등심': 154,
#              '아는': 155,
#              '있어요': 156,
#              '바삭': 157,
#              '전라남도': 158,
#              '무안군': 159,
#              '스마일': 160,
#              '가든': 161,
#              '인기': 162,
#              '지은': 163,
#              '이네': 164,
#              '횟집': 165,
#              '어떤': 166,
#              '옥천군': 167,
#              '생': 168,
#              '있나': 169,
#              '를': 170,
#              '달래주는': 171,
#              '멕시코': 172,
#              '요리': 173,
#              '있는지요': 174,
#              '인천': 175,
#              '중구': 176,
#              '버건디': 177,
#              '평가': 178,
#              '관악': 179,
#              '인력': 180,
#              '커피': 181,
#              '대전': 182,
#              '음악': 183,
#              '생선': 184,
#              '조림': 185,
#              '부여군': 186,
#              '야경': 187,
#              '마늘': 188,
#              '떡볶이': 189,
#              '볼라': 190,
#              '진주시': 191,
#              '버': 192,
#              '무려': 193,
#              '매콤': 194,
#              '크림': 195,
#              '새우': 196,
#              '괜찮은': 197,
#              '지': 198,
#              '경상남도': 199,
#              '거제시': 200,
#              '덤': 201,
#              '청': 202,
#              '기와': 203,
#              '식당': 204,
#              '혜자': 205,
#              '스러운': 206,
#              '튀김': 207,
#              '토종': 208,
#              '순대': 209,
#              '족발': 210,
#              '죠': 211,
#              '조화로운': 212,
#              '닭개장': 213,
#              '아시나요': 214,
#              '제주도': 215,
#              '제주시': 216,
#              '에바': 217,
#              '키라': 218,
#              '이스': 219,
#              '안': 220,
#              '질리는': 221,
#              '다슬기': 222,
#              '뭘': 223,
#              '까요': 224,
#              '청주': 225,
#              '내': 226,
#              '장탕': 227,
#              '윤희': 228,
#              '네': 229,
#              '여': 230,
#              '부산': 231,
#              '서구': 232,
#              '봐': 233,
#              '예': 234,
#              '서초구': 235,
#              '고급스러운': 236,
#              '포구': 237,
#              '회집': 238,
#              '깨끗한': 239,
#              '궁합': 240,
#              '맞는': 241,
#              '찜': 242,
#              '있으시죠': 243,
#              '서귀포시': 244,
#              '돈': 245,
#              '사': 246,
#              '각막': 247,
#              '창': 248,
#              '강북구': 249,
#              '이름난': 250,
#              '뭡': 251,
#              '니까': 252,
#              '대': 253,
#              '한식당': 254,
#              '낭만': 255,
#              '적': 256,
#              ',': 257,
#              '찾아주세요': 258,
#              '용산구': 259,
#              '세잔': 260,
#              '귀여운': 261,
#              '재': 262,
#              '방문': 263,
#              '률': 264,
#              '높은': 265,
#              '청풍': 266,
#              '삼계탕': 267,
#              '물어볼려고요': 268,
#              '갈매기': 269,
#              '삼겹': 270,
#              '알아요': 271,
#              '냄새': 272,
#              '가': 273,
#              '예술인': 274,
#              '곡물': 275,
#              '포항시': 276,
#              '돌': 277,
#              '곱창': 278,
#              '있죠': 279,
#              '메이트': 280,
#              '해동': 281,
#              '영주시': 282,
#              '콩알': 283,
#              '국밥': 284,
#              '나주시': 285,
#              '하얼빈': 286,
#              '꼬치': 287,
#              '&': 288,
#              '닭': 289,
#              '날개': 290,
#              '어때': 291,
#              '대흥': 292,
#              '구구': 293,
#              '북구': 294,
#              '다인': 295,
#              '한정식': 296,
#              '영도구': 297,
#              '부드럽게': 298,
#              '궁금합니다': 299,
#              '문경시': 300,
#              '군더더기': 301,
#              '없이': 302,
#              '질문': 303,
#              '드려요': 304,
#              '동두천시': 305,
#              '키츠네': 306,
#              '꾸며진': 307,
#              '배달': 308,
#              '의': 309,
#              '민족': 310,
#              '봉': 311,
#              '계': 312,
#              '참숯': 313,
#              '구이': 314,
#              '진짜': 315,
#              '궁금해요': 316,
#              '양평군': 317,
#              '향토': 318,
#              '아리랑': 319,
#              '미스터': 320,
#              '보쌈': 321,
#              '5379': 322,
#              'STANDINGSTEAK': 323,
#              '동인천역': 324,
#              '점': 325,
#              '인생': 326,
#              '알려주': 327,
#              '삼': 328,
#              '재료': 329,
#              '실한': 330,
#              '선호': 331,
#              '하는': 332,
#              '광명': 333,
#              '찹쌀': 334,
#              '꽈배기': 335,
#              '해물파전': 336,
#              '화려한': 337,
#              '느낌': 338,
#              '알려주시겠습니까': 339,
#              '동대문': 340,
#              '정원': 341,
#              '예쁜': 342,
#              '더덕': 343,
#              '정식': 344,
#              '메밀묵': 345,
#              '촌': 346,
#              '바글바글': 347,
#              '한빛': 348,
#              '맛': 349,
#              '강원도': 350,
#              '양구군': 351,
#              '아름다운': 352,
#              '양천': 353,
#              '남용': 354,
#              '궁금해서요': 355,
#              '영등포': 356,
#              '해장국': 357,
#              '신곡': 358,
#              '달콤한': 359,
#              '어떻게': 360,
#              '되나요': 361,
#              '입맛': 362,
#              '맞을만한': 363,
#              '스시': 364,
#              '소': 365,
#              '진씨': 366,
#              '엄마': 367,
#              '왕': 368,
#              '야외': 369,
#              '테이블': 370,
#              '어': 371,
#              '라운드': 372,
#              '마켓': 373,
#              '남원': 374,
#              '복죽': 375,
#              '알수있나요': 376,
#              '기장군': 377,
#              '추어탕': 378,
#              '가봐요': 379,
#              '드리면': 380,
#              '고을': 381,
#              '한식': 382,
#              '뷔페': 383,
#              '알려줄래': 384,
#              '멋진': 385,
#              '안심': 386,
#              '스테이크': 387,
#              '의령': 388,
#              '서정식': 389,
#              '당': 390,
#              '어울리는': 391,
#              '콩나물': 392,
#              '고고': 393,
#              '베네치아': 394,
#              '서천군': 395,
#              '또래': 396,
#              '오래': 397,
#              '튀겨주는': 398,
#              '누린내': 399,
#              '없는': 400,
#              '돈가스': 401,
#              '인공': 402,
#              '이지': 403,
#              '청결한': 404,
#              '황금': 405,
#              '떡갈비': 406,
#              '구미시': 407,
#              '죠스': 408,
#              '전라북도': 409,
#              '중랑구': 410,
#              '은파': 411,
#              '보은': 412,
#              '식욕': 413,
#              '을': 414,
#              '살리는': 415,
#              '보은군': 416,
#              '에메랄드': 417,
#              '라떼': 418,
#              '하세요': 419,
#              '은평': 420,
#              '연어': 421,
#              '덮': 422,
#              '있는가': 423,
#              '일품': 424,
#              '오픈': 425,
#              '주방': 426,
#              '났던': 427,
#              '어우러진': 428,
#              '아산시': 429,
#              '모꼬지': 430,
#              '도널드': 431,
#              '분식': 432,
#              '쫄깃': 433,
#              '송파구': 434,
#              '독특한': 435,
#              '옛날': 436,
#              '삼겹살': 437,
#              '부드러운': 438,
#              '불고기': 439,
#              '있는지': 440,
#              '부천': 441,
#              '바다': 442,
#              '궁전': 443,
#              '싶어요': 444,
#              '도둑': 445,
#              '함안군': 446,
#              '교동': 447,
#              '해산물': 448,
#              '싱싱한': 449,
#              '미스': 450,
#              '빈대떡': 451,
#              '파스타': 452,
#              '회': 453,
#              '신': 454,
#              '포차': 455,
#              '마포구': 456,
#              '자매': 457,
#              '국수': 458,
#              '본점': 459,
#              '궁금해': 460,
#              '모던': 461,
#              '도': 462,
#              '볼려': 463,
#              '구': 464,
#              '오': 465,
#              '겹살': 466,
#              '우아한': 467,
#              '전골': 468,
#              '류': 469,
#              '골짝': 470,
#              '알싸한': 471,
#              '몸': 472,
#              '보신': 473,
#              '수': 474,
#              '두툼': 475,
#              '텔레파시': 476,
#              '부안군': 477,
#              '유명': 478,
#              '손': 479,
#              '칼국수': 480,
#              '나': 481,
#              '쾌적한': 482,
#              '의령군': 483,
#              '함양': 484,
#              '흡입': 485,
#              '소바': 486,
#              '물어볼게요': 487,
#              '사천': 488,
#              '다리': 489,
#              '집': 490,
#              '든든한': 491,
#              '충청북도': 492,
#              '진천군': 493,
#              '불': 494,
#              '오리': 495,
#              '백숙': 496,
#              '시': 497,
#              '그': 498,
#              '니': 499,
#              '처': 500,
#              '장어': 501,
#              '명동': 502,
#              '함흥': 503,
#              '면옥': 504,
#              '명진': 505,
#              '줄이': 506,
#              '엄청': 507,
#              '긴': 508,
#              '춘천시': 509,
#              '있을까요': 510,
#              '정리': 511,
#              '정돈': 512,
#              '된': 513,
#              '꽃게': 514,
#              '고양시': 515,
#              '오정동': 516,
#              '부대찌개': 517,
#              '올랑': 518,
#              '청도군': 519,
#              '별미': 520,
#              '트인': 521,
#              '마르': 522,
#              '게리': 523,
#              '따': 524,
#              '피자': 525,
#              '자유로운': 526,
#              '있는거죠': 527,
#              '주문': 528,
#              '진회': 529,
#              '짬뽕': 530,
#              '순두부': 531,
#              '아주': 532,
#              '가문': 533,
#              '미추홀': 534,
#              '전원주': 535,
#              '큰': 536,
#              '할매': 537,
#              '대국': 538,
#              '강진군': 539,
#              '황태': 540,
#              '빈': 541,
#              '닭꼬치': 542,
#              '폭포': 543,
#              '있으': 544,
#              '신지': 545,
#              '먹을': 546,
#              '해물탕': 547,
#              '있어여': 548,
#              '주막': 549,
#              '울주군': 550,
#              '훌륭한': 551,
#              '디저트': 552,
#              '에요': 553,
#              '닭갈비': 554,
#              '물어볼게': 555,
#              '단체': 556,
#              '석': 557,
#              '준비': 558,
#              '다정': 559,
#              '장사': 560,
#              '되는': 561,
#              '돼지국밥': 562,
#              '곡성군': 563,
#              '풍월': 564,
#              '가르쳐주세요': 565,
#              '사하구': 566,
#              '두산': 567,
#              '당진시': 568,
#              '뚝심': 569,
#              '김치찌개': 570,
#              '소품': 571,
#              '딸린': 572,
#              '입': 573,
#              '호강': 574,
#              '해주시겠어요': 575,
#              '참': 576,
#              '치즈': 577,
#              '돈카츠': 578,
#              '창원시': 579,
#              '차이나': 580,
#              '게이트': 581,
#              '핵존맛': 582,
#              '서산시': 583,
#              '졸라': 584,
#              '목살': 585,
#              '있습니까': 586,
#              '구리시': 587,
#              '최고': 588,
#              '태안군': 589,
#              '제': 590,
#              '버거': 591,
#              '앤디': 592,
#              '(': 593,
#              'B': 594,
#              'D': 595,
#              ')': 596,
#              '괴산군': 597,
#              '월드': 598,
#              '가정식': 599,
#              '함평': 600,
#              '원평': 601,
#              '이색': 602,
#              '골뱅이': 603,
#              '꿀맛': 604,
#              '터키': 605,
#              '김해': 606,
#              '가라아게': 607,
#              '부평': 608,
#              '5': 609,
#              '포식': 610,
#              '천': 611,
#              '매운탕': 612,
#              '성남시': 613,
#              '눈사람': 614,
#              '생선회': 615,
#              '인가요': 616,
#              '영광': 617,
#              '오징어': 618,
#              '바삭바삭한': 619,
#              '구미': 620,
#              '맛있어': 621,
#              '보이는': 622,
#              '있겠죠': 623,
#              '김천시': 624,
#              '낙': 625,
#              '동': 626,
#              '입안': 627,
#              '깔끔한': 628,
#              '규모': 629,
#              '알맞은': 630,
#              '샐러드': 631,
#              '부페': 632,
#              '슬기': 633,
#              '비주': 634,
#              '얼': 635,
#              '삼척시': 636,
#              '또': 637,
#              '왔다': 638,
#              '어마어마한': 639,
#              '비율': 640,
#              '적절한': 641,
#              '좌': 642,
#              '식': 643,
#              '버섯': 644,
#              '뚝방': 645,
#              '곱창전골': 646,
#              '노원구': 647,
#              '해물뚝배기': 648,
#              '있어': 649,
#              '더': 650,
#              '바베큐': 651,
#              '먹을만한': 652,
#              '만': 653,
#              '고기': 654,
#              '안성시': 655,
#              '예뻐': 656,
#              '하남': 657,
#              '복': 658,
#              '성': 659,
#              '산장': 660,
#              '알려주실래요': 661,
#              '계룡시': 662,
#              '떠': 663,
#              '억': 664,
#              '벌어지는': 665,
#              '조개': 666,
#              '폭주': 667,
#              '사골': 668,
#              '스트레스': 669,
#              '풀리는': 670,
#              '모퉁이': 671,
#              '살살': 672,
#              '녹는': 673,
#              '해운대구': 674,
#              '이편': 675,
#              '쉼': 676,
#              '터': 677,
#              '알아보는데요': 678,
#              '동래': 679,
#              '존맛': 680,
#              '볼테기': 681,
#              '탕': 682,
#              '광명시': 683,
#              '차슈': 684,
#              '있으세요': 685,
#              '세': 686,
#              '아세요': 687,
#              '금정구': 688,
#              '호호': 689,
#              '만호': 690,
#              '전주시': 691,
#              '한번': 692,
#              '쯤': 693,
#              '은': 694,
#              '가볼만': 695,
#              '있나요': 696,
#              '메카': 697,
#              '후회': 698,
#              '화성': 699,
#              '특별한': 700,
#              '비법': 701,
#              '있었나요': 702,
#              '도현': 703,
#              '형님': 704,
#              '막창': 705,
#              '육즙': 706,
#              '풍부한': 707,
#              '전복': 708,
#              '뚝배기': 709,
#              '오산시': 710,
#              '작은': 711,
#              '음악회': 712,
#              '마': 713,
#              '복림': 714,
#              '할머니': 715,
#              '새': 716,
#              '콤': 717,
#              '만석': 718,
#              '있지요': 719,
#              '아메리칸': 720,
#              '스멜': 721,
#              '군포': 722,
#              '광': 723,
#              '도봉': 724,
#              '삼척': 725,
#              '명품': 726,
#              '우정': 727,
#              '육': 728,
#              '자리': 729,
#              '넓은': 730,
#              '공기': 731,
#              '맑은': 732,
#              '두루치기': 733,
#              '명물': 734,
#              '전문': 735,
#              '쫀득쫀득': 736,
#              '새마을': 737,
#              '명란젓': 738,
#              '스파게티': 739,
#              '완도': 740,
#              '꽃': 741,
#              '돼지': 742,
#              '푸드': 743,
#              '함양군': 744,
#              '전경': 745,
#              '본': 746,
#              '원': 747,
#              '의정부시': 748,
#              '참치': 749,
#              '네가지': 750,
#              '맛깔나게': 751,
#              '현미': 752,
#              '채식': 753,
#              '해주실래요': 754,
#              '대구': 755,
#              '양천구': 756,
#              '더비': 757,
#              '블루': 758,
#              '사파이어': 759,
#              '남양주시': 760,
#              '연화': 761,
#              '야들야들한': 762,
#              '합천군': 763,
#              '묵향': 764,
#              '아기': 765,
#              '의자': 766,
#              '퐁당': 767,
#              '샤브': 768,
#              '유성': 769,
#              '강동': 770,
#              '미고': 771,
#              '랭': 772,
#              '만두': 773,
#              '이영자': 774,
#              '사랑': 775,
#              '손님': 776,
#              '여쭈어': 777,
#              '볼려고요': 778,
#              '종류': 779,
#              '여러': 780,
#              '개인': 781,
#              '잇나요': 782,
#              '혜강': 783,
#              '산봉': 784,
#              '동태': 785,
#              '마리': 786,
#              '구워주는': 787,
#              '시흥시': 788,
#              '완주군': 789,
#              '죽': 790,
#              '두': 791,
#              '메밀': 792,
#              '호수': 793,
#              '가마': 794,
#              '무한': 795,
#              '리필': 796,
#              '남포면': 797,
#              '옥': 798,
#              '화천군': 799,
#              '저렴하고': 800,
#              '이천': 801,
#              '후': 802,
#              '도봉구': 803,
#              '35': 804,
#              '서대문구': 805,
#              '안동시': 806,
#              '청송군': 807,
#              '상주시': 808,
#              '신세대': 809,
#              '루': 810,
#              '엔': 811,
#              '타이': 812,
#              '김포': 813,
#              '후각': 814,
#              '자극': 815,
#              '종합': 816,
#              '활': 817,
#              '어시장': 818,
#              '수영': 819,
#              '목련': 820,
#              '도토리묵': 821,
#              '널찍한': 822,
#              '조미료': 823,
#              '전혀': 824,
#              '있지': 825,
#              '토박이': 826,
#              '우렁': 827,
#              '쌈밥': 828,
#              '고흥': 829,
#              '밥상': 830,
#              '극찬': 831,
#              '옻': 832,
#              '장어구이': 833,
#              '맛깔나는': 834,
#              '진한': 835,
#              '동작': 836,
#              '구수한': 837,
#              '신라': 838,
#              '회관': 839,
#              '원조': 840,
#              '춘천': 841,
#              '막국수': 842,
#              '최애': 843,
#              '성북': 844,
#              '넘': 845,
#              '연천': 846,
#              '자몽주스': 847,
#              '청룡': 848,
#              '취향': 849,
#              '저격': 850,
#              '궁금': 851,
#              '부평구': 852,
#              '에클레어': 853,
#              '볼려고': 854,
#              '랑': 855,
#              '찾아줘': 856,
#              '조용한': 857,
#              '소주': 858,
#              '있노': 859,
#              '화천': 860,
#              '널널': 861,
#              '월화': 862,
#              '환상': 863,
#              '발': 864,
#              '로': 865,
#              '갈': 866,
#              '때': 867,
#              '까지': 868,
#              '양평': 869,
#              '있는가요': 870,
#              '김제': 871,
#              '서민': 872,
#              '배부르게': 873,
#              '넓': 874,
#              '직한': 875,
#              '들락날락': 876,
#              '만족할만': 877,
#              '생맥주': 878,
#              '강동구': 879,
#              '은은한': 880,
#              '진천': 881,
#              '김치말이': 882,
#              '아이': 883,
#              '한남': 884,
#              '정육점': 885,
#              '맵': 886,
#              '놀라운': 887,
#              '있으려나': 888,
#              '보성군': 889,
#              '중식': 890,
#              '조팔팔': 891,
#              '어때요': 892,
#              '연제': 893,
#              '빵': 894,
#              '림': 895,
#              '정읍': 896,
#              '킹콩': 897,
#              '장수군': 898,
#              '깊은': 899,
#              '느낄': 900,
#              '꼬': 901,
#              '수운': 902,
#              '티비': 903,
#              '나온': 904,
#              '스토리': 905,
#              '문경': 906,
#              '연못': 907,
#              '일동': 908,
#              '뉴월드': 909,
#              '음성군': 910,
#              '제일': 911,
#              '싼': 912,
#              '물어봐야겠죠': 913,
#              '맛나': 914,
#              '프랑스': 915,
#              '코스': 916,
#              '동대문구': 917,
#              '띵똥': 918,
#              '와플': 919,
#              '군침': 920,
#              '순천': 921,
#              '아구찜': 922,
#              '주차장': 923,
#              '술안주': 924,
#              '남구': 925,
#              '금천': 926,
#              '포스': 927,
#              '주먹': 928,
#              '해주세요': 929,
#              '얼라이브': 930,
#              '홈': 931,
#              '연': 932,
#              '게장': 933,
#              '어떠니': 934,
#              '삿포로': 935,
#              '랜드': 936,
#              '구워진': 937,
#              '일부러': 938,
#              '찾아갈': 939,
#              '묵은지': 940,
#              '난': 941,
#              '술': 942,
#              '한잔': 943,
#              '미학': 944,
#              '조화': 945,
#              '시금치': 946,
#              '베이컨': 947,
#              '강화군': 948,
#              '진안군': 949,
#              '성훈': 950,
#              '수산': 951,
#              '평창군': 952,
#              '마님': 953,
#              '야식': 954,
#              '묘향손': 955,
#              '귀': 956,
#              '운': 957,
#              '고르곤졸라': 958,
#              '은평구': 959,
#              '여유': 960,
#              '매력': 961,
#              '그린': 962,
#              '광양': 963,
#              '백': 964,
#              '광진': 965,
#              '오늘': 966,
#              '저렴한': 967,
#              '영천': 968,
#              '태양': 969,
#              '송원': 970,
#              '퀄리티': 971,
#              '밥사랑': 972,
#              '제주': 973,
#              '하남시': 974,
#              '진열': 975,
#              '케르': 976,
#              '테라스': 977,
#              '웰빙': 978,
#              '계양': 979,
#              '강한': 980,
#              '성미': 981,
#              '현': 982,
#              '이분': 983,
#              '돈코츠': 984,
#              '갑인': 985,
#              '소프트': 986,
#              '부산진': 987,
#              '좋아서': 988,
#              '공유': 989,
#              '하고': 990,
#              '싶은': 991,
#              '양주': 992,
#              '굴비': 993,
#              '두름': 994,
#              '횡성군': 995,
#              '식어도': 996,
#              '돈까스': 997,
#              '타지마': 998,
#              '목포': 999,
#              ...})

# %%
idx2token
# Out:
# ['<UNK>',
#  '<PAD>',
#  '치맥',
#  '타운',
#  '사람',
#  '들',
#  '반응',
#  '알려줘요',
#  '페리',
#  '아',
#  '상세',
#  '주소',
#  '알아보려고요',
#  '키친',
#  '홀릭',
#  '핵',
#  '맛있는',
#  '평',
#  '알',
#  '고',
#  '계신가요',
#  '고색',
#  '소머리국밥',
#  '냉면',
#  '가성',
#  '비',
#  '좋은',
#  '솔직',
#  '후기',
#  '부탁',
#  '해',
#  '이벤트',
#  '홀',
#  '있는',
#  '하모',
#  '사시미',
#  '지리는',
#  '곳',
#  '뭐',
#  '였어요',
#  '통영',
#  '전망',
#  '멋있는',
#  '도루묵',
#  '추천',
#  '해줄만',
#  '한',
#  '데',
#  '좀',
#  '각설탕',
#  '알려주시겠어요',
#  '이쁜',
#  '샷',
#  '대박',
#  '맛집',
#  '있아요',
#  '경기도',
#  '이천시',
#  '향',
#  '긋한',
#  '올갱이',
#  '알려주세요',
#  '강서',
#  '티',
#  '하우스',
#  '이',
#  '정말',
#  '끝내주는',
#  '뭔',
#  '데예',
#  '돈부리',
#  '야',
#  '리뷰',
#  '뭔가',
#  '요',
#  '울산',
#  '동구',
#  '양념',
#  '잘',
#  '배',
#  '인',
#  '오지',
#  '는',
#  '석쇠',
#  '마루',
#  '어디',
#  '인데',
#  '경상북도',
#  '예천군',
#  '밥',
#  '반찬',
#  '예요',
#  '솟구쳐',
#  '차기',
#  '여쭤',
#  '보려구요',
#  '충청남도',
#  '금산군',
#  '다져',
#  '주는',
#  '쩌',
#  '물어볼라는데요',
#  '서비스',
#  '많이',
#  '반',
#  '쎄오',
#  '였죠',
#  '저렴하면서',
#  '양',
#  '많은',
#  '꼬리곰탕',
#  '해줘',
#  '부천시',
#  '청탁',
#  '씹는',
#  '식감',
#  '보려고요',
#  '장관',
#  '순',
#  '살',
#  '치킨',
#  '뭐드',
#  '라',
#  '아리수',
#  '자세한',
#  '알려주나요',
#  '서울',
#  '연탄',
#  '갈비',
#  '할',
#  '있으신',
#  '가요',
#  '행복',
#  '마을',
#  '눅눅하지',
#  '않은',
#  '부탁드려요',
#  '해원',
#  '초가집',
#  '궁금한데요',
#  '조명',
#  '너무',
#  '분위기',
#  '미역국',
#  '궁금하네요',
#  '풍',
#  '납',
#  '위치',
#  '혀',
#  '에',
#  '착',
#  '감기',
#  '한우',
#  '채끝',
#  '등심',
#  '아는',
#  '있어요',
#  '바삭',
#  '전라남도',
#  '무안군',
#  '스마일',
#  '가든',
#  '인기',
#  '지은',
#  '이네',
#  '횟집',
#  '어떤',
#  '옥천군',
#  '생',
#  '있나',
#  '를',
#  '달래주는',
#  '멕시코',
#  '요리',
#  '있는지요',
#  '인천',
#  '중구',
#  '버건디',
#  '평가',
#  '관악',
#  '인력',
#  '커피',
#  '대전',
#  '음악',
#  '생선',
#  '조림',
#  '부여군',
#  '야경',
#  '마늘',
#  '떡볶이',
#  '볼라',
#  '진주시',
#  '버',
#  '무려',
#  '매콤',
#  '크림',
#  '새우',
#  '괜찮은',
#  '지',
#  '경상남도',
#  '거제시',
#  '덤',
#  '청',
#  '기와',
#  '식당',
#  '혜자',
#  '스러운',
#  '튀김',
#  '토종',
#  '순대',
#  '족발',
#  '죠',
#  '조화로운',
#  '닭개장',
#  '아시나요',
#  '제주도',
#  '제주시',
#  '에바',
#  '키라',
#  '이스',
#  '안',
#  '질리는',
#  '다슬기',
#  '뭘',
#  '까요',
#  '청주',
#  '내',
#  '장탕',
#  '윤희',
#  '네',
#  '여',
#  '부산',
#  '서구',
#  '봐',
#  '예',
#  '서초구',
#  '고급스러운',
#  '포구',
#  '회집',
#  '깨끗한',
#  '궁합',
#  '맞는',
#  '찜',
#  '있으시죠',
#  '서귀포시',
#  '돈',
#  '사',
#  '각막',
#  '창',
#  '강북구',
#  '이름난',
#  '뭡',
#  '니까',
#  '대',
#  '한식당',
#  '낭만',
#  '적',
#  ',',
#  '찾아주세요',
#  '용산구',
#  '세잔',
#  '귀여운',
#  '재',
#  '방문',
#  '률',
#  '높은',
#  '청풍',
#  '삼계탕',
#  '물어볼려고요',
#  '갈매기',
#  '삼겹',
#  '알아요',
#  '냄새',
#  '가',
#  '예술인',
#  '곡물',
#  '포항시',
#  '돌',
#  '곱창',
#  '있죠',
#  '메이트',
#  '해동',
#  '영주시',
#  '콩알',
#  '국밥',
#  '나주시',
#  '하얼빈',
#  '꼬치',
#  '&',
#  '닭',
#  '날개',
#  '어때',
#  '대흥',
#  '구구',
#  '북구',
#  '다인',
#  '한정식',
#  '영도구',
#  '부드럽게',
#  '궁금합니다',
#  '문경시',
#  '군더더기',
#  '없이',
#  '질문',
#  '드려요',
#  '동두천시',
#  '키츠네',
#  '꾸며진',
#  '배달',
#  '의',
#  '민족',
#  '봉',
#  '계',
#  '참숯',
#  '구이',
#  '진짜',
#  '궁금해요',
#  '양평군',
#  '향토',
#  '아리랑',
#  '미스터',
#  '보쌈',
#  '5379',
#  'STANDINGSTEAK',
#  '동인천역',
#  '점',
#  '인생',
#  '알려주',
#  '삼',
#  '재료',
#  '실한',
#  '선호',
#  '하는',
#  '광명',
#  '찹쌀',
#  '꽈배기',
#  '해물파전',
#  '화려한',
#  '느낌',
#  '알려주시겠습니까',
#  '동대문',
#  '정원',
#  '예쁜',
#  '더덕',
#  '정식',
#  '메밀묵',
#  '촌',
#  '바글바글',
#  '한빛',
#  '맛',
#  '강원도',
#  '양구군',
#  '아름다운',
#  '양천',
#  '남용',
#  '궁금해서요',
#  '영등포',
#  '해장국',
#  '신곡',
#  '달콤한',
#  '어떻게',
#  '되나요',
#  '입맛',
#  '맞을만한',
#  '스시',
#  '소',
#  '진씨',
#  '엄마',
#  '왕',
#  '야외',
#  '테이블',
#  '어',
#  '라운드',
#  '마켓',
#  '남원',
#  '복죽',
#  '알수있나요',
#  '기장군',
#  '추어탕',
#  '가봐요',
#  '드리면',
#  '고을',
#  '한식',
#  '뷔페',
#  '알려줄래',
#  '멋진',
#  '안심',
#  '스테이크',
#  '의령',
#  '서정식',
#  '당',
#  '어울리는',
#  '콩나물',
#  '고고',
#  '베네치아',
#  '서천군',
#  '또래',
#  '오래',
#  '튀겨주는',
#  '누린내',
#  '없는',
#  '돈가스',
#  '인공',
#  '이지',
#  '청결한',
#  '황금',
#  '떡갈비',
#  '구미시',
#  '죠스',
#  '전라북도',
#  '중랑구',
#  '은파',
#  '보은',
#  '식욕',
#  '을',
#  '살리는',
#  '보은군',
#  '에메랄드',
#  '라떼',
#  '하세요',
#  '은평',
#  '연어',
#  '덮',
#  '있는가',
#  '일품',
#  '오픈',
#  '주방',
#  '났던',
#  '어우러진',
#  '아산시',
#  '모꼬지',
#  '도널드',
#  '분식',
#  '쫄깃',
#  '송파구',
#  '독특한',
#  '옛날',
#  '삼겹살',
#  '부드러운',
#  '불고기',
#  '있는지',
#  '부천',
#  '바다',
#  '궁전',
#  '싶어요',
#  '도둑',
#  '함안군',
#  '교동',
#  '해산물',
#  '싱싱한',
#  '미스',
#  '빈대떡',
#  '파스타',
#  '회',
#  '신',
#  '포차',
#  '마포구',
#  '자매',
#  '국수',
#  '본점',
#  '궁금해',
#  '모던',
#  '도',
#  '볼려',
#  '구',
#  '오',
#  '겹살',
#  '우아한',
#  '전골',
#  '류',
#  '골짝',
#  '알싸한',
#  '몸',
#  '보신',
#  '수',
#  '두툼',
#  '텔레파시',
#  '부안군',
#  '유명',
#  '손',
#  '칼국수',
#  '나',
#  '쾌적한',
#  '의령군',
#  '함양',
#  '흡입',
#  '소바',
#  '물어볼게요',
#  '사천',
#  '다리',
#  '집',
#  '든든한',
#  '충청북도',
#  '진천군',
#  '불',
#  '오리',
#  '백숙',
#  '시',
#  '그',
#  '니',
#  '처',
#  '장어',
#  '명동',
#  '함흥',
#  '면옥',
#  '명진',
#  '줄이',
#  '엄청',
#  '긴',
#  '춘천시',
#  '있을까요',
#  '정리',
#  '정돈',
#  '된',
#  '꽃게',
#  '고양시',
#  '오정동',
#  '부대찌개',
#  '올랑',
#  '청도군',
#  '별미',
#  '트인',
#  '마르',
#  '게리',
#  '따',
#  '피자',
#  '자유로운',
#  '있는거죠',
#  '주문',
#  '진회',
#  '짬뽕',
#  '순두부',
#  '아주',
#  '가문',
#  '미추홀',
#  '전원주',
#  '큰',
#  '할매',
#  '대국',
#  '강진군',
#  '황태',
#  '빈',
#  '닭꼬치',
#  '폭포',
#  '있으',
#  '신지',
#  '먹을',
#  '해물탕',
#  '있어여',
#  '주막',
#  '울주군',
#  '훌륭한',
#  '디저트',
#  '에요',
#  '닭갈비',
#  '물어볼게',
#  '단체',
#  '석',
#  '준비',
#  '다정',
#  '장사',
#  '되는',
#  '돼지국밥',
#  '곡성군',
#  '풍월',
#  '가르쳐주세요',
#  '사하구',
#  '두산',
#  '당진시',
#  '뚝심',
#  '김치찌개',
#  '소품',
#  '딸린',
#  '입',
#  '호강',
#  '해주시겠어요',
#  '참',
#  '치즈',
#  '돈카츠',
#  '창원시',
#  '차이나',
#  '게이트',
#  '핵존맛',
#  '서산시',
#  '졸라',
#  '목살',
#  '있습니까',
#  '구리시',
#  '최고',
#  '태안군',
#  '제',
#  '버거',
#  '앤디',
#  '(',
#  'B',
#  'D',
#  ')',
#  '괴산군',
#  '월드',
#  '가정식',
#  '함평',
#  '원평',
#  '이색',
#  '골뱅이',
#  '꿀맛',
#  '터키',
#  '김해',
#  '가라아게',
#  '부평',
#  '5',
#  '포식',
#  '천',
#  '매운탕',
#  '성남시',
#  '눈사람',
#  '생선회',
#  '인가요',
#  '영광',
#  '오징어',
#  '바삭바삭한',
#  '구미',
#  '맛있어',
#  '보이는',
#  '있겠죠',
#  '김천시',
#  '낙',
#  '동',
#  '입안',
#  '깔끔한',
#  '규모',
#  '알맞은',
#  '샐러드',
#  '부페',
#  '슬기',
#  '비주',
#  '얼',
#  '삼척시',
#  '또',
#  '왔다',
#  '어마어마한',
#  '비율',
#  '적절한',
#  '좌',
#  '식',
#  '버섯',
#  '뚝방',
#  '곱창전골',
#  '노원구',
#  '해물뚝배기',
#  '있어',
#  '더',
#  '바베큐',
#  '먹을만한',
#  '만',
#  '고기',
#  '안성시',
#  '예뻐',
#  '하남',
#  '복',
#  '성',
#  '산장',
#  '알려주실래요',
#  '계룡시',
#  '떠',
#  '억',
#  '벌어지는',
#  '조개',
#  '폭주',
#  '사골',
#  '스트레스',
#  '풀리는',
#  '모퉁이',
#  '살살',
#  '녹는',
#  '해운대구',
#  '이편',
#  '쉼',
#  '터',
#  '알아보는데요',
#  '동래',
#  '존맛',
#  '볼테기',
#  '탕',
#  '광명시',
#  '차슈',
#  '있으세요',
#  '세',
#  '아세요',
#  '금정구',
#  '호호',
#  '만호',
#  '전주시',
#  '한번',
#  '쯤',
#  '은',
#  '가볼만',
#  '있나요',
#  '메카',
#  '후회',
#  '화성',
#  '특별한',
#  '비법',
#  '있었나요',
#  '도현',
#  '형님',
#  '막창',
#  '육즙',
#  '풍부한',
#  '전복',
#  '뚝배기',
#  '오산시',
#  '작은',
#  '음악회',
#  '마',
#  '복림',
#  '할머니',
#  '새',
#  '콤',
#  '만석',
#  '있지요',
#  '아메리칸',
#  '스멜',
#  '군포',
#  '광',
#  '도봉',
#  '삼척',
#  '명품',
#  '우정',
#  '육',
#  '자리',
#  '넓은',
#  '공기',
#  '맑은',
#  '두루치기',
#  '명물',
#  '전문',
#  '쫀득쫀득',
#  '새마을',
#  '명란젓',
#  '스파게티',
#  '완도',
#  '꽃',
#  '돼지',
#  '푸드',
#  '함양군',
#  '전경',
#  '본',
#  '원',
#  '의정부시',
#  '참치',
#  '네가지',
#  '맛깔나게',
#  '현미',
#  '채식',
#  '해주실래요',
#  '대구',
#  '양천구',
#  '더비',
#  '블루',
#  '사파이어',
#  '남양주시',
#  '연화',
#  '야들야들한',
#  '합천군',
#  '묵향',
#  '아기',
#  '의자',
#  '퐁당',
#  '샤브',
#  '유성',
#  '강동',
#  '미고',
#  '랭',
#  '만두',
#  '이영자',
#  '사랑',
#  '손님',
#  '여쭈어',
#  '볼려고요',
#  '종류',
#  '여러',
#  '개인',
#  '잇나요',
#  '혜강',
#  '산봉',
#  '동태',
#  '마리',
#  '구워주는',
#  '시흥시',
#  '완주군',
#  '죽',
#  '두',
#  '메밀',
#  '호수',
#  '가마',
#  '무한',
#  '리필',
#  '남포면',
#  '옥',
#  '화천군',
#  '저렴하고',
#  '이천',
#  '후',
#  '도봉구',
#  '35',
#  '서대문구',
#  '안동시',
#  '청송군',
#  '상주시',
#  '신세대',
#  '루',
#  '엔',
#  '타이',
#  '김포',
#  '후각',
#  '자극',
#  '종합',
#  '활',
#  '어시장',
#  '수영',
#  '목련',
#  '도토리묵',
#  '널찍한',
#  '조미료',
#  '전혀',
#  '있지',
#  '토박이',
#  '우렁',
#  '쌈밥',
#  '고흥',
#  '밥상',
#  '극찬',
#  '옻',
#  '장어구이',
#  '맛깔나는',
#  '진한',
#  '동작',
#  '구수한',
#  '신라',
#  '회관',
#  '원조',
#  '춘천',
#  '막국수',
#  '최애',
#  '성북',
#  '넘',
#  '연천',
#  '자몽주스',
#  '청룡',
#  '취향',
#  '저격',
#  '궁금',
#  '부평구',
#  '에클레어',
#  '볼려고',
#  '랑',
#  '찾아줘',
#  '조용한',
#  '소주',
#  '있노',
#  '화천',
#  '널널',
#  '월화',
#  '환상',
#  '발',
#  '로',
#  '갈',
#  '때',
#  '까지',
#  '양평',
#  '있는가요',
#  '김제',
#  '서민',
#  '배부르게',
#  '넓',
#  '직한',
#  '들락날락',
#  '만족할만',
#  '생맥주',
#  '강동구',
#  '은은한',
#  '진천',
#  '김치말이',
#  '아이',
#  '한남',
#  '정육점',
#  '맵',
#  '놀라운',
#  '있으려나',
#  '보성군',
#  '중식',
#  '조팔팔',
#  '어때요',
#  '연제',
#  '빵',
#  '림',
#  '정읍',
#  '킹콩',
#  '장수군',
#  '깊은',
#  '느낄',
#  '꼬',
#  '수운',
#  '티비',
#  '나온',
#  '스토리',
#  '문경',
#  '연못',
#  '일동',
#  '뉴월드',
#  '음성군',
#  '제일',
#  '싼',
#  '물어봐야겠죠',
#  '맛나',
#  '프랑스',
#  '코스',
#  '동대문구',
#  '띵똥',
#  '와플',
#  '군침',
#  '순천',
#  '아구찜',
#  '주차장',
#  '술안주',
#  '남구',
#  '금천',
#  '포스',
#  '주먹',
#  '해주세요',
#  '얼라이브',
#  '홈',
#  '연',
#  '게장',
#  '어떠니',
#  '삿포로',
#  '랜드',
#  '구워진',
#  '일부러',
#  '찾아갈',
#  '묵은지',
#  '난',
#  '술',
#  '한잔',
#  '미학',
#  '조화',
#  '시금치',
#  '베이컨',
#  '강화군',
#  '진안군',
#  '성훈',
#  '수산',
#  '평창군',
#  '마님',
#  '야식',
#  '묘향손',
#  '귀',
#  '운',
#  '고르곤졸라',
#  '은평구',
#  '여유',
#  '매력',
#  '그린',
#  '광양',
#  '백',
#  '광진',
#  '오늘',
#  '저렴한',
#  '영천',
#  '태양',
#  '송원',
#  '퀄리티',
#  '밥사랑',
#  '제주',
#  '하남시',
#  '진열',
#  '케르',
#  '테라스',
#  '웰빙',
#  '계양',
#  '강한',
#  '성미',
#  '현',
#  '이분',
#  '돈코츠',
#  '갑인',
#  '소프트',
#  '부산진',
#  '좋아서',
#  '공유',
#  '하고',
#  '싶은',
#  '양주',
#  '굴비',
#  '두름',
#  '횡성군',
#  '식어도',
#  '돈까스',
#  '타지마',
#  '목포',
#  ...]

# %%
tag2idx
# Out:
# defaultdict(<function __main__.build_dict.<locals>.<lambda>()>,
#             {'O': 0,
#              'B-ORG': 1,
#              'I-ORG': 2,
#              'B-ADJ': 3,
#              'I-ADJ': 4,
#              'B-FOD': 5,
#              'I-FOD': 6,
#              'B-LOC': 7,
#              'I-LOC': 8})

# %%
idx2tag
# Out:
# ['O', 'B-ORG', 'I-ORG', 'B-ADJ', 'I-ADJ', 'B-FOD', 'I-FOD', 'B-LOC', 'I-LOC']

# %% [markdown]
# token <-> index, index <-> tag 서로 변환해주는 함수를 정의한다.

# %%
def words2idxs(tokens_list):
    return [token2idx[word] for word in tokens_list]

def tags2idxs(tags_list):
    return [tag2idx[tag] for tag in tags_list]

def idxs2words(idxs):
    return [idx2token[idx] for idx in idxs]

def idxs2tags(idxs):
    return [idx2tag[idx] for idx in idxs]

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
keras.__version__
# Out:
# '2.2.4'

# %%
train_tokens,train_tags
# Out:
# (array([list(['치맥', '타운', '사람', '들', '반응', '알려줘요']),
#         list(['페리', '아', '상세', '주소', '알아보려고요']),
#         list(['키친', '홀릭', '핵', '맛있는', '평', '알', '고', '계신가요']), ...,
#         list(['당진', '순이', '네', '밥집', '솔직', '후기', '궁금합니다']),
#         list(['폭포', '있는', '환상', '적', '인', '추천', '할', '데', '어디', '있죠']),
#         list(['청도군', '서비스', '는', '덤', '인', '스페인', '좋은', '데', '어디', '인데', '요'])],
#        dtype=object), array([list(['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O']),
#         list(['B-ORG', 'I-ORG', 'O', 'O', 'O']),
#         list(['B-ORG', 'I-ORG', 'B-ADJ', 'I-ADJ', 'O', 'O', 'O', 'O']),
#         ..., list(['B-LOC', 'B-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O']),
#         list(['B-ADJ', 'I-ADJ', 'B-ADJ', 'I-ADJ', 'I-ADJ', 'O', 'O', 'O', 'O', 'O']),
#         list(['B-LOC', 'B-ADJ', 'I-ADJ', 'I-ADJ', 'I-ADJ', 'B-FOD', 'O', 'O', 'O', 'O', 'O'])],
#        dtype=object))

# %%
from gensim.models import word2vec

# %%
embedding = word2vec.Word2Vec(X_train)

# %%
from gensim.models.keyedvectors import KeyedVectors

# %%
model = KeyedVectors.load_word2vec_format('my.embedding', binary=False, encoding='utf-8')

# %%
from anago.tagger import Tagger
from anago.trainer import Trainer
from anago.wrapper import Sequence
from anago.utils import NERSequence
# Out:
# /anaconda3/envs/keras-test/lib/python3.6/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
model = Sequence()

# %%
model.fit(x_train=['hey','there','im','test']
        ,y_train=['O','O','O','O'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-cc08a3487a94> in <module>
#       1 model.fit(x_train=['hey','there','im','test']
# ----> 2         ,y_train=['O','O','O','O'])
#
# /anaconda3/envs/keras-test/lib/python3.6/site-packages/anago/wrapper.py in fit(self, x_train, y_train, x_valid, y_valid, epochs, batch_size, verbose, callbacks, shuffle)
#      78                           use_char=self.use_char,
#      79                           use_crf=self.use_crf)
# ---> 80         model, loss = model.build()
#      81         model.compile(loss=loss, optimizer=self.optimizer)
#      82
#
# /anaconda3/envs/keras-test/lib/python3.6/site-packages/anago/models.py in build(self)
#      81     def build(self):
#      82         # build word embedding
# ---> 83         word_ids = Input(batch_shape=(None, None), dtype='int32', name='word_input')
#      84         inputs = [word_ids]
#      85         if self._embeddings is None:
#
# /anaconda3/envs/keras-test/lib/python3.6/site-packages/keras/engine/input_layer.py in Input(shape, batch_shape, name, dtype, sparse, tensor)
#     176                              name=name, dtype=dtype,
#     177                              sparse=sparse,
# --> 178                              input_tensor=tensor)
#     179     # Return tensor including _keras_shape and _keras_history.
#     180     # Note that in this case train_output and test_output are the same pointer.
#
# /anaconda3/envs/keras-test/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /anaconda3/envs/keras-test/lib/python3.6/site-packages/keras/engine/input_layer.py in __init__(self, input_shape, batch_size, batch_input_shape, dtype, input_tensor, sparse, name)
#      85                                          dtype=dtype,
#      86                                          sparse=self.sparse,
# ---> 87                                          name=self.name)
#      88         else:
#      89             self.is_placeholder = False
#
# /anaconda3/envs/keras-test/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in placeholder(shape, ndim, dtype, sparse, name)
#     515         x = tf.sparse_placeholder(dtype, shape=shape, name=name)
#     516     else:
# --> 517         x = tf.placeholder(dtype, shape=shape, name=name)
#     518     x._keras_shape = shape
#     519     x._uses_learning_phase = False
#
# AttributeError: module 'tensorflow' has no attribute 'placeholder'

# %%
model = Sequence.fit

# %% [markdown]
# ### Batch 생성
#
# 신경망 모델은 batch를 이용하여 훈련된다. 즉, 신경망의 가중치는 매번 일정한 순서를 따라 조정된다는 뜻이다. 여기서 중요한 것은 batch 내의 모든 순서가 동일한 길이를 가져야 한다는 점이다. 이를 위해 `<PAD>` 토큰을 이용해 padding을 한다. 아래 함수 *batches_generator* 를 이용해 신경망 모델에 이용할 batch를 생성한다.

# %%
import tensorflow as tf
import numpy as np

# %%
def batches_generator(batch_size, tokens, tags,
                      shuffle=True, allow_smaller_last_batch=True):
    """
        tokens와 tags 각각에 padding된 batch를 생성한다.
    """
    
    n_samples = len(tokens)

    if shuffle:
        # shuffle=True일 경우, n_samples를 랜덤으로 섞는다.
        order = np.random.permutation(n_samples)
    else:
        order = np.arange(n_samples)
    
    # n_samples를 batch_size로 나눈 몫을 n_batches에 저장한다.
    n_batches = n_samples // batch_size

    # allow_smaller_last_batch가 True고, 
    # n_samples를 batch_size로 나눈 나머지가 존재하면,
    # n_batches에 1을 추가한다.
    if allow_smaller_last_batch and n_samples % batch_size:
        n_batches += 1
    
    # n_batchs 수 만큼 batch를 생성한다.
    for k in range(n_batches):
        batch_start = k * batch_size
        batch_end = min((k + 1) * batch_size, n_samples)
        current_batch_size = batch_end - batch_start

        x_list = []
        y_list = []
        max_len_token = 0

        for idx in order[batch_start: batch_end]:
            x_list.append(words2idxs(tokens[idx])) # tokens 리스트를 index 리스트로 바꿔서 x_list에 저장
            y_list.append(tags2idxs(tags[idx])) # tags 리스트를 index 리스트로 바꿔서 y_list에 저장
            max_len_token = max(max_len_token, len(tags[idx])) # 현재까지 batch에서 가장 큰 tag리스트 사이즈를 저장
            
        # padding 인덱스로 채워진 nd-array를 생성한다.
        x = np.ones([current_batch_size, max_len_token], dtype=np.int32) * token2idx['<PAD>']
        y = np.ones([current_batch_size, max_len_token], dtype=np.int32) * tag2idx['O']
        
        # 0으로 채워진 (current_batch_size,) nd-array를 생성한다.
        lengths = np.zeros(current_batch_size, dtype=np.int32)
        for n in range(current_batch_size):
            utt_len = len(x_list[n])
            x[n, :utt_len] = x_list[n]
            lengths[n] = utt_len
            y[n, :utt_len] = y_list[n]
        yield x, y, lengths

# %% [markdown]
# ## RNN (Recurrent Neural Network) 모델 생성
#
# LSTM을 사용해 각 문장의 tag와 token의 확률 분포를 알아내는 모델을 생성한다. 여기서 문장 속의 각 tag/token의 앞뒤 문맥을 모두 고려하기 위해 Bi-Directional LSTM (Bi-LSTM)을 사용한다. tag 분류를 위한 Dense layer는 가장 상위에서 사용된다.

# %%
tf.version
# Out:
# <module 'tensorflow_core._api.v2.version' from '/anaconda3/envs/keras-test/lib/python3.6/site-packages/tensorflow_core/_api/v2/version/__init__.py'>

# %%
class BiLSTMModel():
    
    def declare_placeholders(self):
        """
            모델에 사용할 placeholder를 지정한다.
        """ 
        # input과 ground truth output의 Placeholders
        self.input_batch = tf.placeholder(dtype=tf.int32, shape=[None, None], name='input_batch') 
        self.ground_truth_tags = tf.placeholder(dtype=tf.int32, shape=[None, None], name='ground_truth_tags')

        # sequence의 length의 Placeholder
        self.lengths = tf.placeholder(dtype=tf.int32, shape=[None], name='lengths') 

        # dropout keep probability의 Placeholder
        # 1.0을 디폴트 값으로 준다.
        self.dropout_ph = tf.placeholder_with_default(tf.cast(1.0, tf.float32), shape=[])

        # 학습률의 Placeholder
        self.learning_rate_ph = tf.placeholder(dtype=tf.float32, shape=[], name='learning_rate_ph')

    
    def build_layers(self, vocabulary_size, embedding_dim, n_hidden_rnn, n_tags):
        """
            bi-LSTM 구조 설계하고 logit을 계산
        """
        # embedding 변수 생성
        initial_embedding_matrix = np.random.randn(vocabulary_size, embedding_dim) / np.sqrt(embedding_dim)
        embedding_matrix_variable = tf.Variable(initial_embedding_matrix, name='embeddings_matrix', dtype=tf.float32)

        # 은닉층의 RNN cell을 생성
        # dropout을 생성하고 dropout placeholder 값을 대입
        forward_cell =  tf.nn.rnn_cell.DropoutWrapper(
            tf.nn.rnn_cell.BasicLSTMCell(num_units=n_hidden_rnn, forget_bias=3.0),
            input_keep_prob=self.dropout_ph,
            output_keep_prob=self.dropout_ph,
            state_keep_prob=self.dropout_ph
        )
        backward_cell = tf.nn.rnn_cell.DropoutWrapper(
            tf.nn.rnn_cell.BasicLSTMCell(num_units=n_hidden_rnn, forget_bias=3.0),
            input_keep_prob=self.dropout_ph,
            output_keep_prob=self.dropout_ph,
            state_keep_prob=self.dropout_ph
        )

        # self.input_batch의 Look up embeddings 생성
        # Shape: [batch_size, sequence_len, embedding_dim].
        embeddings = tf.nn.embedding_lookup(embedding_matrix_variable, self.input_batch)

        # Bidirectional Dynamic RNN 에 통과
        # Shape: [batch_size, sequence_len, 2 * n_hidden_rnn]. 
        (rnn_output_fw, rnn_output_bw), _ =  tf.nn.bidirectional_dynamic_rnn(
                                                  cell_fw= forward_cell
                                                , cell_bw= backward_cell
                                                , dtype=tf.float32
                                                , inputs=embeddings
                                                , sequence_length=self.lengths
                                            )
        rnn_output = tf.concat([rnn_output_fw, rnn_output_bw], axis=2)

        # 상위에 Dense layer 생성
        # Shape: [batch_size, sequence_len, n_tags].   
        self.logits = tf.layers.dense(rnn_output, n_tags, activation=None)
        
    def compute_predictions(self):
        """
            logit을 확률로 transform하여 tag를 예측
        """
        # softmax 함수 생성
        softmax_output = tf.nn.softmax(self.logits)

        # argmax 를 이용하여 tag를 예측
        self.predictions = tf.argmax(softmax_output, axis = -1)
        
    def compute_loss(self, n_tags, PAD_index):
        """
            logit을 이용해 cross-entopy loss를 계산
        """
        # cross entropy function 생성
        ground_truth_tags_one_hot = tf.one_hot(self.ground_truth_tags, n_tags)
        loss_tensor = tf.nn.softmax_cross_entropy_with_logits(
            labels=ground_truth_tags_one_hot
            , logits=self.logits
        )

        mask = tf.cast(tf.not_equal(self.input_batch, PAD_index), tf.float32)
        # <PAD> token 은 제외하고 loss를 계산하는 loss function 생성
        self.loss = tf.reduce_mean(tf.reduce_sum(tf.multiply(loss_tensor, mask), axis=-1) \
                                   / tf.reduce_sum(mask, axis=-1))
        
    def perform_optimization(self):
        """
            모델의 optimizer, train_op 지정
        """
        # optimizer 생성
        self.optimizer = tf.train.AdamOptimizer(learning_rate=self.learning_rate_ph)
        self.grads_and_vars = self.optimizer.compute_gradients(self.loss)

        # self.grads_and_vars에 Gradient clipping 적용
        clip_norm = tf.cast(1.0, tf.float32)
        self.grads_and_vars = [(tf.clip_by_norm(grad, clip_norm), var) for grad, var in self.grads_and_vars]
        self.train_op = self.optimizer.apply_gradients(self.grads_and_vars)
    
    def __init__(self, vocabulary_size, n_tags, embedding_dim, n_hidden_rnn, PAD_index):
        """
            모델 생성 시, vocabulary_size, n_tags, embedding_dim, n_hidden_rnn, PAD_index를 지정하는 init 메소드
        """
        self.declare_placeholders()
        self.build_layers(vocabulary_size, embedding_dim, n_hidden_rnn, n_tags)
        self.compute_predictions()
        self.compute_loss(n_tags, PAD_index)
        self.perform_optimization()
        
    def train_on_batch(self, session, x_batch, y_batch, lengths, learning_rate, dropout_keep_probability):
        feed_dict = {self.input_batch: x_batch,
                     self.ground_truth_tags: y_batch,
                     self.learning_rate_ph: learning_rate,
                     self.dropout_ph: dropout_keep_probability,
                     self.lengths: lengths}

        session.run(self.train_op, feed_dict=feed_dict)
        
    def predict_for_batch(self, session, x_batch, lengths):
        predictions = session.run(self.predictions
                                 , feed_dict={self.input_batch:x_batch, self.lengths:lengths})
        return predictions

# %% [markdown]
# # 위 클래스 정의했으면 아래로 쭉! >> *모델평가*로 직행하세요

# %% [markdown]
# ### BiLSTMModel 클래스 각각의 함수 설명

# %% [markdown]
# 신경망이 실행되는 동안 입력할 data를 지정하기 위해 아래와 같은 [placeholders](https://www.tensorflow.org/versions/master/api_docs/python/tf/placeholder) 를 생성한다.
#
#  - *input_batch* — 단어 sequence (shape : [batch_size, sequence_len]);
#  - *ground_truth_tags* — 태그 sequence (shape :  [batch_size, sequence_len]);
#  - *lengths* — 패딩 되지 않은 sequence의 길이 (shape :  [batch_size]);
#  - *dropout_ph* — dropout keep probability;
#  - *learning_rate_ph* — 학습률;
#
# 아래 함수에서 shape를 지정하기 위해 *None* 값을 주었다. data (단어, 태그) 로 어떤 size든 올 수 있다는 뜻이다.

# %%
def declare_placeholders(self):
    """
        모델에 사용할 placeholder를 지정한다.
    """

    # input과 ground truth output의 Placeholders
    self.input_batch = tf.placeholder(dtype=tf.int32, shape=[None, None], name='input_batch') 
    self.ground_truth_tags = tf.placeholder(dtype=tf.int32, shape=[None, None], name='ground_truth_tags')
  
    # sequence의 length의 Placeholder
    self.lengths = tf.placeholder(dtype=tf.int32, shape=[None], name='lengths') 
    
    # dropout keep probability의 Placeholder
    # 1.0을 디폴트 값으로 준다.
    self.dropout_ph = tf.placeholder_with_default(tf.cast(1.0, tf.float32), shape=[])
    
    # 학습률의 Placeholder
    self.learning_rate_ph = tf.placeholder(dtype=tf.float32, shape=[], name='learning_rate_ph')

# %%
BiLSTMModel.__declare_placeholders = classmethod(declare_placeholders)

# %% [markdown]
# #### 신경망의 layer을 아래와 같이 지정한다.
#
# - [tf.Variable](https://www.tensorflow.org/api_docs/python/tf/Variable)를 이용하여 embedding matrix (*embeddings_matrix*)를 생성하고 랜덤 int값을 대입한다.
# - forward LSTM / backward LSTM cell을 각각 생성한다. TensorFlow의 *LSTMCell* 메소드를 이용한다.
#     - (다른 타입의 cell에 대한 설명은 다음을 참조 : e.g. GRU cells. [This](http://colah.github.io/posts/2015-08-Understanding-LSTMs/))
# - [DropoutWrapper](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper) 를 이용해 cell을 wrapping 한다. Dropout 은 신경망 모델의 regularization 에서 중요한 역할을 한다. 위의 `declare_placeholders`에서 지정한 `dropout_ph`를 이용한다.
#
# #### input_batch를 변환하여 computation graph를 아래와 같이 생성한다:
#
# - [Look up](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) 메소드를 이용해 embeddings를 생성한다.
# - embeddings 를 [Bidirectional Dynamic RNN](https://www.tensorflow.org/api_docs/python/tf/nn/bidirectional_dynamic_rnn) 에 적용한다. 위의  `declare_placeholders`에서 지정한 `lengths` placeholder를 이용해 padding token은 RNN에서 계산되지 않도록 한다.
# - 가장 상위에 dense layer를 생성한다. 이 layer의 output은 바로 loss function에 입력된다.

# %%
def build_layers(self, vocabulary_size, embedding_dim, n_hidden_rnn, n_tags):
    """
        bi-LSTM 구조 설계하고 logit을 계산
    """
    
    # embedding 변수 생성
    initial_embedding_matrix = np.random.randn(vocabulary_size, embedding_dim) / np.sqrt(embedding_dim)
    embedding_matrix_variable = tf.Variable(initial_embedding_matrix, name='embeddings_matrix', dtype=tf.float32)
    
    # 은닉층의 RNN cell을 생성
    # dropout을 생성하고 dropout placeholder 값을 대입
    forward_cell =  tf.nn.rnn_cell.DropoutWrapper(
        tf.nn.rnn_cell.BasicLSTMCell(num_units=n_hidden_rnn, forget_bias=3.0),
        input_keep_prob=self.dropout_ph,
        output_keep_prob=self.dropout_ph,
        state_keep_prob=self.dropout_ph
    )
    backward_cell = tf.nn.rnn_cell.DropoutWrapper(
        tf.nn.rnn_cell.BasicLSTMCell(num_units=n_hidden_rnn, forget_bias=3.0),
        input_keep_prob=self.dropout_ph,
        output_keep_prob=self.dropout_ph,
        state_keep_prob=self.dropout_ph
    )

    # self.input_batch의 Look up embeddings 생성
    # Shape: [batch_size, sequence_len, embedding_dim].
    embeddings = tf.nn.embedding_lookup(embedding_matrix_variable, self.input_batch)
    
    # Bidirectional Dynamic RNN 에 통과
    # Shape: [batch_size, sequence_len, 2 * n_hidden_rnn]. 
    (rnn_output_fw, rnn_output_bw), _ =  tf.nn.bidirectional_dynamic_rnn(
                                              cell_fw= forward_cell
                                            , cell_bw= backward_cell
                                            , dtype=tf.float32
                                            , inputs=embeddings
                                            , sequence_length=self.lengths
                                        )
    rnn_output = tf.concat([rnn_output_fw, rnn_output_bw], axis=2)

    # 상위에 Dense layer 생성
    # Shape: [batch_size, sequence_len, n_tags].   
    self.logits = tf.layers.dense(rnn_output, n_tags, activation=None)

# %%
BiLSTMModel.__build_layers = classmethod(build_layers)

# %% [markdown]
# 신경망에서 예측값을 나타내기 위해서는 [softmax](https://www.tensorflow.org/api_docs/python/tf/nn/softmax) 를 마지막 layer로 적용하여 tag 값을 나타내도록 해야 한다. [argmax](https://www.tensorflow.org/api_docs/python/tf/argmax).

# %%
def compute_predictions(self):
    """
        logit을 확률로 transform하여 tag를 예측
    """
    
    # softmax 함수 생성
    softmax_output = tf.nn.softmax(self.logits)
    
    # argmax 를 이용하여 tag를 예측
    self.predictions = tf.argmax(softmax_output, axis = -1)

# %%
BiLSTMModel.__compute_predictions = classmethod(compute_predictions)

# %% [markdown]
# 모델 training 중에는 loss function이 필요하다. 이 모델에서는 loss function으로 [cross-entropy loss](http://ml-cheatsheet.readthedocs.io/en/latest/loss_functions.html#cross-entropy)를 사용한다.
#
# TensorFlow에는 [cross entropy with logits](https://www.tensorflow.org/api_docs/python/tf/nn/softmax_cross_entropy_with_logits_v2) 메소드로 구현되어 있다. 이 메소드는 모델의 softmax의 확률이 아닌, logit에 적용되어야 한다. 또한, `<PAD>` 토큰의 loss는 계산되지 않아야 한다. 따라서 [mean](https://www.tensorflow.org/api_docs/python/tf/reduce_mean) 을 계산하기 전에 `<PAD>`의 토큰은 제거되어야 한다.

# %%
def compute_loss(self, n_tags, PAD_index):
    """
        logit을 이용해 cross-entopy loss를 계산
    """
    
    # cross entropy function 생성
    ground_truth_tags_one_hot = tf.one_hot(self.ground_truth_tags, n_tags)
    loss_tensor = tf.nn.softmax_cross_entropy_with_logits(
        labels=ground_truth_tags_one_hot
        , logits=self.logits
    )
    
    mask = tf.cast(tf.not_equal(self.input_batch, PAD_index), tf.float32)
    # <PAD> token 은 제외하고 loss를 계산하는 loss function 생성
    self.loss = tf.reduce_mean(tf.reduce_sum(tf.multiply(loss_tensor, mask), axis=-1) / tf.reduce_sum(mask, axis=-1))

# %%
BiLSTMModel.__compute_loss = classmethod(compute_loss)

# %% [markdown]
# 마지막으로 지정할 것은 loss를 optimize하는 방법이다. 이를 위해서 TensorFlow의 [Adam](https://www.tensorflow.org/api_docs/python/tf/train/AdamOptimizer) optimizer 를 사용한다. (학습률은 위에서 지정한 learning_rate_ph를 사용한다. 또한 발산하는 gradients를 제거하기 위해서 [clip_by_norm](https://www.tensorflow.org/api_docs/python/tf/clip_by_norm) 함수를 이용해 clipping을 적용한다.

# %%
def perform_optimization(self):
    """
        모델의 optimizer, train_op 지정
    """
    
    # optimizer 생성
    self.optimizer = tf.train.AdamOptimizer(learning_rate=self.learning_rate_ph)
    self.grads_and_vars = self.optimizer.compute_gradients(self.loss)
    
    # self.grads_and_vars에 Gradient clipping 적용
    clip_norm = tf.cast(1.0, tf.float32)
    self.grads_and_vars = [(tf.clip_by_norm(grad, clip_norm), var) for grad, var in self.grads_and_vars]
    self.train_op = self.optimizer.apply_gradients(self.grads_and_vars)

# %%
BiLSTMModel.__perform_optimization = classmethod(perform_optimization)

# %%
def init_model(self, vocabulary_size, n_tags, embedding_dim, n_hidden_rnn, PAD_index):
    self.__declare_placeholders()
    self.__build_layers(vocabulary_size, embedding_dim, n_hidden_rnn, n_tags)
    self.__compute_predictions()
    self.__compute_loss(n_tags, PAD_index)
    self.__perform_optimization()

# %%
BiLSTMModel.__init__ = classmethod(init_model)

# %% [markdown]
# ## 신경망 Training & tag 예측

# %% [markdown]
# [Session.run](https://www.tensorflow.org/api_docs/python/tf/Session#run) 메소드는 위에서 정의한 graph를 초기화하는 메소드이다. 신경망을 training 하기 위해서 *perform_optimization* 메소드 안의 *self.train_op*을 먼저 계산한다. tag를 예측하기 위해서는 *self.predictions*을 계산하면 된다.

# %%
def train_on_batch(self, session, x_batch, y_batch, lengths, learning_rate, dropout_keep_probability):
    feed_dict = {self.input_batch: x_batch,
                 self.ground_truth_tags: y_batch,
                 self.learning_rate_ph: learning_rate,
                 self.dropout_ph: dropout_keep_probability,
                 self.lengths: lengths}
    
    session.run(self.train_op, feed_dict=feed_dict)

# %%
BiLSTMModel.train_on_batch = classmethod(train_on_batch)

# %% [markdown]
# *feed_dict* 를 *x_batch* 와 *lengths* 를 이용해 초기화한 후, *predict_for_batch* 함수를 이용해 *prediction* 을 실행한다.

# %%
def predict_for_batch(self, session, x_batch, lengths):
    predictions = session.run(self.predictions
                             , feed_dict={self.input_batch:x_batch, self.lengths:lengths})
    return predictions

# %%
BiLSTMModel.predict_for_batch = classmethod(predict_for_batch)

# %% [markdown]
# ## 모델 평가
#  - *predict_tags*: 모델을 이용해 예측한 token, tag를 반환한다;
#  - *eval_conll*: 결과의 precision, recall, F1 score를 계산한다.

# %%
from evaluation import precision_recall_f1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-56-b78214df1dd0> in <module>
# ----> 1 from evaluation import precision_recall_f1
#
# ModuleNotFoundError: No module named 'evaluation'

# %%
def predict_tags(model, session, token_idxs_batch, lengths):
    """
        예측한 결과를 token, tag 형태로 반환
    """
    
    tag_idxs_batch = model.predict_for_batch(session, token_idxs_batch, lengths)
    
    tags_batch, tokens_batch = [], []
    for tag_idxs, token_idxs in zip(tag_idxs_batch, token_idxs_batch):
        tags, tokens = [], []
        for tag_idx, token_idx in zip(tag_idxs, token_idxs):
            tags.append(idx2tag[tag_idx])
            tokens.append(idx2token[token_idx])
        tags_batch.append(tags)
        tokens_batch.append(tokens)
    return tags_batch, tokens_batch
    
    
def eval_conll(model, session, tokens, tags, short_report=True):
    """
        Computes NER quality measures using CONLL shared task script.
    """
    
    y_true, y_pred = [], []
    for x_batch, y_batch, lengths in batches_generator(1, tokens, tags):
        tags_batch, tokens_batch = predict_tags(model, session, x_batch, lengths)
        if len(x_batch[0]) != len(tags_batch[0]):
            raise Exception("Incorrect length of prediction for the input, "
                            "expected length: %i, got: %i" % (len(x_batch[0]), len(tags_batch[0])))
        predicted_tags = []
        ground_truth_tags = []
        for gt_tag_idx, pred_tag, token in zip(y_batch[0], tags_batch[0], tokens_batch[0]): 
            if token != '<PAD>':
                ground_truth_tags.append(idx2tag[gt_tag_idx])
                predicted_tags.append(pred_tag)

        # We extend every prediction and ground truth sequence with 'O' tag
        # to indicate a possible end of entity.
        y_true.extend(ground_truth_tags + ['O'])
        y_pred.extend(predicted_tags + ['O'])
        
    results = precision_recall_f1(y_true, y_pred, print_results=True, short_report=short_report)
    return results

# %% [markdown]
# ## Run your experiment

# %% [markdown]
# Create *BiLSTMModel* model with the following parameters:
#  - *vocabulary_size* — token의 수;
#  - *n_tags* — tag의 수;
#  - *embedding_dim* — embedding의 차원, recommended value: 200;
#  - *n_hidden_rnn* — RNN 은닉층 size, recommended value: 200;
#  - *PAD_index* — padding token (`<PAD>`)의 index.
#
# hyperparameters 세팅:
# - *batch_size*: 32;
# - 4 epochs;
# - *learning_rate* 시작값: 0.005
# - *learning_rate_decay*: sqrt(2);
# - *dropout_keep_probability*: 0.1, 0.5, 0.9.

# %%
model = BiLSTMModel(20505, 21, 200, 200
                    , token2idx['<PAD>'])

batch_size = 32
n_epochs = 4
learning_rate = 0.005
learning_rate_decay = np.sqrt(2)

#0.1, 0.5, 0.9
dropout_keep_probability = 0.5
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-bb94481c34b0> in <module>
#       1 model = BiLSTMModel(20505, 21, 200, 200
# ----> 2                     , token2idx['<PAD>'])
#       3
#       4 batch_size = 32
#       5 n_epochs = 4
#
# <ipython-input-62-e8d38bbe626d> in __init__(self, vocabulary_size, n_tags, embedding_dim, n_hidden_rnn, PAD_index)
#     105             모델 생성 시, vocabulary_size, n_tags, embedding_dim, n_hidden_rnn, PAD_index를 지정하는 init 메소드
#     106         """
# --> 107         self.declare_placeholders()
#     108         self.build_layers(vocabulary_size, embedding_dim, n_hidden_rnn, n_tags)
#     109         self.compute_predictions()
#
# <ipython-input-62-e8d38bbe626d> in declare_placeholders(self)
#       6         """
#       7         # input과 ground truth output의 Placeholders
# ----> 8         self.input_batch = tf.placeholder(dtype=tf.int32, shape=[None, None], name='input_batch')
#       9         self.ground_truth_tags = tf.placeholder(dtype=tf.int32, shape=[None, None], name='ground_truth_tags')
#      10
#
# AttributeError: module 'tensorflow' has no attribute 'placeholder'

# %% [markdown]
# If you got an error *"Tensor conversion requested dtype float64 for Tensor with dtype float32"* in this point, check if there are variables without dtype initialised. Set the value of dtype equals to *tf.float32* for such variables.

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

print('Start training... \n')
for epoch in range(n_epochs):
    # For each epoch evaluate the model on train and validation data
    print('-' * 20 + ' Epoch {} '.format(epoch+1) + 'of {} '.format(n_epochs) + '-' * 20)
    print('Train data evaluation:')
    eval_conll(model, sess, train_tokens, train_tags, short_report=True)
    print('Validation data evaluation:')
    eval_conll(model, sess, validation_tokens, validation_tags, short_report=True)
    
    # Train the model
    for x_batch, y_batch, lengths in batches_generator(batch_size, train_tokens, train_tags):
        model.train_on_batch(sess, x_batch, y_batch, lengths, learning_rate, dropout_keep_probability)
        
    # Decaying the learning rate
    learning_rate = learning_rate / learning_rate_decay
    
print('...training finished.')
# Out:
# Start training...
#
# -------------------- Epoch 1 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 67843 phrases; correct: 130.
#
# precision:  0.19%; recall:  2.90%; F1:  0.36
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 8183 phrases; correct: 24.
#
# precision:  0.29%; recall:  4.47%; F1:  0.55
#
# -------------------- Epoch 2 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 2104 phrases; correct: 524.
#
# precision:  24.90%; recall:  11.67%; F1:  15.90
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 192 phrases; correct: 48.
#
# precision:  25.00%; recall:  8.94%; F1:  13.17
#
# -------------------- Epoch 3 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4673 phrases; correct: 1888.
#
# precision:  40.40%; recall:  42.06%; F1:  41.21
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 340 phrases; correct: 127.
#
# precision:  37.35%; recall:  23.65%; F1:  28.96
#
# -------------------- Epoch 4 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4800 phrases; correct: 2715.
#
# precision:  56.56%; recall:  60.48%; F1:  58.46
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 395 phrases; correct: 163.
#
# precision:  41.27%; recall:  30.35%; F1:  34.98
#
# ...training finished.

# %% [markdown]
# Now let us see full quality reports for the final model on train, validation, and test sets. To give you a hint whether you have implemented everything correctly, you might expect F-score about 40% on the validation set.
#
# **The output of the cell below (as well as the output of all the other cells) should be present in the notebook for peer2peer review!**

# %%
print('-' * 20 + ' Train set quality: ' + '-' * 20)
train_results = eval_conll(model, sess, train_tokens, train_tags, short_report=False)
    
print('-' * 20 + ' Validation set quality: ' + '-' * 20)
validation_results = eval_conll(model, sess, validation_tokens, validation_tags, short_report=False)

print('-' * 20 + ' Test set quality: ' + '-' * 20)
test_results = eval_conll(model, sess, test_tokens, test_tags, short_report=False)
# Out:
# -------------------- Train set quality: --------------------
# processed 105778 tokens with 4489 phrases; found: 4824 phrases; correct: 3346.
#
# precision:  69.36%; recall:  74.54%; F1:  71.86
#
# 	     company: precision:   74.66%; recall:   85.69%; F1:   79.80; predicted:   738
#
# 	    facility: precision:   60.27%; recall:   71.02%; F1:   65.20; predicted:   370
#
# 	     geo-loc: precision:   75.40%; recall:   93.57%; F1:   83.51; predicted:  1236
#
# 	       movie: precision:   14.29%; recall:    1.47%; F1:    2.67; predicted:     7
#
# 	 musicartist: precision:   43.37%; recall:   46.55%; F1:   44.91; predicted:   249
#
# 	       other: precision:   58.60%; recall:   85.07%; F1:   69.40; predicted:  1099
#
# 	      person: precision:   84.50%; recall:   86.12%; F1:   85.30; predicted:   903
#
# 	     product: precision:   55.25%; recall:   38.05%; F1:   45.07; predicted:   219
#
# 	  sportsteam: precision:  100.00%; recall:    1.38%; F1:    2.73; predicted:     3
#
# 	      tvshow: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0
#
# -------------------- Validation set quality: --------------------
# processed 12836 tokens with 537 phrases; found: 434 phrases; correct: 183.
#
# precision:  42.17%; recall:  34.08%; F1:  37.69
#
# 	     company: precision:   63.22%; recall:   52.88%; F1:   57.59; predicted:    87
#
# 	    facility: precision:   29.03%; recall:   26.47%; F1:   27.69; predicted:    31
#
# 	     geo-loc: precision:   58.82%; recall:   53.10%; F1:   55.81; predicted:   102
#
# 	       movie: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0
#
# 	 musicartist: precision:   17.65%; recall:   10.71%; F1:   13.33; predicted:    17
#
# 	       other: precision:   23.85%; recall:   38.27%; F1:   29.38; predicted:   130
#
# 	      person: precision:   46.15%; recall:   21.43%; F1:   29.27; predicted:    52
#
# 	     product: precision:    6.67%; recall:    2.94%; F1:    4.08; predicted:    15
#
# 	  sportsteam: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0
#
# 	      tvshow: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0
#
# -------------------- Test set quality: --------------------
# processed 13258 tokens with 604 phrases; found: 514 phrases; correct: 210.
#
# precision:  40.86%; recall:  34.77%; F1:  37.57
#
# 	     company: precision:   55.38%; recall:   42.86%; F1:   48.32; predicted:    65
#
# 	    facility: precision:   38.64%; recall:   36.17%; F1:   37.36; predicted:    44
#
# 	     geo-loc: precision:   60.58%; recall:   50.30%; F1:   54.97; predicted:   137
#
# 	       movie: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0
#
# 	 musicartist: precision:   13.64%; recall:   11.11%; F1:   12.24; predicted:    22
#
# 	       other: precision:   20.81%; recall:   34.95%; F1:   26.09; predicted:   173
#
# 	      person: precision:   58.62%; recall:   32.69%; F1:   41.98; predicted:    58
#
# 	     product: precision:    6.67%; recall:    3.57%; F1:    4.65; predicted:    15
#
# 	  sportsteam: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0
#
# 	      tvshow: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0

# %% [markdown]
# ### Conclusions
#
# Could we say that our model is state of the art and the results are acceptable for the task? Definately, we can say so. Nowadays, Bi-LSTM is one of the state of the art approaches for solving NER problem and it outperforms other classical methods. Despite the fact that we used small training corpora (in comparison with usual sizes of corpora in Deep Learning), our results are quite good. In addition, in this task there are many possible named entities and for some of them we have only several dozens of trainig examples, which is definately small. However, the implemented model outperforms classical CRFs for this task. Even better results could be obtained by some combinations of several types of methods, e.g. see [this](https://arxiv.org/abs/1603.01354) paper if you are interested.
