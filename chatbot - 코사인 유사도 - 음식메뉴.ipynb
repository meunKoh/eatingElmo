# %% [markdown]
# ## 음식메뉴 코사인 유사도
#
# **목표**<br>
# 챗봇에서 음식메뉴를 입력 받을 때, 데이터셋에 있는 음식메뉴와 정확하게 일치하지 않아도 코사인 유사도 모델을 통해 비슷한 음식메뉴를 선택할 수 있다.
#
# - 가게리스트 데이터의 Category1, Category2, menu 컬럼을 이용해 food 데이터셋을 만든다.
# - 위 데이터셋을 이용해 각 음식메뉴별 코사인 유사도를 나타내는 모델을 만든다.

# %% [markdown]
# #### 코사인 유사도 설명 참고자료
# - https://wikidocs.net/24603

# %%
import pandas as pd
import numpy as np
import re
from konlpy.tag import Mecab

# %% [markdown]
# ### 1. 음식메뉴 데이터 불러오기

# %%
df_foods = pd.read_csv('./questions/foods_bio.csv', encoding='utf-8', index_col=0)
df_foods.head(3)
# Out:
#      food           mecab           mecab_tag             okt  \
# 0     BBQ         ['BBQ']           ['B-FOD']         ['BBQ']
# 1  BBQ샐러드  ['BBQ', '샐러드']  ['B-FOD', 'I-FOD']  ['BBQ', '샐러드']
# 2    가라아게        ['가라아게']           ['B-FOD']        ['가라아게']
#
#               okt_tag
# 0           ['B-FOD']
# 1  ['B-FOD', 'I-FOD']
# 2           ['B-FOD']

# %%
# 가게리스트 데이터 불러오기
df_restaurants = pd.read_csv('./questions/가게리스트_카테고리_최종.csv',encoding='utf-8',index_col=0)
df_restaurants.head(2)
# Out:
#    storeid   Title storename Region Sigungu search_area Category1 Category2  \
# 0    13992  빛고을떡갈비    빛고을떡갈비     광주     광산구          광산        한식      숯불구이
# 1    13995   착한소장수     착한소장수     광주      동구          광주        한식        갈비
#
#                menu  Blog  reviews_num
# 0             육회비빔밥    24            2
# 1  갈비살/안창살/살치살/왕갈비탕  4155            7

# %%
# Category1, Category2, menu 컬럼 저장
df_foods = df_restaurants.groupby(['Category1','Category2','menu'], as_index=False).count()\
           [['Category1','Category2','menu']]
df_foods.shape
# Out:
# (916, 3)

# %%
df_foods.head(10)
# Out:
#   Category1 Category2        menu
# 0        기타       디저트  과일주스/ 수박주스
# 1        기타       디저트          꿀빵
# 2        기타       디저트         미용실
# 3        기타       디저트         바게트
# 4        기타       디저트        반찬가게
# 5        기타       디저트         보리빵
# 6        기타       디저트           빵
# 7        기타       디저트       아이스크림
# 8        기타       디저트        알수없음
# 9        기타       디저트         유원지

# %%
# Category1 + Category2 + menu를 합쳐서 저장
df_foods['food'] = df_foods['Category1'] + ' ' + df_foods['Category2'] + ' ' + df_foods['menu']
df_foods.head(10)
# Out:
#   Category1 Category2        menu               food
# 0        기타       디저트  과일주스/ 수박주스  기타 디저트 과일주스/ 수박주스
# 1        기타       디저트          꿀빵          기타 디저트 꿀빵
# 2        기타       디저트         미용실         기타 디저트 미용실
# 3        기타       디저트         바게트         기타 디저트 바게트
# 4        기타       디저트        반찬가게        기타 디저트 반찬가게
# 5        기타       디저트         보리빵         기타 디저트 보리빵
# 6        기타       디저트           빵           기타 디저트 빵
# 7        기타       디저트       아이스크림       기타 디저트 아이스크림
# 8        기타       디저트        알수없음        기타 디저트 알수없음
# 9        기타       디저트         유원지         기타 디저트 유원지

# %% [markdown]
# ### 2. `TfidfVectorizer`를 이용하여 벡터화

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
KOREAN_RE = re.compile('[^ ㄱ-ㅣ가-힣]+')

# 불용어는 챗봇 모델과 동일
STOPWORDS = set(['은','는','이','가','하','아','것','들','의','그','수','한','나','같','그렇'
                ,'문제','그리고','크','중','나오','지금','생각하','집','어떤','명','생각','이런'
                ,'인','지','을','를','에','스러운','스러워','주','할','만','게','도','져','된','로','고','던','로운','면서'
                ,'사실','이렇','점','싶','말','좀','식당','가게','집','음식점'
                ,'는지','나요','해요','해','는가요','삼','게요','예','는가','습니까','죠','려고요','는지요','서요','였어요','겠'
                ,'인가요','요' '라는','데','해서','세요','어요','을까요','건가요','겠죠','실래요','네요','으세요','지요','인데요'
                ,'드려요','려구요','합니다'])

# 각 음식메뉴를 mecab 형태소 분석하기 위한 함수
def text_prepare(text):
    
    # 한글/공백이 아닌 기타 문자는 space로 대체 (ex. 짜장면/짬뽕 -> 짜장면 짬뽕)
    text = KOREAN_RE.sub(' ',text)
    
    # Mecab 토크나이저
    mecab = Mecab()
    
    # mecab으로 text를 형태소 단위로 나누고 불용어를 제거
    text = ' '.join(token for token in mecab.morphs(text) if token not in STOPWORDS)

    return text

# %%
# 지역명에 mecab 형태소 분석 적용
df_foods['food_prep'] = df_foods.food.apply(text_prepare)
df_foods.head(10)
# Out:
#   Category1 Category2        menu               food           food_prep
# 0        기타       디저트  과일주스/ 수박주스  기타 디저트 과일주스/ 수박주스  기타 디저트 과일 주스 수박 주스
# 1        기타       디저트          꿀빵          기타 디저트 꿀빵          기타 디저트 꿀 빵
# 2        기타       디저트         미용실         기타 디저트 미용실          기타 디저트 미용실
# 3        기타       디저트         바게트         기타 디저트 바게트          기타 디저트 바게트
# 4        기타       디저트        반찬가게        기타 디저트 반찬가게           기타 디저트 반찬
# 5        기타       디저트         보리빵         기타 디저트 보리빵         기타 디저트 보리 빵
# 6        기타       디저트           빵           기타 디저트 빵            기타 디저트 빵
# 7        기타       디저트       아이스크림       기타 디저트 아이스크림        기타 디저트 아이스크림
# 8        기타       디저트        알수없음        기타 디저트 알수없음        기타 디저트 알 없 음
# 9        기타       디저트         유원지         기타 디저트 유원지          기타 디저트 유원지

# %%
# TF-IDF vectorizer 생성
tfidf_vectorizer = TfidfVectorizer(ngram_range=(1,2) # unigram, bigram 
                                  ,token_pattern='(\S+)') # 공백을 제거한 모든 문자/숫자/특수문자

# 벡터화할 데이터를 저장
y = df_foods.food_prep.values

# 벡터화된 데이터의 지역명을 저장
y_food = df_foods.food.values

# vectorizer를 y 데이터로 fitting
tfidf_vectorizer.fit(y)

# fitting 된 vectorizer 확인
tfidf_vectorizer
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=1.0, max_features=None,
#                 min_df=1, ngram_range=(1, 2), norm='l2', preprocessor=None,
#                 smooth_idf=True, stop_words=None, strip_accents=None,
#                 sublinear_tf=False, token_pattern='(\\S+)', tokenizer=None,
#                 use_idf=True, vocabulary=None)

# %%
# tfidf에 사용된 형태소 단어 확인 : 916개 음식메뉴를 나타내기 위해 총 2,203개 형태소가 사용되었음
tfidf_vocabs = tfidf_vectorizer.vocabulary_
len(tfidf_vocabs)
# Out:
# 2203

# %%
# 형태소 단어 미리보기
tfidf_vocabs
# Out:
# {'기타': 238,
#  '디저트': 507,
#  '과일': 137,
#  '주스': 1610,
#  '수박': 1168,
#  '기타 디저트': 239,
#  '디저트 과일': 508,
#  '과일 주스': 138,
#  '주스 수박': 1611,
#  '수박 주스': 1169,
#  '꿀': 290,
#  '빵': 928,
#  '디저트 꿀': 509,
#  '꿀 빵': 291,
#  '미용실': 699,
#  '디저트 미용실': 510,
#  '바게트': 714,
#  '디저트 바게트': 511,
#  '반찬': 730,
#  '디저트 반찬': 512,
#  '보리': 775,
#  '디저트 보리': 513,
#  '보리 빵': 776,
#  '디저트 빵': 514,
#  '아이스크림': 1302,
#  '디저트 아이스크림': 515,
#  '알': 1310,
#  '없': 1355,
#  '음': 1478,
#  '디저트 알': 516,
#  '알 없': 1311,
#  '없 음': 1356,
#  '유원지': 1463,
#  '디저트 유원지': 517,
#  '중국': 1618,
#  '디저트 중국': 518,
#  '중국 빵': 1619,
#  '캠': 1760,
#  '핌': 1966,
#  '장': 1525,
#  '디저트 캠': 519,
#  '캠 핌': 1761,
#  '핌 장': 1967,
#  '테마파크': 1866,
#  '디저트 테마파크': 520,
#  '펜션': 1937,
#  '디저트 펜션': 521,
#  '풀': 1947,
#  '빌': 924,
#  '라': 548,
#  '디저트 풀': 522,
#  '풀 빌': 1948,
#  '빌 라': 925,
#  '뷔페': 874,
#  '고기': 63,
#  '기타 뷔페': 240,
#  '뷔페 고기': 875,
#  '국수': 196,
#  '뷔페 국수': 876,
#  '떡볶이': 531,
#  '뷔페 떡볶이': 877,
#  '바베큐': 718,
#  '뷔페 바베큐': 878,
#  '뷔페 뷔페': 879,
#  '샐러드': 1011,
#  '뷔페 샐러드': 880,
#  '소고기': 1125,
#  '뷔페 소고기': 881,
#  '숙박': 1184,
#  '시설': 1259,
#  '뷔페 숙박': 882,
#  '숙박 시설': 1185,
#  '스테이크': 1214,
#  '뷔페 스테이크': 883,
#  '웨딩': 1460,
#  '홀': 2137,
#  '뷔페 웨딩': 884,
#  '웨딩 홀': 1461,
#  '한식': 1974,
#  '뷔페 한식': 886,
#  '한식 뷔페': 2023,
#  '카페': 1749,
#  '술': 1198,
#  '기타 카페': 242,
#  '카페 술': 1751,
#  '차': 1672,
#  '카페 차': 1752,
#  '카페 카페': 1753,
#  '커피': 1764,
#  '카페 커피': 1754,
#  '케이크': 1782,
#  '카페 케이크': 1755,
#  '포장마차': 1941,
#  '주류': 1605,
#  '기타 포장마차': 243,
#  '포장마차 주류': 1942,
#  '포장마차 포장마차': 1943,
#  '호프': 2121,
#  '골뱅이': 113,
#  '무침': 683,
#  '기타 호프': 244,
#  '호프 골뱅이': 2122,
#  '골뱅이 무침': 115,
#  '막걸리': 590,
#  '호프 막걸리': 2123,
#  '막걸리 주류': 592,
#  '맥주': 617,
#  '호프 맥주': 2124,
#  '맥주 주류': 618,
#  '치킨': 1724,
#  '맥주 치킨': 619,
#  '한치': 2067,
#  '맥주 한치': 620,
#  '소주': 1152,
#  '호프 소주': 2125,
#  '호프 술': 2126,
#  '호프 알': 2127,
#  '정종': 1581,
#  '대포': 395,
#  '소주방': 1153,
#  '호프 정종': 2128,
#  '정종 대포': 1582,
#  '대포 소주방': 396,
#  '호프 주류': 2129,
#  '오뎅': 1385,
#  '탕': 1825,
#  '주류 오뎅': 1606,
#  '오뎅 탕': 1386,
#  '주점': 1612,
#  '호프 주점': 2130,
#  '호프 치킨': 2131,
#  '파전': 1927,
#  '호프 파전': 2133,
#  '통닭': 1875,
#  '호프 호프': 2134,
#  '호프 통닭': 2132,
#  '아시아': 1300,
#  '식': 1260,
#  '베트남': 768,
#  '샤브샤브': 1086,
#  '기타 아시아': 241,
#  '아시아 식': 1301,
#  '식 베트남': 1261,
#  '베트남 샤브샤브': 769,
#  '쌀국수': 1265,
#  '베트남 쌀국수': 770,
#  '반': 728,
#  '쎄오': 1280,
#  '쌀국수 반': 1266,
#  '반 쎄오': 729,
#  '분': 833,
#  '짜': 1629,
#  '쌀국수 분': 1267,
#  '분 짜': 834,
#  '조': 1591,
#  '쌀국수 짜': 1268,
#  '짜 조': 1632,
#  '월남': 1458,
#  '쌈': 1269,
#  '베트남 월남': 771,
#  '월남 쌈': 1459,
#  '쌈 샤브샤브': 1270,
#  '팟타이': 1932,
#  '베트남 팟타이': 772,
#  '팟타이 쌀국수': 1934,
#  '인도': 1484,
#  '시': 1249,
#  '랭': 564,
#  '미고': 696,
#  '식 인도': 1262,
#  '인도 시': 1486,
#  '시 랭': 1250,
#  '랭 미고': 565,
#  '미고 랭': 697,
#  '머턴': 625,
#  '커리': 1762,
#  '인도 머턴': 1485,
#  '머턴 커리': 626,
#  '인도 쌀국수': 1487,
#  '태국': 1841,
#  '인도 인도': 1489,
#  '인도 태국': 1492,
#  '요리': 1429,
#  '인도 요리': 1488,
#  '요리 치킨': 1436,
#  '치킨 커리': 1736,
#  '카레': 1746,
#  '인도 카레': 1490,
#  '탄두리': 1821,
#  '인도 탄두리': 1491,
#  '탄두리 치킨': 1822,
#  '버터': 762,
#  '치킨 버터': 1728,
#  '버터 치킨': 763,
#  '치킨 카레': 1735,
#  '구아': 158,
#  '카': 1744,
#  '몰리': 681,
#  '식 태국': 1264,
#  '태국 구아': 1842,
#  '구아 카': 159,
#  '카 몰리': 1745,
#  '몰리 샐러드': 682,
#  '똠양꿍': 539,
#  '팍': 1928,
#  '붕': 872,
#  '태국 똠양꿍': 1843,
#  '똠양꿍 팍': 540,
#  '팍 붕': 1929,
#  '태국 태국': 1845,
#  '태국 요리': 1844,
#  '갈비': 9,
#  '요리 갈비': 1430,
#  '갈비 국수': 12,
#  '국수 팟타이': 221,
#  '전문': 1552,
#  '요리 전문': 1435,
#  '태국 팟타이': 1846,
#  '팟타이 똠양꿍': 1933,
#  '서양식': 1092,
#  '멕시코': 634,
#  '감자튀김': 48,
#  '서양식 멕시코': 1093,
#  '멕시코 감자튀김': 635,
#  '김치': 246,
#  '겹': 58,
#  '필라프': 1965,
#  '멕시코 김치': 636,
#  '김치 겹': 247,
#  '겹 필라프': 60,
#  '꽃등심': 289,
#  '멕시코 꽃등심': 637,
#  '멕시코 맥주': 638,
#  '타코': 1818,
#  '퀘': 1796,
#  '사': 940,
#  '디아': 506,
#  '멕시코 멕시코': 639,
#  '멕시코 요리': 646,
#  '요리 타코': 1437,
#  '타코 퀘': 1819,
#  '퀘 사': 1797,
#  '사 디아': 941,
#  '복합문': 819,
#  '화': 2143,
#  '공간': 133,
#  '멕시코 복합문': 640,
#  '복합문 화': 820,
#  '화 공간': 2144,
#  '멕시코 뷔페': 641,
#  '비비': 915,
#  '큐': 1799,
#  '멕시코 비비': 643,
#  '비비 큐': 916,
#  '비': 912,
#  '스트로': 1240,
#  '멕시코 비': 642,
#  '비 스트로': 913,
#  '멕시코 서양식': 644,
#  '멕시코 알': 645,
#  '멕시코 주류': 647,
#  '멕시코 치킨': 648,
#  '멕시코 카레': 649,
#  '커트': 1763,
#  '멕시코 커트': 650,
#  '멕시코 타코': 651,
#  '멕시코 통닭': 652,
#  '피자': 1959,
#  '멕시코 피자': 653,
#  '해산물': 2098,
#  '멕시코 해산물': 654,
#  '브런치': 888,
#  '까페': 271,
#  '서양식 브런치': 1094,
#  '브런치 까페': 889,
#  '녹차': 319,
#  '라떼': 550,
#  '브런치 녹차': 890,
#  '녹차 라떼': 320,
#  '도넛': 425,
#  '브런치 도넛': 891,
#  '뚱': 545,
#  '샌드위치': 1010,
#  '브런치 뚱': 892,
#  '뚱 샌드위치': 546,
#  '라이브': 557,
#  '브런치 라이브': 893,
#  '라이브 카페': 558,
#  '브런치 뷔페': 895,
#  '브런치 브런치': 896,
#  '바비큐': 720,
#  '플래터': 1957,
#  '브런치 바비큐': 894,
#  '바비큐 플래터': 721,
#  '플래터 스테이크': 1958,
#  '스테이크 샐러드': 1222,
#  '새우': 1002,
#  '파니니': 1879,
#  '브런치 새우': 897,
#  '새우 샐러드': 1003,
#  '샐러드 파니니': 1013,
#  '브런치 샌드위치': 898,
#  '브런치 샐러드': 899,
#  '샤': 1084,
#  '케라': 1778,
#  '또': 534,
#  '브런치 샤': 900,
#  '샤 케라': 1085,
#  '케라 또': 1779,
#  '브런치 숙박': 901,
#  '아메리카노': 1291,
#  '브런치 아메리카노': 902,
#  '단호박': 332,
#  '아메리카노 단호박': 1292,
#  '단호박 라떼': 333,
#  '아메리카노 라떼': 1293,
#  '에스프레소': 1359,
#  '아메리카노 에스프레소': 1295,
#  '아메리카노 카페': 1296,
#  '카페 라떼': 1750,
#  '쿠키': 1795,
#  '아메리카노 쿠키': 1297,
#  '크림': 1806,
#  '생': 1015,
#  '아메리카노 크림': 1299,
#  '크림 생': 1809,
#  '생 맥주': 1019,
#  '아인': 1304,
#  '슈페너': 1208,
#  '브런치 아인': 903,
#  '아인 슈페너': 1305,
#  '에메랄드': 1357,
#  '브런치 에메랄드': 904,
#  '에메랄드 라떼': 1358,
#  '장미': 1526,
#  '맨': 621,
#  '숀': 1164,
#  '브런치 장미': 905,
#  '장미 맨': 1527,
#  '맨 숀': 622,
#  '숀 라떼': 1165,
#  '초코': 1706,
#  '브런치 초코': 906,
#  '초코 라떼': 1707,
#  '브런치 커피': 907,
#  '과': 134,
#  '일청': 1508,
#  '커피 과': 1765,
#  '과 일청': 136,
#  '일청 꿀': 1509,
#  '더치커피': 401,
#  '자몽': 1513,
#  '커피 더치커피': 1766,
#  '더치커피 자몽': 402,
#  '자몽 주스': 1514,
#  '돈': 433,
#  '까스': 262,
#  '커피 돈': 1767,
#  '돈 까스': 434,
#  '돌체': 448,
#  '커피 돌체': 1768,
#  '돌체 라떼': 449,
#  '토스트': 1874,
#  '커피 브런치': 1769,
#  '브런치 토스트': 910,
#  '커피 샐러드': 1770,
#  '샐러드 쿠키': 1012,
#  '모': 667,
#  '히토': 2202,
#  '커피 아메리카노': 1772,
#  '아메리카노 모': 1294,
#  '모 히토': 669,
#  '크로': 1802,
#  '와': 1413,
#  '상': 1000,
#  '아메리카노 크로': 1298,
#  '크로 와': 1803,
#  '와 상': 1415,
#  '상 샌드위치': 1001,
#  '당근': 374,
#  '커피 에스프레소': 1773,
#  '에스프레소 당근': 1360,
#  '당근 케이크': 375,
#  '클레어': 1812,
#  '커피 클레어': 1774,
#  '타르트': 1817,
#  '커피 타르트': 1775,
#  '프라': 1951,
#  '푸치노': 1946,
#  '커피 프라': 1777,
#  '프라 푸치노': 1952,
#  '브런치 퀘': 908,
#  '모카': 676,
#  '인력': 1493,
#  '브런치 크림': 909,
#  '크림 모카': 1807,
#  '모카 인력': 677,
#  '인력 커피': 1494,
#  '파스타': 1881,
#  '브런치 파스타': 911,
#  '나베': 298,
#  '서양식 스테이크': 1095,
#  '스테이크 나베': 1215,
#  '나베 돈': 299,
#  '스테이크 돈': 1217,
#  '초계': 1699,
#  '까스 초계': 267,
#  '초계 국수': 1700,
#  '등심': 500,
#  '스테이크 등심': 1218,
#  '등심 돈': 501,
#  '등심 스테이크': 504,
#  '제': 1583,
#  '스테이크 제': 1228,
#  '제 파스타': 1585,
#  '바닷가재': 715,
#  '정식': 1567,
#  '스테이크 바닷가재': 1219,
#  '바닷가재 정식': 716,
#  '살치': 963,
#  '살': 957,
#  '스테이크 살치': 1221,
#  '살치 살': 964,
#  '살 스테이크': 958,
#  '수제': 1173,
#  '왕돈': 1427,
#  '스테이크 수제': 1223,
#  '수제 왕돈': 1177,
#  '왕돈 까스': 1428,
#  '스테이크 스테이크': 1224,
#  '함박': 2068,
#  '스테이크 함박': 1236,
#  '함박 스테이크': 2069,
#  '오븐': 1396,
#  '스파게티': 1243,
#  '스테이크 오븐': 1225,
#  '오븐 스파게티': 1397,
#  '와인': 1418,
#  '스테이크 와인': 1226,
#  '칵테일': 1756,
#  '와인 칵테일': 1420,
#  '이탈리아': 1481,
#  '코스': 1786,
#  '스테이크 이탈리아': 1227,
#  '이탈리아 코스': 1482,
#  '코스 요리': 1787,
#  '철판': 1690,
#  '스테이크 철판': 1229,
#  '철판 스테이크': 1691,
#  '스테이크 칵테일': 1230,
#  '칵테일 와인': 1757,
#  '와인 샐러드': 1419,
#  '스테이크 커피': 1231,
#  '커피 스테이크': 1771,
#  '큐브': 1800,
#  '스테이크 큐브': 1232,
#  '큐브 스테이크': 1801,
#  '키조개': 1813,
#  '리조': 577,
#  '스테이크 키조개': 1233,
#  '키조개 리조': 1814,
#  '리조 또': 578,
#  '프랑스': 1953,
#  '스테이크 프랑스': 1234,
#  '프랑스 코스': 1954,
#  '하버': 1970,
#  '순두부': 1192,
#  '스테이크 하버': 1235,
#  '하버 순두부': 1971,
#  '순두부 카레': 1196,
#  '스테이크 해산물': 1237,
#  '해산물 스파게티': 2099,
#  '히': 2200,
#  '레': 566,
#  '스테이크 히': 1238,
#  '히 레': 2201,
#  '레 까스': 567,
#  '스페인': 1244,
#  '홍합': 2141,
#  '스튜': 1239,
#  '서양식 스페인': 1096,
#  '스페인 스페인': 1245,
#  '스페인 요리': 1247,
#  '요리 와인': 1434,
#  '와인 홍합': 1422,
#  '홍합 스튜': 2142,
#  '타파스': 1820,
#  '스페인 코스': 1248,
#  '요리 타파스': 1438,
#  '스페인 알': 1246,
#  '터키': 1847,
#  '서양식 터키': 1097,
#  '터키 갈비': 1848,
#  '감': 42,
#  '바스': 722,
#  '터키 감': 1849,
#  '감 바스': 43,
#  '뉴욕': 323,
#  '스트립': 1241,
#  '터키 뉴욕': 1850,
#  '뉴욕 스트립': 324,
#  '스트립 스테이크': 1242,
#  '터키 샐러드': 1851,
#  '터키 스테이크': 1852,
#  '터키 알': 1854,
#  '플': 1956,
#  '터키 와': 1855,
#  '와 플': 1417,
#  '우육': 1449,
#  '면': 655,
#  '터키 우육': 1856,
#  '우육 면': 1451,
#  '케밥': 1780,
#  '터키 케밥': 1858,
#  '사디': 947,
#  '띠': 547,
#  '터키 퀘': 1859,
#  '퀘 사디': 1798,
#  '사디 또': 948,
#  '또 띠': 535,
#  '음식': 1479,
#  '터키 터키': 1860,
#  '터키 음식': 1857,
#  '음식 케밥': 1480,
#  '케밥 터키': 1781,
#  '터키 식': 1853,
#  '식 치킨': 1263,
#  '치킨 스테이크': 1730,
#  '터키 파스타': 1861,
#  '파스타 스테이크': 1906,
#  '한우': 2059,
#  '채끝': 1685,
#  '터키 한우': 1862,
#  '한우 채끝': 2066,
#  '채끝 등심': 1686,
#  '항': 2071,
#  '정상': 1565,
#  '덮밥': 405,
#  '바키': 726,
#  '라이스': 559,
#  '터키 항': 1863,
#  '항 정상': 2072,
#  '정상 덮밥': 1566,
#  '덮밥 바키': 411,
#  '바키 라이스': 727,
#  '서양식 피자': 1098,
#  '피자 파스타': 1964,
#  '파스타 샐러드': 1903,
#  '갈레': 6,
#  '쉬': 1206,
#  '림프': 579,
#  '파스타 갈레': 1882,
#  '갈레 쉬': 7,
#  '쉬 림프': 1207,
#  '림프 스파게티': 580,
#  '고르': 105,
#  '곤': 109,
#  '졸라': 1602,
#  '파스타 고르': 1883,
#  '고르 곤': 106,
#  '곤 졸라': 110,
#  '관자': 139,
#  '파스타 관자': 1884,
#  '관자 제': 140,
#  '까르보': 260,
#  '나라': 296,
#  '파스타 까르보': 1886,
#  '까르보 나라': 261,
#  '꽁': 283,
#  '떼': 532,
#  '쏘': 1281,
#  '파스타 꽁': 1887,
#  '꽁 떼': 284,
#  '떼 쏘': 533,
#  '폴리': 1944,
#  '파스타 폴리': 1921,
#  '폴리 피자': 1945,
#  '돈가스': 440,
#  '파스타 돈가스': 1889,
#  '파스타 제': 1914,
#  '파스타 김치': 1885,
#  '김치 필라프': 250,
#  '파스타 리조': 1891,
#  '마르': 587,
#  '리': 573,
#  '따': 524,
#  '파스타 마르': 1892,
#  '마르 리': 588,
#  '리 따': 574,
#  '따 피자': 525,
#  '화덕': 2146,
#  '따 화덕': 526,
#  '화덕 피자': 2147,
#  '매운': 603,
#  '파스타 매운': 1893,
#  '매운 갈비': 604,
#  '갈비 파스타': 31,
#  '명란젓': 663,
#  '파스타 명란젓': 1895,
#  '명란젓 크림': 664,
#  '크림 스파게티': 1810,
#  '명란': 660,
#  '파스타 명란': 1894,
#  '명란 크림': 661,
#  '크림 파스타': 1811,
#  '명란 파스타': 662,
#  '렐라': 568,
#  '프레스코': 1955,
#  '파스타 모': 1896,
#  '모 짜': 668,
#  '짜 렐라': 1631,
#  '렐라 알': 569,
#  '알 프레스코': 1312,
#  '미트볼': 700,
#  '파스타 미트볼': 1898,
#  '미트볼 파스타': 701,
#  '나라 스테이크': 297,
#  '버거': 750,
#  '파스타 버거': 1899,
#  '버섯': 751,
#  '파스타 버섯': 1900,
#  '버섯 리조': 752,
#  '빠': 926,
#  '네': 314,
#  '파스타 빠': 1901,
#  '빠 네': 927,
#  '텔레토비': 1867,
#  '파스타 새우': 1902,
#  '새우 제': 1005,
#  '제 리조': 1584,
#  '또 텔레토비': 538,
#  '텔레토비 피자': 1868,
#  '새우 크림': 1006,
#  '샐러드 파스타': 1014,
#  '샷': 1091,
#  '파스타 샷': 1904,
#  '파스타 쉬': 1905,
#  '파스타 스파게티': 1907,
#  '시금치': 1254,
#  '베이컨': 766,
#  '파스타 시금치': 1908,
#  '시금치 베이컨': 1255,
#  '베이컨 피자': 767,
#  '앤': 1315,
#  '쵸': 1708,
#  '오': 1378,
#  '일': 1497,
#  '안심': 1306,
#  '파스타 앤': 1910,
#  '앤 쵸': 1316,
#  '쵸 비': 1709,
#  '비 오': 914,
#  '오 일': 1382,
#  '일 파스타': 1498,
#  '파스타 안심': 1909,
#  '안심 스테이크': 1307,
#  '파스타 와인': 1911,
#  '와인 파스타': 1421,
#  '스테이크 브런치': 1220,
#  '파스타 이탈리아': 1912,
#  '요리 샐러드': 1433,
#  '이탈리안': 1483,
#  '파스타 이탈리안': 1913,
#  '파스타 치킨': 1915,
#  '칠': 1741,
#  '파스타 칠': 1916,
#  '칠 리': 1742,
#  '리 치킨': 576,
#  '파스타 커피': 1917,
#  '커피 파스타': 1776,
#  '토마토': 1872,
#  '파스타 토마토': 1918,
#  '토마토 칠': 1873,
#  '리 새우': 575,
#  '새우 스파게티': 1004,
#  '파스타 파니니': 1919,
#  '파니니 파스타': 1880,
#  '파스타 파스타': 1920,
#  '파스타 돈': 1888,
#  '라따뚜이': 549,
#  '파스타 라따뚜이': 1890,
#  '또 샐러드': 537,
#  '물냉면': 693,
#  '파스타 물냉면': 1897,
#  '파스타 피자': 1922,
#  '피자 스테이크': 1963,
#  '피자 리조': 1961,
#  '또 맥주': 536,
#  '파스타 한우': 1923,
#  '파스타 함박': 1924,
#  '해물': 2074,
#  '뚝배기': 542,
#  '파스타 해물': 1925,
#  '해물 뚝배기': 2076,
#  '뚝배기 파스타': 544,
#  '드래프트': 492,
#  '비어': 921,
#  '파스타 화덕': 1926,
#  '피자 드래프트': 1960,
#  '드래프트 비어': 493,
#  '피자 수제': 1962,
#  '수제 파스타': 1178,
#  '햄버거': 2110,
#  '서양식 햄버거': 1099,
#  '햄버거 샐러드': 2111,
#  '햄버거 수제': 2112,
#  '수제 버거': 1175,
#  '수제 햄버거': 1179,
#  '햄버거 치킨': 2113,
#  '패스트푸드': 1936,
#  '햄버거 패스트푸드': 2114,
#  '핫도그': 2070,
#  '햄버거 핫도그': 2115,
#  '햄버거 햄버거': 2116,
#  '일식': 1499,
#  '가라아게': 0,
#  '일식 덮밥': 1500,
#  '덮밥 가라아게': 406,
#  '도시락': 430,
#  '덮밥 도시락': 407,
#  '츠': 1714,
#  '덮밥 돈': 408,
#  '돈 츠': 437,
#  '츠 덮밥': 1715,
#  '민나': 703,
#  '노': 315,
#  '꼬': 273,
#  '노미야': 317,
#  '끼': 294,
#  '덮밥 민나': 409,
#  '민나 노': 704,
#  '노 오': 316,
#  '오 꼬': 1380,
#  '꼬 노미야': 274,
#  '노미야 끼': 318,
#  '바지락': 723,
#  '찜': 1661,
#  '덮밥 바지락': 410,
#  '바지락 찜': 725,
#  '새우튀김': 1008,
#  '덮밥 새우튀김': 412,
#  '야': 1317,
#  '규동': 232,
#  '덮밥 야': 414,
#  '야 끼': 1318,
#  '끼 규동': 295,
#  '규동 정식': 233,
#  '덮밥 오': 415,
#  '오징어': 1399,
#  '튀김': 1878,
#  '덮밥 오징어': 416,
#  '오징어 튀김': 1402,
#  '왕': 1424,
#  '덮밥 왕': 417,
#  '왕 갈비': 1425,
#  '우동': 1442,
#  '덮밥 우동': 418,
#  '자카야': 1517,
#  '매콤': 615,
#  '덮밥 자카야': 419,
#  '자카야 매콤': 1518,
#  '매콤 크림': 616,
#  '크림 새우': 1808,
#  '덮밥 주류': 420,
#  '치즈': 1720,
#  '카츠': 1748,
#  '덮밥 치즈': 421,
#  '치즈 돈': 1722,
#  '돈 카츠': 438,
#  '오야코동': 1398,
#  '덮밥 카레': 422,
#  '카레 오야코동': 1747,
#  '토리': 1869,
#  '게살': 55,
#  '고로케': 104,
#  '덮밥 토리': 423,
#  '토리 가라아게': 1870,
#  '가라아게 새우튀김': 1,
#  '새우튀김 수제': 1009,
#  '수제 게살': 1174,
#  '게살 고로케': 56,
#  '회': 2154,
#  '덮밥 회': 424,
#  '돈부리': 441,
#  '일식 돈': 1501,
#  '까스 츠': 268,
#  '츠 돈부리': 1716,
#  '까스 돈가스': 264,
#  '까스 돈': 263,
#  '까스 돈부리': 265,
#  '라멘': 551,
#  '코츠': 1788,
#  '차슈': 1674,
#  '동': 450,
#  '까스 라멘': 266,
#  '라멘 돈': 552,
#  '돈 코츠': 439,
#  '코츠 차슈': 1789,
#  '차슈 동': 1675,
#  '까스 파스타': 269,
#  '흑': 2195,
#  '까스 흑': 270,
#  '흑 돈': 2196,
#  '돈 등심': 435,
#  '등심 카츠': 505,
#  '일식 라멘': 1502,
#  '라멘 라멘': 553,
#  '소바': 1145,
#  '일식 소바': 1504,
#  '소바 덮밥': 1146,
#  '메밀국수': 632,
#  '소바 메밀국수': 1147,
#  '소바 소바': 1148,
#  '소바 알': 1149,
#  '소바 우동': 1150,
#  '탄탄': 1823,
#  '소바 탄탄': 1151,
#  '탄탄 면': 1824,
#  '광어': 141,
#  '일식 일식': 1505,
#  '일식 회': 1507,
#  '회 광어': 2155,
#  '광어회': 142,
#  '회 광어회': 2156,
#  '미회': 702,
#  '회 미회': 2167,
#  '랍': 560,
#  '스타': 1211,
#  '회 랍': 2160,
#  '랍 스타': 561,
#  '스타 찜': 1212,
#  '로브스터': 570,
#  '스터': 1213,
#  '회 로브스터': 2161,
#  '로브스터 랍': 571,
#  '랍 스터': 562,
#  '모듬': 670,
#  '등': 498,
#  '회 모듬': 2164,
#  '모듬 회': 674,
#  '회 등': 2158,
#  '물회': 694,
#  '회 물회': 2166,
#  '방어회': 735,
#  '회 방어회': 2168,
#  '벤': 773,
#  '댕이': 397,
#  '회 벤': 2169,
#  '벤 댕이': 774,
#  '생선회': 1079,
#  '회 생선회': 2172,
#  '세꼬': 1121,
#  '생선회 오징어': 1080,
#  '오징어 회': 1403,
#  '회 세꼬': 2173,
#  '세꼬 시': 1122,
#  '초밥': 1701,
#  '생선회 초밥': 1081,
#  '시 회': 1251,
#  '송어': 1158,
#  '회 송어': 2174,
#  '송어 회': 1159,
#  '연어': 1361,
#  '회 연어': 2176,
#  '사케': 950,
#  '혼마': 2135,
#  '구로동': 157,
#  '연어 사케': 1363,
#  '사케 동': 951,
#  '동 혼마': 451,
#  '혼마 구로동': 2136,
#  '우럭': 1443,
#  '회 우럭': 2177,
#  '우럭 회': 1444,
#  '참치': 1681,
#  '회 참치': 2180,
#  '참가자미': 1678,
#  '참치 참가자미': 1682,
#  '회 초밥': 2181,
#  '물': 690,
#  '회 물': 2165,
#  '물 요리': 692,
#  '해물탕': 2096,
#  '회 해물탕': 2182,
#  '해물탕 회': 2097,
#  '회 해산물': 2183,
#  '활어': 2149,
#  '회 활어': 2184,
#  '활어 회': 2150,
#  '매운탕': 607,
#  '회 매운탕': 2163,
#  '회 회': 2185,
#  '전복': 1553,
#  '회 전복': 2178,
#  '전복 회': 1558,
#  '회무': 2188,
#  '침': 1743,
#  '회 회무': 2186,
#  '회무 침': 2189,
#  '회 정식': 2179,
#  '회집': 2192,
#  '회 회집': 2187,
#  '일식 뷔페': 1503,
#  '뷔페 초밥': 885,
#  '뷔페 해산물': 887,
#  '일식 초밥': 1506,
#  '초밥 초밥': 1704,
#  '초밥 생': 1702,
#  '생 연어': 1022,
#  '스': 1209,
#  '초밥 스': 1703,
#  '스 시': 1210,
#  '사시미': 949,
#  '초밥 회': 1705,
#  '회 사시미': 2171,
#  '중국식': 1620,
#  '마라': 585,
#  '중국식 마라': 1621,
#  '마라 탕': 586,
#  '탕 마라': 1827,
#  '탕 샤브샤브': 1828,
#  '유린기': 1462,
#  '탕 유린기': 1831,
#  '양': 1340,
#  '꼬치': 280,
#  '꿔': 292,
#  '바로우': 717,
#  '중국식 양': 1622,
#  '양 꼬치': 1343,
#  '꼬치 양': 281,
#  '양 갈비': 1341,
#  '갈비 꿔': 14,
#  '꿔 바로우': 293,
#  '짬뽕': 1638,
#  '탕수육': 1835,
#  '꼬치 짬뽕': 282,
#  '짬뽕 탕수육': 1643,
#  '짜장면': 1635,
#  '중국식 짜장면': 1623,
#  '짜장면 짬뽕': 1636,
#  '짜장': 1633,
#  '짬뽕 짜장': 1640,
#  '짜장 짬뽕': 1634,
#  '짬뽕 짜장면': 1641,
#  '짜장면 탕수육': 1637,
#  '짬뽕 짬뽕': 1642,
#  '짬뽕 피자': 1644,
#  '베이징': 764,
#  '덕': 403,
#  '딤섬': 523,
#  '중국식 탕수육': 1624,
#  '탕수육 베이징': 1836,
#  '베이징 덕': 765,
#  '덕 딤섬': 404,
#  '탕수육 알': 1837,
#  '탕수육 유린기': 1838,
#  '탕수육 탕수육': 1839,
#  '훠궈': 2194,
#  '탕수육 훠궈': 1840,
#  '닭강정': 353,
#  '치킨 닭강정': 1725,
#  '닭강정 닭강정': 354,
#  '닭꼬치': 360,
#  '닭강정 치즈': 356,
#  '치즈 닭꼬치': 1721,
#  '불닭': 871,
#  '닭강정 불닭': 355,
#  '닭강정 치킨': 357,
#  '치킨 통닭': 1738,
#  '마늘': 581,
#  '치킨 치킨': 1734,
#  '치킨 마늘': 1727,
#  '마늘 치킨': 584,
#  '치킨 정종': 1731,
#  '닭': 334,
#  '똥집': 541,
#  '치킨 찜': 1732,
#  '찜 닭': 1665,
#  '닭 치킨': 346,
#  '치킨 똥집': 1726,
#  '치': 1717,
#  '밥': 732,
#  '치킨 치': 1733,
#  '치 밥': 1718,
#  '크리스피': 1804,
#  '순': 1186,
#  '치킨 크리스피': 1737,
#  '크리스피 치킨': 1805,
#  '치킨 순': 1729,
#  '순 살': 1188,
#  '살 치킨': 961,
#  '퓨전': 1949,
#  '치킨 퓨전': 1739,
#  '퓨전 치킨': 1950,
#  '치킨 호프': 1740,
#  '한식 갈비': 1976,
#  '갈비 갈비': 10,
#  '안창살': 1308,
#  '갈비탕': 34,
#  '갈비 살': 19,
#  ...}

# %%
# y 데이터 벡터화
y_vectorized = tfidf_vectorizer.transform(y)

# 벡터화된 희소행렬 확인 
# (916*2203 행렬, 916개 음식메뉴가 총 2203개의 형태소 벡터를 이용하여 벡터화되었음)
# (6335개 element가 있으므로, 한 행당 평균 7개 정도의 element가 있음)
y_vectorized
# Out:
# <916x2203 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6335 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### 3. cosine 유사도 모델 생성 : 데이터 내부
# - "y데이터 내부"에서 서로 비슷한 음식메뉴는 무엇인지 찾는 모델 생성
# - [linear_kernel](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.pairwise.linear_kernel.html) 이용

# %%
from sklearn.metrics.pairwise import linear_kernel

# y_vectorized 데이터를 이용해 linear_kernel 행렬 생성
cosine_sim = linear_kernel(y_vectorized, y_vectorized)

# %%
cosine_sim.shape
# Out:
# (916, 916)

# %%
def get_similar_indices(idx, cosine_sim=cosine_sim):
    """
        idx를 "y데이터 내부"에서 서로 비슷한 음식메뉴는 무엇인지 찾는 모델 생성
    """

    # 모든 음식메뉴에 대해서 해당 idx와의 유사도를 구한다. ((index, linear_kernel값)의 list 형태)
    sim_scores = list(enumerate(cosine_sim[idx])) 

    # 유사도에 따라 음식메뉴를 정렬한다. (key 파라미터는 정렬기준을 선택)
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # 유사도가 0 이상인 것만 sim_list에 저장한다.
    sim_list=[]
    for i in range(len(sim_scores)):
        if sim_scores[i][1] > 0:
            sim_list.append(sim_scores[i])
            
    # sim_list에서 유사도가 가장 높은 3개만 저장한다.
    sim_list = sim_list[:3]
            
    # sim_list의 인덱스를 저장한다.
    sim_indices = [i[0] for i in sim_list]

    # 5개의 음식메뉴를 list 타입으로 반환한다.
    return sim_indices

# %%
test_idxs = [10,40,60,80,100,130,150,180,200]
for idx in test_idxs:
    test_food = y_food[idx]
    sim_indices = get_similar_indices(idx)
    sim_food = [y_food[idx] for idx in sim_indices]
    print("'",test_food,"'",'가장 유사한 지역명 5개:', sim_food)
# Out:
# ' 기타 디저트 중국빵 ' 가장 유사한 지역명 5개: ['기타 디저트 중국빵', '기타 디저트 빵', '기타 디저트 꿀빵']
# ' 기타 호프 맥주/ 한치 ' 가장 유사한 지역명 5개: ['기타 호프 맥주/ 한치', '기타 호프 맥주', '기타 호프 맥주/ 치킨']
# ' 기타아시아식 인도 머턴커리 ' 가장 유사한 지역명 5개: ['기타아시아식 인도 머턴커리', '기타아시아식 인도 인도요리/ 치킨커리', '기타아시아식 인도 쌀국수']
# ' 서양식 멕시코 뷔페 ' 가장 유사한 지역명 5개: ['서양식 멕시코 뷔페', '서양식 멕시코 서양식', '서양식 멕시코 피자']
# ' 서양식 브런치 브런치바비큐플래터/ 스테이크샐러드 ' 가장 유사한 지역명 5개: ['서양식 브런치 브런치바비큐플래터/ 스테이크샐러드', '서양식 브런치 브런치', '서양식 브런치 샐러드']
# ' 서양식 브런치 퀘사디아 ' 가장 유사한 지역명 5개: ['서양식 브런치 퀘사디아', '서양식 멕시코 멕시코요리/ 타코/ 퀘사디아', '서양식 브런치 브런치']
# ' 서양식 스테이크 칵테일/ 와인/ 샐러드 ' 가장 유사한 지역명 5개: ['서양식 스테이크 칵테일/ 와인/ 샐러드', '서양식 스테이크 와인/ 칵테일', '서양식 스테이크 와인']
# ' 서양식 피자/ 파스타 고르곤졸라 ' 가장 유사한 지역명 5개: ['서양식 피자/ 파스타 고르곤졸라', '서양식 피자/ 파스타 피자/ 파스타', '서양식 피자/ 파스타 파스타']
# ' 서양식 피자/ 파스타 빠네 ' 가장 유사한 지역명 5개: ['서양식 피자/ 파스타 빠네', '서양식 피자/ 파스타 피자/ 파스타', '서양식 피자/ 파스타 파스타']

# %% [markdown]
# `locations_bio.csv` 파일 내부의 지역명에 대해서는 정확하게 유사한 지역명을 예측했다.

# %% [markdown]
# ### 4. cosine 유사도 모델 생성 : 데이터 외부
# - df_foods 데이터에 없던 음식메뉴가 입력되었을 때, df_foods 내에서 가장 비슷한 음식메뉴는 무엇인지 찾는 모델 생성
# - [cosine_similarity](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.pairwise.cosine_similarity.html) 이용
#
# #### 데이터에 없던 새로운 음식명을 테스트

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
def get_similar_food(new_food, tfidf_vectorizer, y_vectorized):
    """
        데이터에 없는 새로운 지역명 new_food을 입력 받고, 
        new_food과 가장 유사한 지역명 3개와 각각의 유사도를 데이터프레임 형태로 반환
    """
    
    # new_food 형태소 분석
    new_food_mecab = [text_prepare(new_food)]
    
    # new_food 벡터화
    new_food_vectorized = tfidf_vectorizer.transform(new_food_mecab)
    
    # 유사한 메뉴와 유사도를 저장
    sim_food = {}

    for i in range(y_vectorized.shape[0]):
        curr_sim = cosine_similarity(y_vectorized[i], new_food_vectorized)[0,0]
        if curr_sim > 0.2:
            sim_food[y_food[i]] = curr_sim

    sim_food = pd.DataFrame(data=sim_food.values()
                           ,index=sim_food.keys()
                           ,columns=['cs']).sort_values('cs',ascending=False)

    return sim_food[:3]

# %%
y_food
# Out:
# array(['기타 디저트 과일주스/ 수박주스', '기타 디저트 꿀빵', '기타 디저트 미용실', '기타 디저트 바게트',
#        '기타 디저트 반찬가게', '기타 디저트 보리빵', '기타 디저트 빵', '기타 디저트 아이스크림',
#        '기타 디저트 알수없음', '기타 디저트 유원지', '기타 디저트 중국빵', '기타 디저트 캠핌장',
#        '기타 디저트 테마파크', '기타 디저트 펜션', '기타 디저트 풀빌라', '기타 뷔페 고기', '기타 뷔페 국수',
#        '기타 뷔페 떡볶이', '기타 뷔페 바베큐', '기타 뷔페 뷔페', '기타 뷔페 샐러드', '기타 뷔페 소고기',
#        '기타 뷔페 숙박시설', '기타 뷔페 스테이크', '기타 뷔페 웨딩홀', '기타 뷔페 한식', '기타 뷔페 한식뷔페',
#        '기타 카페 술', '기타 카페 차', '기타 카페 카페', '기타 카페 커피', '기타 카페 케이크',
#        '기타 포장마차 주류', '기타 포장마차 포장마차', '기타 호프 골뱅이무침', '기타 호프 막걸리',
#        '기타 호프 막걸리/ 주류', '기타 호프 맥주', '기타 호프 맥주/ 주류', '기타 호프 맥주/ 치킨',
#        '기타 호프 맥주/ 한치', '기타 호프 맥주/주류', '기타 호프 소주', '기타 호프 술', '기타 호프 알수없음',
#        '기타 호프 정종/대포집/소주방', '기타 호프 주류', '기타 호프 주류/ 오뎅탕', '기타 호프 주점',
#        '기타 호프 치킨', '기타 호프 파전', '기타 호프 호프/통닭', '기타아시아식 베트남 샤브샤브',
#        '기타아시아식 베트남 쌀국수', '기타아시아식 베트남 쌀국수/ 반쎄오', '기타아시아식 베트남 쌀국수/ 분짜',
#        '기타아시아식 베트남 쌀국수/ 짜조', '기타아시아식 베트남 월남쌈/ 샤브샤브',
#        '기타아시아식 베트남 팟타이/ 쌀국수', '기타아시아식 인도 나시고랭/ 미고랭', '기타아시아식 인도 머턴커리',
#        '기타아시아식 인도 쌀국수', '기타아시아식 인도 인도/ 태국', '기타아시아식 인도 인도/태국',
#        '기타아시아식 인도 인도요리/ 치킨커리', '기타아시아식 인도 카레', '기타아시아식 인도 탄두리치킨',
#        '기타아시아식 인도 탄두리치킨/ 버터치킨카레', '기타아시아식 태국 구아카몰리샐러드',
#        '기타아시아식 태국 똠양꿍/ 팍붕', '기타아시아식 태국 태국요리', '기타아시아식 태국 태국요리/ 갈비국수/ 팟타이',
#        '기타아시아식 태국 태국요리전문', '기타아시아식 태국 팟타이/ 똠양꿍', '서양식 멕시코 감자튀김',
#        '서양식 멕시코 김치삼겹필라프', '서양식 멕시코 꽃등심', '서양식 멕시코 맥주',
#        '서양식 멕시코 멕시코요리/ 타코/ 퀘사디아', '서양식 멕시코 복합문화공간', '서양식 멕시코 뷔페',
#        '서양식 멕시코 비비큐', '서양식 멕시코 비스트로', '서양식 멕시코 서양식', '서양식 멕시코 알수없음',
#        '서양식 멕시코 주류', '서양식 멕시코 치킨', '서양식 멕시코 카레', '서양식 멕시코 커트',
#        '서양식 멕시코 타코', '서양식 멕시코 통닭', '서양식 멕시코 피자', '서양식 멕시코 해산물',
#        '서양식 브런치 까페', '서양식 브런치 녹차라떼', '서양식 브런치 도넛', '서양식 브런치 뚱샌드위치',
#        '서양식 브런치 라이브카페', '서양식 브런치 뷔페', '서양식 브런치 브런치',
#        '서양식 브런치 브런치바비큐플래터/ 스테이크샐러드', '서양식 브런치 새우샐러드/ 파니니', '서양식 브런치 샌드위치',
#        '서양식 브런치 샐러드', '서양식 브런치 샤케라또', '서양식 브런치 숙박시설', '서양식 브런치 아메리카노',
#        '서양식 브런치 아메리카노/ 단호박라떼', '서양식 브런치 아메리카노/ 라떼',
#        '서양식 브런치 아메리카노/ 에스프레소', '서양식 브런치 아메리카노/ 카페라떼', '서양식 브런치 아메리카노/ 쿠키',
#        '서양식 브런치 아메리카노/ 크림생맥주', '서양식 브런치 아인슈페너', '서양식 브런치 에메랄드라떼',
#        '서양식 브런치 장미맨숀라떼', '서양식 브런치 초코라떼', '서양식 브런치 커피',
#        '서양식 브런치 커피/ 과일청/ 꿀빵', '서양식 브런치 커피/ 더치커피/ 자몽주스', '서양식 브런치 커피/ 돈까스',
#        '서양식 브런치 커피/ 돌체라떼', '서양식 브런치 커피/ 브런치/ 토스트', '서양식 브런치 커피/ 샐러드/ 쿠키',
#        '서양식 브런치 커피/ 아메리카노/ 모히토', '서양식 브런치 커피/ 아메리카노/ 크로와상샌드위치',
#        '서양식 브런치 커피/ 에스프레소/ 당근케이크', '서양식 브런치 커피/ 에클레어', '서양식 브런치 커피/ 타르트',
#        '서양식 브런치 커피프라푸치노', '서양식 브런치 퀘사디아', '서양식 브런치 크림모카/ 인력커피',
#        '서양식 브런치 토스트', '서양식 브런치 파스타', '서양식 스테이크 나베돈까스', '서양식 스테이크 돈까스',
#        '서양식 스테이크 돈까스/ 초계국수', '서양식 스테이크 등심돈까스', '서양식 스테이크 등심스테이크',
#        '서양식 스테이크 로제파스타', '서양식 스테이크 바닷가재정식', '서양식 스테이크 살치살스테이크',
#        '서양식 스테이크 수제왕돈까스', '서양식 스테이크 스테이크', '서양식 스테이크 에그함박스테이크',
#        '서양식 스테이크 오븐스파게티', '서양식 스테이크 와인', '서양식 스테이크 와인/ 칵테일',
#        '서양식 스테이크 이탈리아코스요리', '서양식 스테이크 철판스테이크', '서양식 스테이크 칵테일/ 와인/ 샐러드',
#        '서양식 스테이크 커피/ 스테이크', '서양식 스테이크 큐브스테이크/ 와인', '서양식 스테이크 키조개리조또',
#        '서양식 스테이크 프랑스코스요리', '서양식 스테이크 하버순두부카레', '서양식 스테이크 함박스테이크',
#        '서양식 스테이크 해산물 스파게티', '서양식 스테이크 히레까스', '서양식 스페인 스페인요리/ 와인/ 홍합스튜',
#        '서양식 스페인 스페인코스요리/ 타파스', '서양식 스페인 알수없음', '서양식 터키 갈비', '서양식 터키 감바스',
#        '서양식 터키 뉴욕스트립스테이크', '서양식 터키 샐러드', '서양식 터키 스테이크', '서양식 터키 알수없음',
#        '서양식 터키 와플', '서양식 터키 우육면', '서양식 터키 케밥', '서양식 터키 퀘사디아/ 또띠아',
#        '서양식 터키 터키음식/ 케밥', '서양식 터키 터키음식/ 케밥/ 터키식치킨스테이크', '서양식 터키 파스타',
#        '서양식 터키 파스타,스테이크', '서양식 터키 한우채끝등심', '서양식 터키 항정상 덮밥/ 에바키라이스',
#        '서양식 피자/ 파스타 BBQ샐러드', '서양식 피자/ 파스타 갈레쉬림프스파게티', '서양식 피자/ 파스타 고르곤졸라',
#        '서양식 피자/ 파스타 관자로제파스타', '서양식 피자/ 파스타 까르보나라', '서양식 피자/ 파스타 꽁떼 로쏘',
#        '서양식 피자/ 파스타 나폴리피자', '서양식 피자/ 파스타 돈가스', '서양식 피자/ 파스타 로제파스타',
#        '서양식 피자/ 파스타 로제파스타/ 김치필라프', '서양식 피자/ 파스타 리조또', '서양식 피자/ 파스타 마르게리따',
#        '서양식 피자/ 파스타 마르게리따 피자', '서양식 피자/ 파스타 마르게리따화덕피자',
#        '서양식 피자/ 파스타 매운갈비파스타', '서양식 피자/ 파스타 명란젓크림스파게티',
#        '서양식 피자/ 파스타 명란크림파스타', '서양식 피자/ 파스타 명란파스타',
#        '서양식 피자/ 파스타 모짜렐라 알 프레스코', '서양식 피자/ 파스타 미트볼파스타/ 까르보나라스테이크',
#        '서양식 피자/ 파스타 버거/BBQ', '서양식 피자/ 파스타 버섯리조또', '서양식 피자/ 파스타 빠네',
#        '서양식 피자/ 파스타 새우로제 리조또/ 텔레토비 피자', '서양식 피자/ 파스타 새우크림파스타',
#        '서양식 피자/ 파스타 샐러드', '서양식 피자/ 파스타 샐러드/파스타', '서양식 피자/ 파스타 샷',
#        '서양식 피자/ 파스타 쉬림프', '서양식 피자/ 파스타 스테이크', '서양식 피자/ 파스타 스파게티',
#        '서양식 피자/ 파스타 시금치베이컨피자', '서양식 피자/ 파스타 앤쵸비오일파스타/ 안심스테이크',
#        '서양식 피자/ 파스타 와인/ 파스타/ 스테이크/ 브런치', '서양식 피자/ 파스타 이탈리아코스요리/ 샐러드/ 파스타',
#        '서양식 피자/ 파스타 이탈리안', '서양식 피자/ 파스타 치킨', '서양식 피자/ 파스타 칠리치킨스테이크',
#        '서양식 피자/ 파스타 커피/ 파스타', '서양식 피자/ 파스타 토마토칠리 새우 스파게티',
#        '서양식 피자/ 파스타 파니니/ 파스타', '서양식 피자/ 파스타 파스타', '서양식 피자/ 파스타 파스타/ 돈까스',
#        '서양식 피자/ 파스타 파스타/ 라따뚜이', '서양식 피자/ 파스타 파스타/ 리조또/ 샐러드',
#        '서양식 피자/ 파스타 파스타/ 물냉면', '서양식 피자/ 파스타 파스타/ 스테이크',
#        '서양식 피자/ 파스타 파스타/ 피자', '서양식 피자/ 파스타 파스타/ 피자/ 스테이크',
#        '서양식 피자/ 파스타 피자', '서양식 피자/ 파스타 피자/ 리조또/ 맥주',
#        '서양식 피자/ 파스타 피자/ 스테이크', '서양식 피자/ 파스타 피자/ 파스타',
#        '서양식 피자/ 파스타 피자/ 파스타/ 리조또', '서양식 피자/ 파스타 한우채끝등심스테이크',
#        '서양식 피자/ 파스타 함박스테이크/ 로제파스타', '서양식 피자/ 파스타 해물뚝배기파스타',
#        '서양식 피자/ 파스타 화덕피자/ 드래프트비어', '서양식 피자/ 파스타 화덕피자/ 수제파스타',
#        '서양식 햄버거 샐러드', '서양식 햄버거 수제버거', '서양식 햄버거 수제햄버거', '서양식 햄버거 치킨',
#        '서양식 햄버거 패스트푸드', '서양식 햄버거 핫도그', '서양식 햄버거 햄버거', '일식 덮밥 가라아게',
#        '일식 덮밥 도시락', '일식 덮밥 돈가츠덮밥', '일식 덮밥 민나노 오꼬노미야끼', '일식 덮밥 바지락찜',
#        '일식 덮밥 새우튀김', '일식 덮밥 야끼규동정식', '일식 덮밥 오꼬노미야끼', '일식 덮밥 오징어튀김',
#        '일식 덮밥 왕갈비', '일식 덮밥 우동', '일식 덮밥 이자카야/ 매콤크림새우', '일식 덮밥 주류',
#        '일식 덮밥 치즈돈카츠', '일식 덮밥 카레/ 오야코동', '일식 덮밥 토리가라아게/ 새우튀김/ 수제게살고로케',
#        '일식 덮밥 회', '일식 돈까스 가츠돈부리', '일식 돈까스 돈가스', '일식 돈까스 돈까스',
#        '일식 돈까스 돈부리', '일식 돈까스 돈카츠', '일식 돈까스 라멘/ 돈코츠/ 차슈동', '일식 돈까스 파스타',
#        '일식 돈까스 흑돈등심카츠', '일식 라멘 라멘', '일식 소바 덮밥', '일식 소바 메밀국수', '일식 소바 소바',
#        '일식 소바 알수없음', '일식 소바 우동', '일식 소바 탄탄면', '일식 일식 회 광어', '일식 일식 회 광어회',
#        '일식 일식 회 도미회', '일식 일식 회 랍스타찜', '일식 일식 회 로브스터/랍스터', '일식 일식 회 모듬회등',
#        '일식 일식 회 물회', '일식 일식 회 방어회', '일식 일식 회 벤댕이', '일식 일식 회 생선회',
#        '일식 일식 회 생선회/ 오징어회/ 세꼬시', '일식 일식 회 생선회/초밥', '일식 일식 회 세꼬시',
#        '일식 일식 회 세꼬시, 회', '일식 일식 회 송어', '일식 일식 회 송어회', '일식 일식 회 연어',
#        '일식 일식 회 연어사케동/ 혼마구로동', '일식 일식 회 우럭회', '일식 일식 회 참치',
#        '일식 일식 회 참치/ 참가자미', '일식 일식 회 초밥', '일식 일식 회 해물요리', '일식 일식 회 해물탕/ 회',
#        '일식 일식 회 해산물', '일식 일식 회 활어', '일식 일식 회 활어회', '일식 일식 회 활어회.매운탕',
#        '일식 일식 회 활어회/ 매운탕', '일식 일식 회 회', '일식 일식 회 회/ 전복회', '일식 일식 회 회무침',
#        '일식 일식 회 회정식', '일식 일식 회 회집', '일식 일식뷔페 뷔페', '일식 일식뷔페 초밥',
#        '일식 일식뷔페 해산물', '일식 초밥 초밥', '일식 초밥 초밥/ 생연어', '일식 초밥 초밥/ 스시',
#        '일식 초밥 회/사시미', '중국식 마라탕 마라탕', '중국식 마라탕 샤브샤브', '중국식 마라탕 유린기',
#        '중국식 양꼬치 양갈비/ 꿔바로우', '중국식 양꼬치 양꼬치', '중국식 양꼬치 짬뽕/탕수육',
#        '중국식 짜장면 짬뽕/탕수육', '중국식 짜장면/ 짬뽕 짜장', '중국식 짜장면/ 짬뽕 짜장. 짬뽕',
#        '중국식 짜장면/ 짬뽕 짜장면', '중국식 짜장면/ 짬뽕 짜장면/ 짬뽕', '중국식 짜장면/ 짬뽕 짜장면/탕수육',
#        '중국식 짜장면/ 짬뽕 짬뽕', '중국식 짜장면/ 짬뽕 짬뽕/탕수육', '중국식 짜장면/ 짬뽕 피자',
#        '중국식 탕수육 베이징덕/ 딤섬', '중국식 탕수육 알수없음', '중국식 탕수육 유린기', '중국식 탕수육 탕수육',
#        '중국식 탕수육 훠궈', '치킨 닭강정 닭강정', '치킨 닭강정 닭강정/ 치즈닭꼬치', '치킨 닭강정 불닭',
#        '치킨 닭강정 치킨/ 통닭', '치킨 치킨 마늘치킨', '치킨 치킨 정종/대포집/소주방',
#        '치킨 치킨 찜닭/치킨/똥집', '치킨 치킨 치밥', '치킨 치킨 치킨', '치킨 치킨 치킨/ 통닭',
#        '치킨 치킨 크리스피치킨/ 순살치킨', '치킨 치킨 퓨전치킨', '치킨 치킨 호프/통닭', '한식 갈비 갈비',
#        '한식 갈비 갈비살/안창살/살치살/왕갈비탕', '한식 갈비 갈비정식', '한식 갈비 곰탕', '한식 갈비 돼지갈비',
#        '한식 갈비 돼지구이', '한식 갈비 등갈비', '한식 갈비 등갈비 김치찜', '한식 갈비 매운갈비찜',
#        '한식 갈비 삼겹살', '한식 갈비 생갈비', '한식 갈비 소갈비', '한식 갈비 수제생갈비', '한식 갈비 양갈비',
#        '한식 갈비 양념갈비', '한식 갈비 양념돼지갈비', '한식 갈비 연탄갈비', '한식 갈비 왕갈비',
#        '한식 갈비 젓국갈비', '한식 갈비 참숯갈비', '한식 갈비 회일식', '한식 갈비탕 갈비탕',
#        '한식 갈비탕 돼지갈비', '한식 감자탕 감자탕', '한식 감자탕집 감자탕', '한식 감자탕집 감자탕집',
#        '한식 게 간장게장', '한식 게 게', '한식 게 게국지', '한식 게 게장', '한식 게 꽃게',
#        '한식 게 꽃게찜', '한식 게 꽃게탕', '한식 게 대게', '한식 게 떡갈비', '한식 게 매생이굴국밥',
#        '한식 게 민물장어/간장게장', '한식 게 한정식/꽃게장', '한식 게 홍게', '한식 경양식 경양식',
#        '한식 고기 갈매기살', '한식 고기 갈비', '한식 고기 고기', '한식 고기 돈까스', '한식 고기 돼지꼬리',
#        '한식 고기 등심', '한식 고기 떡갈비', '한식 고기 생삼겹살', '한식 고기 양념라비', '한식 고기 오돌뼈',
#        '한식 고기 오징어볶음', '한식 고기 월남쌈', '한식 고기 육회', '한식 고기 주먹고기', '한식 고기 파스타',
#        '한식 고기 한우등심/삼겹살/목삼겹살', '한식 고기구이 갈매기살', '한식 고기구이 고기구이',
#        '한식 고기구이 고기구이/ 샤브샤브', '한식 고기구이 껍데기',
#        '한식 고기구이 돼지고기구이/ 직화삼겹살/ 고등어김치찌개', '한식 고기구이 돼지껍데기', '한식 고기구이 매운닭발',
#        '한식 고기구이 바베큐', '한식 고기구이 생고기', '한식 고기구이 생고기/ 삼겹살', '한식 고기구이 생고기구이',
#        '한식 고기구이 석쇠구이', '한식 고기구이 소고기', '한식 고기구이 숯불구이', '한식 고기구이 오겹살',
#        '한식 고기구이 철판구이', '한식 고기구이 화로구이', '한식 골뱅이 골뱅이', '한식 곰탕 곰탕',
#        '한식 곱창 갈비', '한식 곱창 곱창', '한식 곱창 곱창/ 막창', '한식 곱창 곱창전골', '한식 곱창 돌곱창',
#        '한식 곱창 돼지곱창', '한식 곱창 막창', '한식 곱창 생고기/ 육회/ 곱창전골', '한식 곱창 소곱창',
#        '한식 곱창 양곱창', '한식 국밥 고기구이/ 국밥', '한식 국밥 국밥', '한식 국밥 국밥/ 감자탕',
#        '한식 국밥 국수/ 국밥', '한식 국밥 굴국밥', '한식 국밥 냉면', '한식 국밥 다슬기탕/ 국밥',
#        '한식 국밥 돼지국밥', '한식 국밥 드루와정식', '한식 국밥 뚝배기', '한식 국밥 메밀국수',
#        '한식 국밥 모듬수육', '한식 국밥 석쇠구이/국밥', '한식 국밥 소고기국밥', '한식 국밥 소머리국밥',
#        '한식 국밥 수구레국밥/소머리국밥', '한식 국밥 수육/ 국밥', '한식 국밥 수육국밥', '한식 국밥 순대국밥',
#        '한식 국밥 시래기국밥', '한식 국밥 암뽕국밥', '한식 국밥 장터국밥', '한식 국밥 전복뚝배기. 조림',
#        '한식 국밥 치킨', '한식 국밥 콩나물국밥', '한식 국밥 편육', '한식 국밥 한우국밥', '한식 국밥 해물뚝배기',
#        '한식 국수 검은콩국수', '한식 국수 검정콩국수', '한식 국수 고기국수. 비빔국수', '한식 국수 국수',
#        '한식 국수 국수/ 죽', '한식 국수 김치말이국수', '한식 국수 닭국수', '한식 국수 막국수',
#        '한식 국수 메밀국수', '한식 국수 메밀육개장칼국수', '한식 국수 메밀전', '한식 국수 면',
#        '한식 국수 멸치국수', '한식 국수 보말국. 보말칼국수', '한식 국수 비빔국수', '한식 국수 손칼국수',
#        '한식 국수 순대국밥', '한식 국수 알수없음', '한식 국수 완당', '한식 국수 잔치국수', '한식 국수 장터국수',
#        '한식 국수 칼국수', '한식 국수 칼국수/ 수육', '한식 국수 팔도면요리', '한식 국수 흑돼지구이. 동치미국수',
#        '한식 김치찌개 김치찌개', '한식 김치찌개 김치찜', '한식 김치찌개 된장찌개', '한식 김치찌개 묵은지',
#        '한식 김치찌개 묵은지감자탕', '한식 김치찌개 묵은지닭매운탕', '한식 김치찌개 버섯해물두부전골',
#        '한식 김치찌개 삼겹살', '한식 김치찌개 오징어볶음두부', '한식 김치찌개 청국장', '한식 낙지 낙지',
#        '한식 낙지 막국수', '한식 낙지 산낙지비빔밥', '한식 냉면 냉면', '한식 냉면 냉면집', '한식 냉면 밀냉면',
#        '한식 냉면 소갈비/ 냉면', '한식 냉면 회냉면', '한식 닭 닭', '한식 닭 닭곰탕', '한식 닭 닭꼬치',
#        '한식 닭 닭한마리', '한식 닭 모듬똥집', '한식 닭 불닭', '한식 닭 옛날통닭', '한식 닭갈비 닭갈비',
#        '한식 닭갈비 숯불닭갈비', '한식 닭갈비 치킨', '한식 닭갈비 회막국수', '한식 닭발 닭발',
#        '한식 닭볶음탕 닭개장', '한식 닭볶음탕 닭도리탕', '한식 닭볶음탕 닭볶음탕', '한식 닭볶음탕 닭토리탕',
#        '한식 닭볶음탕 닭토리탕/소머리국밥', '한식 닭볶음탕 솥뚜껑닭볶음탕', '한식 닭볶음탕 잣 백숙',
#        '한식 닭볶음탕 찜닭', '한식 도시락 도시락', '한식 돼지 돼지', '한식 돼지구이 돼지고기',
#        '한식 돼지구이 돼지고기/ 주꾸미/ 냉면', '한식 돼지구이 돼지고기정식', '한식 돼지구이 돼지구이',
#        '한식 돼지구이 생삼겹살', '한식 돼지구이 한우등심/ 돼지고기 등', '한식 돼지구이 흑돼지구이',
#        '한식 돼지구이 흑돼지구이. 갈비탕', '한식 돼지구이 흑돼지구이. 김치찌개', '한식 돼지구이 흑돼지구이. 해물찜',
#        '한식 두루치기 두루치기', '한식 두루치기 치즈돈가스', '한식 두부 두부', '한식 두부 두부김치',
#        '한식 두부 두부전골', '한식 두부 두부정식', '한식 두부 손두부', '한식 두부 잡어매운탕',
#        '한식 두부 잣두부전골', '한식 라면 라면', '한식 막창 곱창', '한식 막창 돈사각막창', '한식 막창 돼지막창',
#        '한식 막창 막창', '한식 막창 막창,곱창', '한식 막창 와규/ 막창', '한식 매운탕 닭볶음탕/닭토리탕',
#        '한식 매운탕 매운탕', '한식 매운탕 메기매운탕', '한식 매운탕 복매운탕', '한식 매운탕 오리주물럭',
#        '한식 매운탕 참복국/ 복매운탕', '한식 묵 도토리묵', '한식 묵 묵', '한식 물회 물회', '한식 밀면 밀면',
#        '한식 바베큐 바베큐', '한식 반찬 반찬', '한식 백반 가정식', '한식 백반 돌솥밥', '한식 백반 들깨수제비',
#        '한식 백반 백반', '한식 백반 삼겹살', '한식 버섯 버섯', '한식 버섯 버섯불고기', '한식 버섯 버섯요리',
#        '한식 버섯 버섯전골', '한식 버섯 울금떡갈비정식/ 버섯불고기정식', '한식 버섯 자연산버섯찌개',
#        '한식 보리밥 감자국', '한식 보리밥 곤드레밥', '한식 보리밥 대통밥', '한식 보리밥 더덕정식',
#        '한식 보리밥 돌솥밥', '한식 보리밥 마늘약선정식', '한식 보리밥 매운탕/회무침', '한식 보리밥 메밀',
#        '한식 보리밥 밴댕이무침', '한식 보리밥 보리밥', '한식 보리밥 비빔밥', '한식 보리밥 수수부꾸미',
#        '한식 보리밥 시골밥상', '한식 보리밥 약채밥상', '한식 보리밥 영양돌솥밥', '한식 보리밥 영양솥밥',
#        '한식 보리밥 육전', '한식 보리밥 전복순두부짬뽕', '한식 보리밥 청국장/두부전골', '한식 보리밥 현미채식',
#        '한식 보신탕 보신탕', '한식 보쌈 보쌈', '한식 보쌈 보쌈,족발', '한식 보쌈 순대국밥', '한식 복어 복어',
#        '한식 복어 복어요리', '한식 복어 복어요리/ 복매운탕', '한식 복어 아구찜', '한식 부대찌개 부대찌개',
#        '한식 부대찌개 부대찌게', '한식 부대찌개 치킨', '한식 분식 곡물치킨', '한식 분식 김밥',
#        '한식 분식 떡볶이', '한식 분식 마늘떡볶이', '한식 분식 만두', '한식 분식 만두/치킨', '한식 분식 모밀',
#        '한식 분식 밥버거', '한식 분식 분식', '한식 분식 아이스크림호떡', '한식 분식 어묵/ 오뎅',
#        '한식 분식 카페', '한식 분식 튀김', '한식 불고기 김치찌개', '한식 불고기 닭볶음탕',
#        '한식 불고기 닭불고기', '한식 불고기 대파불고기', '한식 불고기 돼지불고기', '한식 불고기 백숙',
#        '한식 불고기 불고기', '한식 불고기 불고기 산채정식', '한식 불고기 불고기/ 양대창구이',
#        '한식 불고기 불고기정식', '한식 불고기 불백', '한식 불고기 손수제비', '한식 불고기 쌈제육정식',
#        '한식 불고기 제육볶음', '한식 불고기 한우', '한식 불고기 한우구이/한우불고기',
#        '한식 불고기 한우불고기/ 꽃등심', '한식 불고기 한우불고기/한우등심', '한식 빈대떡 빈대떡',
#        '한식 삼겹살 갈매기살', '한식 삼겹살 갈비. 삼겹살/ 냉면', '한식 삼겹살 갈비살', '한식 삼겹살 닭백숙',
#        '한식 삼겹살 대패삼겹살', '한식 삼겹살 돼지갈비', '한식 삼겹살 등심', '한식 삼겹살 목살',
#        '한식 삼겹살 백숙', '한식 삼겹살 삼겹살', '한식 삼겹살 생삼겹', '한식 삼겹살 생삼겹살',
#        '한식 삼겹살 생선조림/생선구이', '한식 삼겹살 양념갈비', '한식 삼겹살 옛날삼겹살', '한식 삼겹살 오겹살',
#        '한식 삼겹살 오겹살/ 항정살', '한식 삼겹살 오리백숙', '한식 삼겹살 오리주물럭', '한식 삼겹살 장어주물럭',
#        '한식 삼겹살 주물럭', '한식 삼계탕 누룽지백숙', '한식 삼계탕 능이백숙코스', '한식 삼계탕 닭백숙',
#        '한식 삼계탕 닭볶음탕', '한식 삼계탕 닭볶음탕/닭토리탕', '한식 삼계탕 백숙', '한식 삼계탕 삼계탕',
#        '한식 삼계탕 삼계탕/백숙', '한식 삼계탕 오골계탕', '한식 삼계탕 오리구이/오리탕', '한식 삼계탕 오리백숙',
#        '한식 삼계탕 오리주물럭', '한식 삼계탕 오리훈제', '한식 삼계탕 인삼정식+삼계탕', '한식 삼계탕 한방백숙',
#        '한식 생선 갈치', '한식 생선 갈치요리', '한식 생선 갈치조림', '한식 생선 갈치조림. 고등어조림',
#        '한식 생선 고등어조림', '한식 생선 과메기', '한식 생선 굴', '한식 생선 굴구이', '한식 생선 굴국밥',
#        '한식 생선 굴비구이', '한식 생선 굴비정식', '한식 생선 굴요리전문', '한식 생선 김치찌개/된장찌개',
#        '한식 생선 꼬막', '한식 생선 꼬막무침', '한식 생선 꼬막무침/ 통소라', '한식 생선 꼬막비빔밥/ 한우타다끼',
#        '한식 생선 닭볶음탕', '한식 생선 닭토리탕', '한식 생선 대구', '한식 생선 대구막창',
#        '한식 생선 대구머리찜', '한식 생선 대구뽈찜/ 뽈구이', '한식 생선 대구지리탕', '한식 생선 대구찜',
#        '한식 생선 대구탕', '한식 생선 대방어회. 갈치조림', '한식 생선 더덕제육쌈밥', '한식 생선 동태',
#        '한식 생선 동태찜', '한식 생선 동태탕', '한식 생선 막걸리/ 소고기전골', '한식 생선 매운탕',
#        '한식 생선 메기탕', '한식 생선 명태', '한식 생선 명태조림', '한식 생선 물곰탕', '한식 생선 바닷가재',
#        '한식 생선 복요리.시래기갈치고등어조림', '한식 생선 북어', '한식 생선 붕어찜', '한식 생선 삼겹살',
#        '한식 생선 삼합', '한식 생선 생선구이', '한식 생선 생선조림', '한식 생선 생선찜', '한식 생선 생태탕',
#        '한식 생선 순두부찌개', '한식 생선 쌈정식/ 코다리정식/ 약채정식', '한식 생선 아구찜', '한식 생선 아나고탕',
#        '한식 생선 오징어', '한식 생선 오징어 보쌈', '한식 생선 육사시미', '한식 생선 육회비빔밥',
#        '한식 생선 전골', '한식 생선 전복', '한식 생선 제육볶음', '한식 생선 코다리', '한식 생선 코다리찜',
#        '한식 생선 콩비지찌개/돼지두루치기', '한식 생선 킹크랩', '한식 생선 해물', '한식 생선 해물요리',
#        '한식 생선 해물전골', '한식 생선 해물찜', '한식 생선 해물탕', '한식 생선 해산물찜', '한식 생선 황태',
#        '한식 생선 황태구이', '한식 생선 황태구이백반', '한식 샤브샤브 복죽', '한식 샤브샤브 샤브샤브',
#        '한식 샤브샤브 샤브샤브/월남쌈', '한식 샤브샤브 하모 사시미', '한식 설렁탕 곰치국',
#        '한식 설렁탕 곰탕/ 사골', '한식 설렁탕 곰탕/설렁탕', '한식 설렁탕 꼬리곰탕', '한식 설렁탕 내장탕',
#        '한식 설렁탕 닭볶음탕', '한식 설렁탕 도가니탕', '한식 설렁탕 동태탕', '한식 설렁탕 매운탕',
#        '한식 설렁탕 복탕', '한식 설렁탕 사골옹심이', '한식 설렁탕 사철탕', '한식 설렁탕 설렁탕',
#        '한식 설렁탕 쏘가리탕', '한식 설렁탕 오리/백숙', '한식 설렁탕 평양냉면/소고기온면', '한식 소고기 갈비',
#        '한식 소고기 김치찌개', '한식 소고기 두루치기정식/육회비빔밥', '한식 소고기 소고기', '한식 소고기 육회',
#        '한식 소고기 육회비빔밥', '한식 소고기 차돌박이', '한식 소고기 평양냉면', '한식 소고기 한우 한돈',
#        '한식 소고기 한우/ 소고기', '한식 소고기 한우고기', '한식 소고기 한우생갈비',
#        '한식 소고기 한정식/ 한우육개장', '한식 소금구이 소금구이', '한식 수제비 도토리묵', '한식 수제비 들깨수제비',
#        '한식 수제비 수제비', '한식 순대/순대국 순대/순대국', '한식 순대/순대국 순대국', '한식 순두부 순두부',
#        '한식 순두부 순두부찌개', '한식 순두부 짬뽕순두부', '한식 숯불구이 고기', '한식 숯불구이 숯불갈비',
#        '한식 숯불구이 숯불고기', '한식 숯불구이 숯불구기', '한식 숯불구이 숯불구이', '한식 숯불구이 육회비빔밥',
#        '한식 쌈밥 멸치회/ 쌈밥정식', '한식 쌈밥 삼겹살', '한식 쌈밥 쌈밥', '한식 쌈밥 우렁쌈밥정식',
#        '한식 쌈밥 우렁이쌈밥', '한식 쌈밥 채식요리/ 불구이쌈밥', '한식 아구찜 아구수육', '한식 아구찜 아구찜',
#        '한식 아구찜 코다리찜', '한식 야식집 감자전', '한식 야식집 꼬치', '한식 야식집 두부김치',
#        '한식 야식집 맥주', '한식 야식집 민속주점', '한식 야식집 뷔페', '한식 야식집 샷', '한식 야식집 알수없음',
#        '한식 야식집 야식', '한식 야식집 야식집', '한식 야식집 전통찻집', '한식 야식집 주점', '한식 야식집 튀김',
#        '한식 야식집 파전', '한식 야식집 포장마차', '한식 야식집 호떡', '한식 염소탕 염소탕',
#        '한식 염소탕 흑염소전골', '한식 오리 오리', '한식 오리 오리구이', '한식 옻닭 백숙', '한식 옻닭 옻닭',
#        '한식 육개장 영양탕', '한식 육개장 육개장', '한식 장어 옻장어구이', '한식 장어 우렁쌈밥',
#        '한식 장어 장어', '한식 장어 장어구이', '한식 장어 장어요리', '한식 장어 장어탕/ 된장찌개',
#        '한식 전 꼬막무침/육전', '한식 전 백숙', '한식 전 전', '한식 전 파전', '한식 전 해물파전',
#        '한식 조개 조개', '한식 조개 조개구이', '한식 조개 조개및삼겹살구이', '한식 조개 조개찜',
#        '한식 족발/보쌈 보쌈', '한식 족발/보쌈 족발', '한식 족발/보쌈 족발/보쌈',
#        '한식 족발/보쌈 족발/보쌈/치킨', '한식 죽 전복영양죽', '한식 죽 죽', '한식 죽 팥죽', '한식 죽 호박죽',
#        '한식 쭈꾸미 돼지국밥', '한식 쭈꾸미 쭈꾸미', '한식 찌개 곱창전골', '한식 찌개 김치찌개',
#        '한식 찌개 꼬막비빔밥', '한식 찌개 도루묵/가자미찌개', '한식 찌개 두루치기', '한식 찌개 생선찌개',
#        '한식 찌개 오리백숙/닭볶음탕/된장정식', '한식 찌개 정식코스', '한식 찌개 짜글이찌개', '한식 찌개 찌개',
#        '한식 찜 갈비찜', '한식 찜 남도요리', '한식 찜 다슬기', '한식 찜 물곰탕', '한식 찜 생성구이',
#        '한식 찜 자라용봉탕', '한식 찜 전골류', '한식 찜 찜', '한식 찜닭 찜닭', '한식 청국장 삼겹살',
#        '한식 청국장 생삼겹살', '한식 청국장 제육볶음', '한식 청국장 청국장', '한식 추어탕 부대찌개',
#        '한식 추어탕 비빔밥/고디탕/', '한식 추어탕 추어탕', '한식 한정식 곰탕', '한식 한정식 산채돌솥비빔밥',
#        '한식 한정식 우족탕', '한식 한정식 한정식', '한식 한정식 해산물한정식', '한식 해물 매생이국',
#        '한식 해물 모듬전/꼬막무침', '한식 해물 미역국', '한식 해물 민어탕', '한식 해물 바지락죽',
#        '한식 해물 볼테기탕', '한식 해물 불낙전골', '한식 해물 뽈때기찜', '한식 해물 뽈살', '한식 해물 새우구이',
#        '한식 해물 아구찜', '한식 해물 연어덮밥/ 스테이크덮밥', '한식 해물 올갱이', '한식 해물 옹심이',
#        '한식 해물 장어탕/전복탕/장어구이', '한식 해물 전복', '한식 해물 전복죽', '한식 해물 전복코스요리',
#        '한식 해장국 다슬기해장국', '한식 해장국 뼈다귀', '한식 해장국 뼈다귀감자탕', '한식 해장국 뼈해장국',
#        '한식 해장국 선지국', '한식 해장국 올갱이해장국', '한식 해장국 한식', '한식 해장국 해장국',
#        '한식 홍어 홍어', '한식 회 라면', '한식 회 모듬회', '한식 회 생선회', '한식 회 회', '한식 회 회집'],
#       dtype=object)

# %%
type(y_food), y_food.shape
# Out:
# (numpy.ndarray, (916,))

# %%
y_vectorized
# Out:
# <916x2203 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6335 stored elements in Compressed Sparse Row format>

# %%
test_foods = [
    '한식','중식','중국식','서양식','일식','일본식','태국요리','태국음식','베트남','쌀국수'
    ,'설렁탕','곰탕','갈비탕','갈비찜','멕시칸','멕시코','닭볶음','오징어','순대','순대국밥'
    ,'퓨전','철판구이','꿀떡','호빵','생선구이','국밥','고등어조림','갈치조림','고등어구이'
    ,'타코','파스타','피자','짜장면','탕수육','마라탕','오메기떡','회','방어회','스시','사시미'
    ,'복어','흑돼지','소갈비'
]

print('가장 유사한 메뉴 3가지')
for food in test_foods:
    print(food,'\t:',get_similar_food(food,tfidf_vectorizer,y_vectorized).index.tolist())
    print('\tscore:',get_similar_food(food,tfidf_vectorizer,y_vectorized)['cs'].tolist())
# Out:
# 가장 유사한 메뉴 3가지
# 한식 	: ['한식 게 게', '한식 해장국 한식']
# 	score: [1.0, 0.2666188853273465]
# 중식 	: []
# 	score: []
# 중국식 	: ['중국식 탕수육 유린기', '중국식 탕수육 훠궈', '중국식 짜장면/ 짬뽕 피자']
# 	score: [0.3505920216161386, 0.3454059532897735, 0.33259184881901305]
# 서양식 	: ['서양식 멕시코 서양식', '서양식 브런치 커피', '서양식 브런치 아메리카노']
# 	score: [0.4772297134005853, 0.28010968089652644, 0.26304788783384425]
# 일식 	: ['일식 일식 회 생선회', '일식 일식 회 활어', '일식 일식 회 초밥']
# 	score: [0.5268033545106742, 0.5268033545106742, 0.5173082891882225]
# 일본식 	: []
# 	score: []
# 태국요리 	: ['기타아시아식 태국 태국요리', '기타아시아식 태국 태국요리전문', '기타아시아식 태국 태국요리/ 갈비국수/ 팟타이']
# 	score: [0.6798904932847614, 0.6087103550130296, 0.5317343500512843]
# 태국음식 	: ['기타아시아식 태국 태국요리', '기타아시아식 태국 태국요리전문', '기타아시아식 태국 태국요리/ 갈비국수/ 팟타이']
# 	score: [0.3777007210223718, 0.33815789785710526, 0.29539528702104556]
# 베트남 	: ['기타아시아식 베트남 쌀국수', '기타아시아식 베트남 샤브샤브', '기타아시아식 베트남 팟타이/ 쌀국수']
# 	score: [0.3718980755293194, 0.3648241407457343, 0.31011366241138383]
# 쌀국수 	: ['기타아시아식 베트남 쌀국수', '기타아시아식 인도 쌀국수', '기타아시아식 베트남 팟타이/ 쌀국수']
# 	score: [0.3805471450746843, 0.3749283640065204, 0.31732583910615786]
# 설렁탕 	: ['한식 설렁탕 설렁탕', '한식 설렁탕 곰탕/설렁탕', '한식 설렁탕 닭볶음탕']
# 	score: [0.7490110365037627, 0.6240426480617578, 0.44046630809086396]
# 곰탕 	: ['한식 곰탕 곰탕', '한식 갈비 곰탕', '한식 한정식 곰탕']
# 	score: [0.7480327388437268, 0.50994215999794, 0.4841798896644811]
# 갈비탕 	: ['한식 갈비탕 갈비탕', '한식 갈비탕 돼지갈비', '한식 돼지구이 흑돼지구이. 갈비탕']
# 	score: [0.7817885761533955, 0.46908703838391247, 0.2628575242869589]
# 갈비찜 	: ['한식 찜 갈비찜', '한식 갈비 매운갈비찜']
# 	score: [0.5505174774979894, 0.4421020529005357]
# 멕시칸 	: []
# 	score: []
# 멕시코 	: ['서양식 멕시코 피자', '서양식 멕시코 치킨', '서양식 멕시코 서양식']
# 	score: [0.443833630287951, 0.4331719840127818, 0.42971834745031906]
# 닭볶음 	: ['한식 닭 닭', '한식 고기 오징어볶음', '한식 닭 닭한마리']
# 	score: [0.4323492888014704, 0.36229476912330627, 0.34405547865068575]
# 오징어 	: ['한식 생선 오징어', '한식 생선 오징어 보쌈', '한식 고기 오징어볶음']
# 	score: [0.5681875499576481, 0.42695523872205593, 0.391170157533357]
# 순대 	: ['한식 국수 순대국밥', '한식 보쌈 순대국밥', '한식 국밥 순대국밥']
# 	score: [0.43732763952014536, 0.4039778756502041, 0.40065574918824626]
# 순대국밥 	: ['한식 국밥 순대국밥', '한식 국수 순대국밥', '한식 보쌈 순대국밥']
# 	score: [0.781717241745089, 0.713370572359213, 0.6589703058541074]
# 퓨전 	: ['치킨 치킨 퓨전치킨']
# 	score: [0.37635769514906064]
# 철판구이 	: ['한식 고기구이 철판구이']
# 	score: [0.5783596477963765]
# 꿀떡 	: []
# 	score: []
# 호빵 	: []
# 	score: []
# 생선구이 	: ['한식 생선 생선구이', '한식 삼겹살 생선조림/생선구이', '한식 생선 굴구이']
# 	score: [0.7782511845125886, 0.5563642284745486, 0.29561538951187244]
# 국밥 	: ['한식 국밥 국밥', '한식 국밥 수구레국밥/소머리국밥', '한식 국밥 국수/ 국밥']
# 	score: [0.7282058597565468, 0.6006720093813006, 0.5885544221038184]
# 고등어조림 	: ['한식 생선 고등어조림', '한식 생선 갈치조림. 고등어조림', '한식 생선 복요리.시래기갈치고등어조림']
# 	score: [0.5888268791841308, 0.44830840831252494, 0.3180817288868555]
# 갈치조림 	: ['한식 생선 갈치조림', '한식 생선 갈치조림. 고등어조림', '한식 생선 대방어회. 갈치조림']
# 	score: [0.6031796464994863, 0.44830840831252494, 0.37026723566717035]
# 고등어구이 	: []
# 	score: []
# 타코 	: ['서양식 멕시코 타코', '서양식 멕시코 멕시코요리/ 타코/ 퀘사디아']
# 	score: [0.5493516861229342, 0.27165903285351467]
# 파스타 	: ['서양식 피자/ 파스타 파스타', '서양식 피자/ 파스타 파스타/ 스테이크', '서양식 피자/ 파스타 파스타/ 피자']
# 	score: [0.629820573531163, 0.5296343236749511, 0.5049492142172396]
# 피자 	: ['서양식 피자/ 파스타 피자', '서양식 피자/ 파스타 피자/ 스테이크', '서양식 피자/ 파스타 파스타/ 피자']
# 	score: [0.6342277072087997, 0.5258788796983356, 0.5136425960331461]
# 짜장면 	: ['중국식 짜장면/ 짬뽕 짜장면', '중국식 짜장면/ 짬뽕 짜장면/탕수육', '중국식 짜장면/ 짬뽕 짜장면/ 짬뽕']
# 	score: [0.6660745606278805, 0.5850968022136478, 0.5209758399540084]
# 탕수육 	: ['중국식 탕수육 탕수육', '중국식 탕수육 유린기', '중국식 탕수육 훠궈']
# 	score: [0.7249410078088621, 0.405048775075069, 0.39905716518797996]
# 마라탕 	: ['중국식 마라탕 마라탕', '중국식 마라탕 샤브샤브', '중국식 마라탕 유린기']
# 	score: [0.8841259798139038, 0.642245005355859, 0.625476338954122]
# 오메기떡 	: []
# 	score: []
# 회 	: ['한식 회 회', '일식 일식 회 회/ 전복회', '일식 일식 회 회']
# 	score: [0.6727407968479098, 0.5975253691237334, 0.583104524374782]
# 방어회 	: ['일식 일식 회 방어회', '한식 생선 대방어회. 갈치조림']
# 	score: [0.4788164566211669, 0.38682082376336124]
# 스시 	: ['일식 초밥 초밥/ 스시']
# 	score: [0.5779799520049735]
# 사시미 	: ['한식 생선 육사시미', '일식 초밥 회/사시미', '한식 샤브샤브 하모 사시미']
# 	score: [0.43841736677497295, 0.41289253036573687, 0.39437667192199277]
# 복어 	: ['한식 복어 복어', '한식 복어 복어요리', '한식 복어 복어요리/ 복매운탕']
# 	score: [0.80781262486583, 0.7129260045351468, 0.5788619180723068]
# 흑돼지 	: ['한식 돼지구이 흑돼지구이', '한식 돼지 돼지']
# 	score: [0.5837144258743551, 0.36431306222477]
# 소갈비 	: ['한식 갈비 소갈비', '한식 냉면 소갈비/ 냉면']
# 	score: [0.5701939317070396, 0.38067478348632644]

# %% [markdown]
# **pickle 저장**

# %%
import pickle

with open('./cosine_food_tfidf_vectorizer.pickle', "wb") as f:
    pickle.dump(tfidf_vectorizer, f, pickle.HIGHEST_PROTOCOL)
with open('./cosine_food_y_food.pickle', "wb") as f:
    pickle.dump(y_food, f, pickle.HIGHEST_PROTOCOL)
with open('./cosine_food_y_vectorized.pickle', "wb") as f:
    pickle.dump(y_vectorized, f, pickle.HIGHEST_PROTOCOL)
with open('./csine_food_cosine_sim.pickle', "wb") as f:
    pickle.dump(cosine_sim, f, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# **클래스 정리**
