# %% [markdown]
# ## 가게명 코사인 유사도
#
# **목표**<br>
# 챗봇에서 가게명을 입력 받을 때 데이터셋에 있는 가게명과 정확하게 일치하지 않아도 코사인 유사도 모델을 통해 비슷한 가게명을 선택할 수 있다.
#
# - 가게리스트 데이터의 storename 컬럼을 이용해 가게명 데이터셋을 만든다.
# - 위 데이터셋을 이용해 각 가게명별 코사인 유사도를 나타내는 모델을 만든다.

# %% [markdown]
# #### 코사인 유사도 설명 참고자료
# - https://wikidocs.net/24603

# %%
import pandas as pd
import numpy as np
import re
from konlpy.tag import Mecab

# %% [markdown]
# ### 1. 음식메뉴 데이터 불러오기

# %%
# 가게리스트 데이터 불러오기
df_restaurants = pd.read_csv('./가게리스트 통합(전국음식점+골목식당).csv',encoding='utf-8',index_col=0)
df_restaurants.head(2)
# Out:
#    storeid   Title Storename Region Sigungu Category1 Category2  \
# 0    13992  빛고을떡갈비    빛고을떡갈비     광주     광산구        한식      숯불구이
# 1    13995   착한소장수     착한소장수     광주      동구        한식        갈비
#
#                Menu  Reviews_num                  addr
# 0             육회비빔밥            2  광주광역시 광산구 송정동 831-21
# 1  갈비살/안창살/살치살/왕갈비탕            7                   NaN

# %%
# 가게리스트 데이터 불러오기
df_restaurants = pd.read_csv('./questions/가게리스트_카테고리_최종.csv',encoding='utf-8',index_col=0)
df_restaurants.head(2)
# Out:
#    storeid   Title storename Region Sigungu search_area Category1 Category2  \
# 0    13992  빛고을떡갈비    빛고을떡갈비     광주     광산구          광산        한식      숯불구이
# 1    13995   착한소장수     착한소장수     광주      동구          광주        한식        갈비
#
#                menu  Blog  reviews_num
# 0             육회비빔밥    24            2
# 1  갈비살/안창살/살치살/왕갈비탕  4155            7

# %%
# storename 컬럼 저장
df_storenames = df_restaurants['Storename'].to_frame()
df_storenames.shape
# Out:
# (22849, 1)

# %%
df_storenames.head(10)
# Out:
#   Storename
# 0    빛고을떡갈비
# 1     착한소장수
# 2     고흥나루터
# 3    고흥장어나라
# 4        관가
# 5        미연
# 6       백운산
# 7      원조장수
# 8    제일중화요리
# 9      청해복집

# %% [markdown]
# ### 2. `TfidfVectorizer`를 이용하여 벡터화

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# 공백 제거하는 함수
def text_prepare(text):
    return text.replace(' ','')

# %%
df_storenames['storename_prep'] = df_storenames['Storename'].apply(text_prepare)
df_storenames.head(5)
# Out:
#   Storename storename_prep
# 0    빛고을떡갈비         빛고을떡갈비
# 1     착한소장수          착한소장수
# 2     고흥나루터          고흥나루터
# 3    고흥장어나라         고흥장어나라
# 4        관가             관가

# %% [markdown]
# 가게명 중에서 가장 긴 음절을 가진 가게명을 찾는다.

# %%
storename_len = df_storenames.storename_prep.apply(lambda x: len(x)).sort_values(ascending=False)
storename_len
# Out:
# 9731     30
# 2025     30
# 16452    28
# 4087     26
# 9169     25
#          ..
# 6865      1
# 7496      1
# 7167      1
# 7492      1
# 12945     1
# Name: storename_prep, Length: 22849, dtype: int64

# %%
# 테스트를 위해 긴 음절 상위 20개, 짧은 음절 하위 20개를 저장한다.
long_storenames = storename_len[:20]
short_storenames = storename_len[-20:]

# %%
storename_len.describe()
# Out:
# count    22782.000000
# mean         4.878501
# std          2.191600
# min          1.000000
# 25%          4.000000
# 50%          5.000000
# 75%          6.000000
# max         30.000000
# Name: storename_prep, dtype: float64

# %%
# 가장 긴 음절은 30음절
df_storenames.iloc[2025].storename
# Out:
# '고기듬뿍대왕비빔밥&커피몬스터(COFFEEMONSTER)'

# %% [markdown]
# 가게명 음절 개수의 평균값은 5이므로, ngram_range를 5로 선택한다.
#
# ngram_range를 1

# %%
# TF-IDF vectorizer 생성
tfidf_vectorizer = TfidfVectorizer(ngram_range=(1,4) # 1음절~3음절까지 검색
                                   ,analyzer='char')  # 음절 단위 분석

# 벡터화할 데이터를 저장
y = df_storenames.storename_prep.values

# 벡터화된 데이터의 지역명을 저장
y_storename = df_storenames.Storename.values

# vectorizer를 y 데이터로 fitting
tfidf_vectorizer.fit(y)

# fitting 된 vectorizer 확인
tfidf_vectorizer
# Out:
# TfidfVectorizer(analyzer='char', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=1.0, max_features=None,
#                 min_df=1, ngram_range=(1, 4), norm='l2', preprocessor=None,
#                 smooth_idf=True, stop_words=None, strip_accents=None,
#                 sublinear_tf=False, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, use_idf=True, vocabulary=None)

# %%
# tfidf에 사용된 형태소 단어 확인 : 22,782개 가게명을 나타내기 위해 총 127,914 음절이 사용되었음
tfidf_vocabs = tfidf_vectorizer.vocabulary_
len(tfidf_vocabs)
# Out:
# 103407

# %%
# 음절 미리보기
tfidf_vocabs
# Out:
# {'빛': 49232,
#  '고': 8033,
#  '을': 73534,
#  '떡': 28385,
#  '갈': 5737,
#  '비': 48461,
#  '빛고': 49233,
#  '고을': 8668,
#  '을떡': 73601,
#  '떡갈': 28391,
#  '갈비': 5794,
#  '빛고을': 49234,
#  '고을떡': 8675,
#  '을떡갈': 73602,
#  '떡갈비': 28392,
#  '빛고을떡': 49236,
#  '고을떡갈': 8676,
#  '을떡갈비': 73603,
#  '착': 85592,
#  '한': 98126,
#  '소': 55084,
#  '장': 78134,
#  '수': 56806,
#  '착한': 85595,
#  '한소': 98697,
#  '소장': 55545,
#  '장수': 78606,
#  '착한소': 85659,
#  '한소장': 98703,
#  '소장수': 55546,
#  '착한소장': 85661,
#  '한소장수': 98704,
#  '흥': 103153,
#  '나': 15538,
#  '루': 31855,
#  '터': 92357,
#  '고흥': 9026,
#  '흥나': 103178,
#  '나루': 15758,
#  '루터': 32039,
#  '고흥나': 9027,
#  '흥나루': 103179,
#  '나루터': 15766,
#  '고흥나루': 9028,
#  '흥나루터': 103180,
#  '어': 65185,
#  '라': 28933,
#  '흥장': 103257,
#  '장어': 78776,
#  '어나': 65272,
#  '나라': 15699,
#  '고흥장': 9039,
#  '흥장어': 103258,
#  '장어나': 78786,
#  '어나라': 65275,
#  '고흥장어': 9040,
#  '흥장어나': 103259,
#  '장어나라': 78787,
#  '관': 10174,
#  '가': 4365,
#  '관가': 10175,
#  '미': 40445,
#  '연': 66768,
#  '미연': 41235,
#  '백': 44013,
#  '운': 70632,
#  '산': 50300,
#  '백운': 44187,
#  '운산': 70746,
#  '백운산': 44190,
#  '원': 71269,
#  '조': 81177,
#  '원조': 71716,
#  '조장': 81529,
#  '원조장': 71869,
#  '조장수': 81532,
#  '원조장수': 71871,
#  '제': 80648,
#  '일': 76175,
#  '중': 82955,
#  '화': 102261,
#  '요': 69992,
#  '리': 32590,
#  '제일': 80938,
#  '일중': 76677,
#  '중화': 83137,
#  '화요': 102631,
#  '요리': 70003,
#  '제일중': 80988,
#  '일중화': 76678,
#  '중화요': 83145,
#  '화요리': 102632,
#  '제일중화': 80989,
#  '일중화요': 76679,
#  '중화요리': 83146,
#  '청': 86819,
#  '해': 99742,
#  '복': 45733,
#  '집': 84569,
#  '청해': 87437,
#  '해복': 100090,
#  '복집': 45980,
#  '청해복': 87438,
#  '해복집': 100093,
#  '청해복집': 87439,
#  '콩': 90068,
#  '콩나': 90086,
#  '콩나루': 90087,
#  '심': 61536,
#  '순': 57875,
#  '두': 26720,
#  '부': 46819,
#  '화심': 102606,
#  '심순': 61566,
#  '순두': 57953,
#  '두부': 26934,
#  '화심순': 102607,
#  '심순두': 61569,
#  '순두부': 57954,
#  '화심순두': 102608,
#  '심순두부': 61570,
#  '림': 33905,
#  '든': 27666,
#  '정': 80092,
#  '금': 12782,
#  '자': 77236,
#  '할': 99309,
#  '매': 36483,
#  '청림': 87022,
#  '림가': 33915,
#  '가든': 4718,
#  '든정': 27710,
#  '정금': 80149,
#  '금자': 13095,
#  '자할': 77907,
#  '할매': 99327,
#  '매집': 36756,
#  '청림가': 87023,
#  '림가든': 33916,
#  '가든정': 4738,
#  '든정금': 27711,
#  '정금자': 80150,
#  '금자할': 13102,
#  '자할매': 77908,
#  '할매집': 99387,
#  '청림가든': 87024,
#  '림가든정': 33917,
#  '가든정금': 4739,
#  '든정금자': 27712,
#  '정금자할': 80151,
#  '금자할매': 13103,
#  '자할매집': 77909,
#  '스': 58512,
#  '트': 93707,
#  '링': 34123,
#  '스트': 59412,
#  '트링': 93826,
#  '스트링': 59443,
#  '위': 72434,
#  '추': 87984,
#  '억': 65786,
#  '의': 73844,
#  '막': 35305,
#  '걸': 7239,
#  '추억': 88056,
#  '억의': 65801,
#  '의막': 73932,
#  '막걸': 35306,
#  '걸리': 7248,
#  '추억의': 88059,
#  '억의막': 65804,
#  '의막걸': 73933,
#  '막걸리': 35307,
#  '추억의막': 88061,
#  '억의막걸': 65805,
#  '의막걸리': 73934,
#  '랑': 29961,
#  '너': 17663,
#  '식': 60417,
#  '당': 21995,
#  '너랑': 17675,
#  '랑나': 30017,
#  '나랑': 15730,
#  '랑식': 30206,
#  '식당': 60464,
#  '너랑나': 17676,
#  '랑나랑': 30018,
#  '나랑식': 15737,
#  '랑식당': 30207,
#  '너랑나랑': 17677,
#  '랑나랑식': 30020,
#  '나랑식당': 15738,
#  '코': 89805,
#  '베': 44628,
#  '르': 32182,
#  '코코': 89957,
#  '코베': 89894,
#  '베르': 44663,
#  '르나': 32197,
#  '코코베': 89962,
#  '코베르': 89895,
#  '베르나': 44664,
#  '코코베르': 89963,
#  '코베르나': 89896,
#  '숯': 58225,
#  '불': 47754,
#  '에': 66170,
#  '구': 10773,
#  '닭': 21477,
#  '발': 42800,
#  '숯불': 58251,
#  '불에': 47989,
#  '에구': 66192,
#  '구운': 11107,
#  '운닭': 70664,
#  '닭발': 21598,
#  '숯불에': 58297,
#  '불에구': 47990,
#  '에구운': 66193,
#  '구운닭': 11108,
#  '운닭발': 70667,
#  '숯불에구': 58298,
#  '불에구운': 47991,
#  '에구운닭': 66194,
#  '구운닭발': 11109,
#  '서': 52701,
#  '천': 86302,
#  '꽃': 14988,
#  '돼': 26518,
#  '지': 83321,
#  '서천': 53159,
#  '천꽃': 86370,
#  '꽃돼': 15012,
#  '돼지': 26524,
#  '서천꽃': 53160,
#  '천꽃돼': 86373,
#  '꽃돼지': 15013,
#  '서천꽃돼': 53161,
#  '천꽃돼지': 86374,
#  '술': 58107,
#  '요술': 70032,
#  '술나': 58125,
#  '요술나': 70033,
#  '술나라': 58126,
#  '요술나라': 70034,
#  '주': 82000,
#  '방': 43511,
#  '미리': 40823,
#  '리소': 33195,
#  '소주': 55561,
#  '주방': 82381,
#  '미리소': 40829,
#  '리소주': 33201,
#  '소주방': 55567,
#  '미리소주': 40830,
#  '리소주방': 33202,
#  '포': 95354,
#  '차': 85431,
#  '흥포': 103276,
#  '포차': 95748,
#  '고흥포': 9041,
#  '흥포차': 103277,
#  '고흥포차': 9042,
#  '광': 10239,
#  '양': 64648,
#  '계': 7781,
#  '란': 29794,
#  '광양': 10403,
#  '양계': 64679,
#  '계란': 7814,
#  '란집': 29845,
#  '광양계': 10408,
#  '양계란': 64680,
#  '계란집': 7817,
#  '광양계란': 10409,
#  '양계란집': 64681,
#  '대': 22310,
#  '명': 37730,
#  '순대': 57895,
#  '대명': 22673,
#  '명가': 37734,
#  '순대명': 57923,
#  '대명가': 22674,
#  '순대명가': 57924,
#  '공': 9803,
#  '이': 74163,
#  '오': 67775,
#  '공이': 9942,
#  '이일': 75204,
#  '일오': 76594,
#  '공이일': 9945,
#  '이일오': 75207,
#  '공이일오': 9946,
#  '향': 100645,
#  '기': 13227,
#  '매화': 36804,
#  '화향': 102773,
#  '향기': 100675,
#  '기나': 13334,
#  '매화향': 36812,
#  '화향기': 102774,
#  '향기나': 100677,
#  '매화향기': 36813,
#  '화향기나': 102775,
#  '다': 20355,
#  '다방': 20646,
#  '로': 31298,
#  '벤': 44761,
#  '토': 92859,
#  '코로': 89866,
#  '로벤': 31493,
#  '벤토': 44772,
#  '코코로': 89958,
#  '코로벤': 89869,
#  '로벤토': 31494,
#  '코코로벤': 89959,
#  '코로벤토': 89870,
#  '디': 28038,
#  '디스': 28089,
#  '끼': 15397,
#  '볶': 46117,
#  'l': 3720,
#  'f': 3452,
#  '아': 62176,
#  '울': 70876,
#  '렛': 31157,
#  '점': 80015,
#  '두끼': 26780,
#  '끼떡': 15431,
#  '떡볶': 28410,
#  '볶이': 46142,
#  '이광': 74306,
#  '양l': 64655,
#  'lf': 3737,
#  'f아': 3500,
#  '아울': 62762,
#  '울렛': 70929,
#  '렛점': 31158,
#  '두끼떡': 26785,
#  '끼떡볶': 15432,
#  '떡볶이': 28414,
#  '볶이광': 46160,
#  '이광양': 74309,
#  '광양l': 10406,
#  '양lf': 64656,
#  'lf아': 3740,
#  'f아울': 3501,
#  '아울렛': 62763,
#  '울렛점': 70930,
#  '두끼떡볶': 26786,
#  '끼떡볶이': 15433,
#  '떡볶이광': 28419,
#  '볶이광양': 46161,
#  '이광양l': 74310,
#  '광양lf': 10407,
#  '양lf아': 64657,
#  'lf아울': 3741,
#  'f아울렛': 3502,
#  '아울렛점': 62764,
#  '망': 36419,
#  '망고': 36422,
#  '름': 32371,
#  '없': 66125,
#  '는': 19332,
#  '이름': 74737,
#  '름없': 32414,
#  '없는': 66126,
#  '는술': 19506,
#  '술집': 58165,
#  '이름없': 74738,
#  '름없는': 32415,
#  '없는술': 66129,
#  '는술집': 19507,
#  '이름없는': 74739,
#  '름없는술': 32416,
#  '없는술집': 66130,
#  '달': 21211,
#  '콤': 90027,
#  '홍': 102031,
#  '시': 59693,
#  '달콤': 21440,
#  '콤홍': 90062,
#  '홍시': 102143,
#  '달콤홍': 21450,
#  '콤홍시': 90063,
#  '달콤홍시': 21451,
#  '여': 66608,
#  '만': 35431,
#  '여기': 66613,
#  '기서': 13568,
#  '서만': 52804,
#  '만나': 35467,
#  '나요': 16018,
#  '여기서': 66619,
#  '기서만': 13569,
#  '서만나': 52805,
#  '만나요': 35486,
#  '여기서만': 66620,
#  '기서만나': 13570,
#  '서만나요': 52806,
#  '사': 49735,
#  '절': 79920,
#  '카': 89138,
#  '페': 94638,
#  '사계': 49764,
#  '계절': 7924,
#  '절카': 79994,
#  '카페': 89294,
#  '사계절': 49767,
#  '계절카': 7969,
#  '절카페': 79995,
#  '사계절카': 49782,
#  '계절카페': 7970,
#  '으': 73104,
#  '야': 64143,
#  '집으': 84888,
#  '으로': 73126,
#  '로야': 31582,
#  '야식': 64355,
#  '집으로': 84889,
#  '으로야': 73132,
#  '로야식': 31583,
#  '집으로야': 84890,
#  '으로야식': 73133,
#  '페나': 94695,
#  '카페나': 89324,
#  '무': 39225,
#  '진': 84154,
#  '먹': 37084,
#  '무진': 39514,
#  '진장': 84345,
#  '장먹': 78413,
#  '먹방': 37170,
#  '무진장': 39519,
#  '진장먹': 84348,
#  '장먹방': 78414,
#  '무진장먹': 39521,
#  '진장먹방': 84349,
#  '마': 34147,
#  '이자': 75212,
#  '자카': 77813,
#  '카야': 89230,
#  '야마': 64262,
#  '마당': 34336,
#  '이자카': 75214,
#  '자카야': 77814,
#  '카야마': 89233,
#  '야마당': 64264,
#  '이자카야': 75215,
#  '자카야마': 77816,
#  '카야마당': 89234,
#  'b': 3108,
#  'y': 4311,
#  'by': 3191,
#  'y카': 4327,
#  'by카': 3192,
#  'y카페': 4328,
#  'by카페': 3193,
#  '김': 14016,
#  '밥': 43015,
#  '행': 100468,
#  '친': 88896,
#  '김밥': 14077,
#  '밥여': 43367,
#  '여행': 66707,
#  '행친': 100639,
#  '친구': 88908,
#  '김밥여': 14152,
#  '밥여행': 43368,
#  '여행친': 66709,
#  '행친구': 100640,
#  '김밥여행': 14153,
#  '밥여행친': 43369,
#  '여행친구': 66710,
#  '훈': 103079,
#  '네': 17826,
#  '훈이': 103088,
#  '이네': 74372,
#  '네만': 17984,
#  '만두': 35510,
#  '훈이네': 103089,
#  '이네만': 74402,
#  '네만두': 17985,
#  '훈이네만': 103090,
#  '이네만두': 74403,
#  '묵': 39598,
#  '묵자': 39635,
#  '투': 93607,
#  '국': 11400,
#  '투가': 93612,
#  '가리': 4796,
#  '리국': 32703,
#  '국밥': 11487,
#  '투가리': 93613,
#  '가리국': 4802,
#  '리국밥': 32704,
#  '투가리국': 93614,
#  '가리국밥': 4803,
#  '벌': 44505,
#  '교': 10601,
#  '반': 42648,
#  '벌교': 44506,
#  '교백': 10713,
#  '백반': 44132,
#  '벌교백': 44511,
#  '교백반': 10714,
#  '벌교백반': 44512,
#  '분': 47653,
#  '미식': 41165,
#  '식가': 60434,
#  '가분': 4990,
#  '분식': 47675,
#  '미식가': 41166,
#  '식가분': 60435,
#  '가분식': 4991,
#  '미식가분': 41167,
#  '식가분식': 60436,
#  '삼': 51454,
#  '겹': 7456,
#  '칼': 89476,
#  '무한': 39554,
#  '한삼': 98639,
#  '삼겹': 51474,
#  '겹칼': 7499,
#  '칼국': 89477,
#  '국수': 11538,
#  '무한삼': 39575,
#  '한삼겹': 98640,
#  '삼겹칼': 51498,
#  '겹칼국': 7500,
#  '칼국수': 89478,
#  '무한삼겹': 39576,
#  '한삼겹칼': 98642,
#  '삼겹칼국': 51499,
#  '겹칼국수': 7501,
#  '현': 101178,
#  '현대': 101199,
#  '대국': 22508,
#  '현대국': 101200,
#  '대국수': 22532,
#  '현대국수': 101201,
#  '슈': 58465,
#  '퍼': 94578,
#  '맨': 36877,
#  '슈퍼': 58489,
#  '퍼맨': 94584,
#  '맨떡': 36887,
#  '슈퍼맨': 58490,
#  '퍼맨떡': 94587,
#  '맨떡볶': 36888,
#  '슈퍼맨떡': 58492,
#  '퍼맨떡볶': 94588,
#  '맨떡볶이': 36889,
#  '돈': 25271,
#  '(': 1133,
#  '1': 2071,
#  '호': 101534,
#  ')': 1720,
#  '수제': 57623,
#  '제돈': 80732,
#  '돈가': 25277,
#  '가스': 5060,
#  '스나': 58640,
#  '라(': 28939,
#  '(광': 1301,
#  '양1': 64652,
#  '1호': 2233,
#  '호점': 101852,
#  '점)': 80033,
#  '수제돈': 57628,
#  '제돈가': 80733,
#  '돈가스': 25287,
#  '가스나': 5069,
#  '스나라': 58641,
#  '나라(': 15702,
#  '라(광': 28948,
#  '(광양': 1302,
#  '광양1': 10404,
#  '양1호': 64653,
#  '1호점': 2238,
#  '호점)': 101853,
#  '수제돈가': 57629,
#  '제돈가스': 80734,
#  '돈가스나': 25290,
#  '가스나라': 5070,
#  '스나라(': 58642,
#  '나라(광': 15703,
#  '라(광양': 28949,
#  '(광양1': 1303,
#  '광양1호': 10405,
#  '양1호점': 64654,
#  '1호점)': 2239,
#  '골': 9164,
#  '사골': 49792,
#  '골칼': 9543,
#  '수집': 57707,
#  '사골칼': 49806,
#  '골칼국': 9544,
#  '국수집': 11633,
#  '사골칼국': 49807,
#  '골칼국수': 9545,
#  '칼국수집': 89495,
#  '밤': 42983,
#  '엉': 66143,
#  '밤부': 43002,
#  '부엉': 47243,
#  '엉이': 66146,
#  '밤부엉': 43003,
#  '부엉이': 47244,
#  '밤부엉이': 43004,
#  '더': 23588,
#  '허': 101044,
#  '브': 48115,
#  '더허': 23991,
#  '허브': 101088,
#  '더허브': 23992,
#  '쿠': 90196,
#  '아쿠': 62946,
#  '쿠아': 90232,
#  '아카': 62932,
#  '아쿠아': 62947,
#  '쿠아카': 90234,
#  '아카페': 62940,
#  '아쿠아카': 62949,
#  '쿠아카페': 90235,
#  '문': 39653,
#  '난': 16306,
#  '황': 102816,
#  '곱': 9698,
#  '창': 85953,
#  '소문': 55316,
#  '문난': 39705,
#  '난황': 16524,
#  '황소': 102847,
#  '소곱': 55117,
#  '곱창': 9724,
#  '소문난': 55317,
#  '문난황': 39805,
#  '난황소': 16525,
#  '황소곱': 102850,
#  '소곱창': 55118,
#  '소문난황': 55363,
#  '문난황소': 39806,
#  '난황소곱': 16526,
#  '황소곱창': 102851,
#  '섬': 54002,
#  '강': 6219,
#  '섬진': 54051,
#  '진강': 84163,
#  '강숯': 6553,
#  '불구': 47797,
#  '구이': 11137,
#  '섬진강': 54052,
#  '진강숯': 84180,
#  '강숯불': 6554,
#  '숯불구': 58262,
#  '불구이': 47798,
#  '섬진강숯': 54059,
#  '진강숯불': 84181,
#  '강숯불구': 6555,
#  '숯불구이': 58263,
#  '신': 60718,
#  '맛': 35976,
#  '신원': 61175,
#  '원맛': 71467,
#  '맛식': 36197,
#  '신원맛': 61178,
#  '원맛식': 71468,
#  '맛식당': 36198,
#  '신원맛식': 61179,
#  '원맛식당': 71469,
#  '벼': 44794,
#  '벼리': 44800,
#  '리벼': 33063,
#  '벼리벼': 44801,
#  '리벼리': 33064,
#  '벼리벼리': 44802,
#  '남': 16624,
#  '남산': 16875,
#  '산곱': 50416,
#  '남산곱': 16881,
#  '산곱창': 50417,
#  '남산곱창': 16882,
#  '안': 63087,
#  '연안': 66869,
#  '안숯': 63351,
#  '불고': 47773,
#  '고기': 8153,
#  '연안숯': 66870,
#  '안숯불': 63352,
#  '숯불고': 58260,
#  '불고기': 47774,
#  '연안숯불': 66871,
#  '안숯불고': 63353,
#  '숯불고기': 58261,
#  '편': 94923,
#  '쉼': 58456,
#  '이편': 75563,
#  '편한': 94951,
#  '한쉼': 98738,
#  '쉼터': 58457,
#  '이편한': 75566,
#  '편한쉼': 94956,
#  '한쉼터': 98739,
#  '이편한쉼': 75568,
#  '편한쉼터': 94957,
#  '대한': 23465,
#  '한숯': 98735,
#  '대한숯': 23482,
#  '한숯불': 98736,
#  '대한숯불': 23483,
#  '한숯불구': 98737,
#  '우': 70139,
#  '촌': 87692,
#  '한우': 98906,
#  '우촌': 70571,
#  '촌식': 87850,
#  '한우촌': 99021,
#  '우촌식': 70574,
#  '촌식당': 87851,
#  '한우촌식': 99023,
#  '우촌식당': 70575,
#  '실': 61432,
#  '청매': 87028,
#  '매실': 36656,
#  '청매실': 87029,
#  '육': 72961,
#  '구네': 10840,
#  '네식': 18163,
#  '식육': 60619,
#  '육식': 72996,
#  '친구네': 88911,
#  '구네식': 10848,
#  '네식육': 18165,
#  '식육식': 60620,
#  '육식당': 72997,
#  '친구네식': 88915,
#  '구네식육': 10850,
#  '네식육식': 18166,
#  '식육식당': 60621,
#  '봉': 46562,
#  '족': 81667,
#  '봉구': 46587,
#  '구족': 11300,
#  '족발': 81682,
#  '봉구족': 46590,
#  '구족발': 11301,
#  '봉구족발': 46591,
#  '동': 25632,
#  '마동': 34401,
#  '동창': 26285,
#  '창고': 85987,
#  '마동창': 34402,
#  '동창고': 26286,
#  '마동창고': 34403,
#  '물': 40060,
#  '횟': 103030,
#  '물금': 40110,
#  '금횟': 13216,
#  '횟집': 103031,
#  '물금횟': 40111,
#  '금횟집': 13217,
#  '물금횟집': 40112,
#  '초': 87480,
#  '양초': 65018,
#  '초밥': 87550,
#  '광양초': 10430,
#  '양초밥': 65019,
#  '광양초밥': 10431,
#  '먹어': 37211,
#  '어섬': 65517,
#  '섬횟': 54069,
#  '먹어섬': 37222,
#  '어섬횟': 65520,
#  '섬횟집': 54070,
#  '먹어섬횟': 37223,
#  '어섬횟집': 65521,
#  '성': 54120,
#  '양중': 64999,
#  '중국': 82959,
#  '국성': 11532,
#  '광양중': 10426,
#  '양중국': 65000,
#  '중국성': 82962,
#  '광양중국': 10427,
#  '양중국성': 65001,
#  '꼬': 14745,
#  '통': 93245,
#  '꼬꼬': 14767,
#  '꼬네': 14811,
#  '네통': 18353,
#  '통닭': 93279,
#  '꼬꼬네': 14768,
#  '꼬네통': 14820,
#  '네통닭': 18354,
#  '꼬꼬네통': 14773,
#  '꼬네통닭': 14821,
#  '때': 28311,
#  '까': 14386,
#  '네발': 18026,
#  '발로': 42888,
#  '로갈': 31324,
#  '갈때': 5753,
#  '때까': 28322,
#  '까지': 14496,
#  '네발로': 18027,
#  '발로갈': 42889,
#  '로갈때': 31325,
#  '갈때까': 5754,
#  '때까지': 28323,
#  '네발로갈': 18028,
#  '발로갈때': 42890,
#  '로갈때까': 31326,
#  '갈때까지': 5755,
#  '꿀': 15210,
#  '꿀닭': 15232,
#  '닭강': 21539,
#  '강정': 6626,
#  '꿀닭강': 15233,
#  '닭강정': 21540,
#  '꿀닭강정': 15234,
#  '드': 27262,
#  '치': 88450,
#  '킨': 90945,
#  '골드': 9248,
#  '드치': 27573,
#  '치킨': 88731,
#  '골드치': 9253,
#  '드치킨': 27574,
#  '골드치킨': 9254,
#  '냠': 17631,
#  '냠냠': 17632,
#  '냠치': 17640,
#  '냠냠치': 17636,
#  '냠치킨': 17641,
#  '냠냠치킨': 17637,
#  '머': 36939,
#  '니': 19857,
#  '머니': 36959,
#  '니머': 19990,
#  '니치': 20162,
#  '머니머': 36983,
#  '니머니': 19991,
#  '머니치': 37022,
#  '니치킨': 20163,
#  '머니머니': 36984,
#  '니머니치': 19992,
#  '머니치킨': 37023,
#  '경': 7507,
#  '도': 24463,
#  '경도': 7540,
#  '도식': 24900,
#  '경도식': 7541,
#  '도식당': 24901,
#  '경도식당': 7542,
#  '바': 41869,
#  '큐': 90356,
#  '아리': 62494,
#  '리랑': 32883,
#  '랑바': 30108,
#  '바베': 42152,
#  '베큐': 44732,
#  '아리랑': 62509,
#  '리랑바': 32902,
#  '랑바베': 30109,
#  '바베큐': 42153,
#  '아리랑바': 62517,
#  '리랑바베': 32903,
#  '랑바베큐': 30110,
#  '음': 73750,
#  '동일': 26190,
#  '일음': 76629,
#  '음식': 73776,
#  '식점': 60661,
#  '동일음': 26191,
#  '일음식': 76630,
#  '음식점': 73780,
#  '동일음식': 26192,
#  '일음식점': 76631,
#  '회': 102894,
#  '대림': 22631,
#  '림회': 34091,
#  '회관': 102903,
#  '대림회': 22653,
#  '림회관': 34092,
#  '대림회관': 22654,
#  '영': 67177,
#  '부영': 47265,
#  '영치': 67536,
#  '부영치': 47281,
#  '영치킨': 67537,
#  '부영치킨': 47282,
#  '번': 44413,
#  '양일': 64968,
#  '일번': 76419,
#  '번지': 44462,
#  '광양일': 10422,
#  '양일번': 64969,
#  '일번지': 76424,
#  '광양일번': 10423,
#  '양일번지': 64971,
#  '전': 79430,
#  '빔': 49079,
#  '전주': 79759,
#  '주비': 82415,
#  '비빔': 48696,
#  '빔밥': 49084,
#  '밥식': 43343,
#  '전주비': 79816,
#  '주비빔': 82416,
#  '비빔밥': 48699,
#  '빔밥식': 49103,
#  '밥식당': 43344,
#  '전주비빔': 79817,
#  '주비빔밥': 82417,
#  '비빔밥식': 48707,
#  '빔밥식당': 49104,
#  '실식': 61496,
#  '매실식': 36659,
#  '실식당': 61497,
#  '매실식당': 36660,
#  '뽀': 49554,
#  '빠': 49309,
#  '뽀빠': 49573,
#  '빠이': 49381,
#  '이식': 75036,
#  '뽀빠이': 49574,
#  '빠이식': 49384,
#  '이식당': 75037,
#  '뽀빠이식': 49576,
#  '빠이식당': 49385,
#  '팔': 94472,
#  '팔구': 94477,
#  '구식': 11052,
#  '팔구식': 94478,
#  '구식당': 11053,
#  '팔구식당': 94479,
#  '태': 91946,
#  '태흥': 92296,
#  '흥해': 103282,
#  '해장': 100291,
#  '장국': 78215,
#  '태흥해': 92297,
#  '흥해장': 103285,
#  '해장국': 100292,
#  '태흥해장': 92298,
#  '흥해장국': 103286,
#  '킨아': 91058,
#  '아이': 62772,
#  '치킨아': 88802,
#  '킨아이': 91059,
#  '치킨아이': 88803,
#  '해운': 100257,
#  '운식': 70768,
#  '해운식': 100270,
#  '운식당': 70769,
#  '해운식당': 100271,
#  '부림': 47014,
#  '부림회': 47021,
#  '부림회관': 47022,
#  '오리': 68118,
#  '리고': 32671,
#  '고집': 8755,
#  '오리고': 68128,
#  '리고집': 32685,
#  '오리고집': 68129,
#  '백마': 44120,
#  '마회': 35303,
#  '백마회': 44121,
#  '마회관': 35304,
#  '백마회관': 44122,
#  '쇠': 56734,
#  '고로': 8459,
#  '로쇠': 31540,
#  '쇠산': 56769,
#  '산장': 51043,
#  '고로쇠': 8460,
#  '로쇠산': 31541,
#  '쇠산장': 56770,
#  '고로쇠산': 8461,
#  '로쇠산장': 31542,
#  '진식': 84308,
#  '섬진식': 54060,
#  '진식당': 84309,
#  '섬진식당': 54061,
#  '풍': 96463,
#  '년': 18489,
#  '풍년': 96525,
#  '년야': 18573,
#  '풍년야': 96547,
#  '년야식': 18574,
#  '풍년야식': 96548,
#  '강기': 6256,
#  '기사': 13539,
#  '사식': 50139,
#  '진강기': 84166,
#  '강기사': 6257,
#  '기사식': 13549,
#  '사식당': 50140,
#  '섬진강기': 54054,
#  ...}

# %%
# y 데이터 벡터화
y_vectorized = tfidf_vectorizer.transform(y)

# 벡터화된 희소행렬 확인 
# (22,782*126,789 행렬, 22,782개 음식메뉴가 총 126,789개 음절 벡터를 이용하여 벡터화되었음)
# (226,182개 element가 있으므로, 한 행당 평균 10개 정도의 element가 있음)
y_vectorized
# Out:
# <22849x103407 sparse matrix of type '<class 'numpy.float64'>'
# 	with 308511 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### 3. cosine 유사도 모델 생성 : 데이터 내부
# - "y데이터 내부"에서 서로 비슷한 음식메뉴는 무엇인지 찾는 모델 생성
# - [linear_kernel](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.pairwise.linear_kernel.html) 이용

# %%
from sklearn.metrics.pairwise import linear_kernel

# y_vectorized 데이터를 이용해 linear_kernel 행렬 생성
cosine_sim = linear_kernel(y_vectorized, y_vectorized)

# %%
cosine_sim.shape
# Out:
# (22782, 22782)

# %%
def get_similar_indices(idx, cosine_sim=cosine_sim):
    """
        idx를 "y데이터 내부"에서 서로 비슷한 가게명는 무엇인지 찾는 모델 생성
    """

    # 모든 가게명에 대해서 해당 idx와의 유사도를 구한다. ((index, linear_kernel값)의 list 형태)
    sim_scores = list(enumerate(cosine_sim[idx])) 

    # 유사도에 따라 가게명을 정렬한다. (key 파라미터는 정렬기준을 선택)
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # 유사도가 0 이상인 것만 sim_list에 저장한다.
    sim_list=[]
    for i in range(len(sim_scores)):
        if sim_scores[i][1] > 0:
            sim_list.append(sim_scores[i])
            
    # sim_list에서 유사도가 가장 높은 1개만 저장한다.
    sim_list = sim_list[:1]
            
    # sim_list의 인덱스를 저장한다.
    sim_indices = [i[0] for i in sim_list]

    # 5개의 가게명을 list 타입으로 반환한다.
    return sim_indices

# %% [markdown]
# 긴 음절의 가게명을 정확하게 예측하는지 살펴본다.

# %%
test_idxs = long_storenames.index
for idx in test_idxs:
    test_storename = y_storename[idx]
    sim_indices = get_similar_indices(idx)
    sim_storename = [y_storename[idx] for idx in sim_indices]
    print("'",test_storename,"'",'가장 유사한 가게명 1개:', sim_storename)
# Out:
# ' 고기듬뿍대왕비빔밥&커피몬스터(COFFEEMONSTER) ' 가장 유사한 가게명 1개: ['고기듬뿍대왕비빔밥&커피몬스터(COFFEEMONSTER)']
# ' 카페앤레스토랑브뤼(Cafe&RestaurantBRUT) ' 가장 유사한 가게명 1개: ['카페앤레스토랑브뤼(Cafe&RestaurantBRUT)']
# ' 미스터보쌈5379&STANDINGSTEAK동인천역점 ' 가장 유사한 가게명 1개: ['미스터보쌈5379&STANDINGSTEAK동인천역점']
# ' 낭만치킨포차동구과학대점엄니국물닭발&탕탕탕(본점) ' 가장 유사한 가게명 1개: ['낭만치킨포차동구과학대점엄니국물닭발&탕탕탕(본점)']
# ' 307버거앤그릴(307Burger&Grill) ' 가장 유사한 가게명 1개: ['307버거앤그릴(307Burger&Grill)']
# ' 위쉐프앤바리스타(We'chef&barista) ' 가장 유사한 가게명 1개: ["위쉐프앤바리스타(We'chef&barista)"]
# ' 한국외식프랜차이즈협동조합(참맛있게&델리커시) ' 가장 유사한 가게명 1개: ['한국외식프랜차이즈협동조합(참맛있게&델리커시)']
# ' 나는조선의떡볶이다&내가조선의닭발이다거제고현점 ' 가장 유사한 가게명 1개: ['나는조선의떡볶이다&내가조선의닭발이다거제고현점']
# ' 원스인어블루문(OnceInABluemoon) ' 가장 유사한 가게명 1개: ['원스인어블루문(OnceInABluemoon)']
# ' 큰가마솥할매순대국&양선지해장국증포점(고풍) ' 가장 유사한 가게명 1개: ['큰가마솥할매순대국&양선지해장국증포점(고풍)']
# ' 원할머니보쌈,족발&박가부대찌개(하남미사점) ' 가장 유사한 가게명 1개: ['원할머니보쌈,족발&박가부대찌개(하남미사점)']
# ' 텍사스데브라질(TexasdeBrazil) ' 가장 유사한 가게명 1개: ['텍사스데브라질(TexasdeBrazil)']
# ' 마켓로커스이마트수지점'My고기&제면명가' ' 가장 유사한 가게명 1개: ["마켓로커스이마트수지점'My고기&제면명가'"]
# ' 불타는장작구이&치맥먹고노가리풀자(고잔점) ' 가장 유사한 가게명 1개: ['불타는장작구이&치맥먹고노가리풀자(고잔점)']
# ' (주)채선당월남쌈&샤브샤브롯데백화점일산점 ' 가장 유사한 가게명 1개: ['(주)채선당월남쌈&샤브샤브롯데백화점일산점']
# ' 큐비라운지&바(QBLounge&Bar) ' 가장 유사한 가게명 1개: ['큐비라운지&바(QBLounge&Bar)']
# ' 놀부부대찌개&철판구이(판교더블유시티점) ' 가장 유사한 가게명 1개: ['놀부부대찌개&철판구이(판교더블유시티점)']
# ' 장충동왕족발보쌈&똥고집한우사골감자탕보쌈 ' 가장 유사한 가게명 1개: ['장충동왕족발보쌈&똥고집한우사골감자탕보쌈']
# ' 동해바다동태탕용인직영점&한도니왕돌판구이 ' 가장 유사한 가게명 1개: ['동해바다동태탕용인직영점&한도니왕돌판구이']
# ' (주)에스앤에스컴퍼니서가앤쿡AK&기흥점 ' 가장 유사한 가게명 1개: ['(주)에스앤에스컴퍼니서가앤쿡AK&기흥점']

# %% [markdown]
# 20음절이 넘는 가게명도 2~5그램의 음절 단위의 tfidf_vectorizer로 정확하게 예측했다.
#
# 1-2음절의 짧은 가게명도 예측하는지 살펴본다

# %%
test_idxs = storename_len[-200:].index
for idx in test_idxs:
    test_storename = y_storename[idx]
    sim_indices = get_similar_indices(idx)
    sim_storename = [y_storename[idx] for idx in sim_indices]
    print("'",test_storename,"'",'가장 유사한 가게명 1개:', sim_storename)
# Out:
# ' 몽촌 ' 가장 유사한 가게명 1개: ['몽촌']
# ' 양군 ' 가장 유사한 가게명 1개: ['양군']
# ' 다함 ' 가장 유사한 가게명 1개: ['다함']
# ' 대판 ' 가장 유사한 가게명 1개: ['대판']
# ' 미니 ' 가장 유사한 가게명 1개: ['미니']
# ' 민하 ' 가장 유사한 가게명 1개: ['민하']
# ' 마녀 ' 가장 유사한 가게명 1개: ['마녀']
# ' 윤정 ' 가장 유사한 가게명 1개: ['윤정']
# ' 이지 ' 가장 유사한 가게명 1개: ['이지']
# ' 방자 ' 가장 유사한 가게명 1개: ['방자']
# ' 덴버 ' 가장 유사한 가게명 1개: ['덴버']
# ' 범양 ' 가장 유사한 가게명 1개: ['범양']
# ' 보말 ' 가장 유사한 가게명 1개: ['보말']
# ' 누나 ' 가장 유사한 가게명 1개: ['누나']
# ' 식당 ' 가장 유사한 가게명 1개: ['식당']
# ' 보그 ' 가장 유사한 가게명 1개: ['보그']
# ' 명주 ' 가장 유사한 가게명 1개: ['명주']
# ' 보트 ' 가장 유사한 가게명 1개: ['보트']
# ' 썰매 ' 가장 유사한 가게명 1개: ['썰매']
# ' 부현 ' 가장 유사한 가게명 1개: ['부현']
# ' 보경 ' 가장 유사한 가게명 1개: ['보경']
# ' 혜성 ' 가장 유사한 가게명 1개: ['혜성']
# ' 로이 ' 가장 유사한 가게명 1개: ['로이']
# ' 보금 ' 가장 유사한 가게명 1개: ['보금']
# ' 다울 ' 가장 유사한 가게명 1개: ['다울']
# ' 별당 ' 가장 유사한 가게명 1개: ['별당']
# ' 비어 ' 가장 유사한 가게명 1개: ['비어']
# ' 냉정 ' 가장 유사한 가게명 1개: ['냉정']
# ' 시오 ' 가장 유사한 가게명 1개: ['시오']
# ' 어군 ' 가장 유사한 가게명 1개: ['어군']
# ' 목마 ' 가장 유사한 가게명 1개: ['목마']
# ' 복지 ' 가장 유사한 가게명 1개: ['복지']
# ' 낯선 ' 가장 유사한 가게명 1개: ['낯선']
# ' 복집 ' 가장 유사한 가게명 1개: ['복집']
# ' 믿고 ' 가장 유사한 가게명 1개: ['믿고']
# ' 본전 ' 가장 유사한 가게명 1개: ['본전']
# ' 담원 ' 가장 유사한 가게명 1개: ['담원']
# ' 민벅 ' 가장 유사한 가게명 1개: ['민벅']
# ' 버블 ' 가장 유사한 가게명 1개: ['버블']
# ' 메로 ' 가장 유사한 가게명 1개: ['메로']
# ' 메종 ' 가장 유사한 가게명 1개: ['메종']
# ' 석탑 ' 가장 유사한 가게명 1개: ['석탑']
# ' 세움 ' 가장 유사한 가게명 1개: ['세움']
# ' 더도 ' 가장 유사한 가게명 1개: ['더도']
# ' 메콩 ' 가장 유사한 가게명 1개: ['메콩']
# ' 로코 ' 가장 유사한 가게명 1개: ['로코']
# ' 선계 ' 가장 유사한 가게명 1개: ['선계']
# ' 들녘 ' 가장 유사한 가게명 1개: ['들녘']
# ' 공감 ' 가장 유사한 가게명 1개: ['공감']
# ' 한섬 ' 가장 유사한 가게명 1개: ['한섬']
# ' 밥밥 ' 가장 유사한 가게명 1개: ['밥밥']
# ' 삼정 ' 가장 유사한 가게명 1개: ['삼정']
# ' 딱! ' 가장 유사한 가게명 1개: ['딱!']
# ' 단골 ' 가장 유사한 가게명 1개: ['단골']
# ' 호령 ' 가장 유사한 가게명 1개: ['호령']
# ' 산적 ' 가장 유사한 가게명 1개: ['산적']
# ' 비추 ' 가장 유사한 가게명 1개: ['비추']
# ' 래빗 ' 가장 유사한 가게명 1개: ['래빗']
# ' 오죽 ' 가장 유사한 가게명 1개: ['오죽']
# ' 숨 ' 가장 유사한 가게명 1개: ['숨']
# ' 깜 ' 가장 유사한 가게명 1개: ['깜']
# ' 길 ' 가장 유사한 가게명 1개: ['길']
# ' 숙 ' 가장 유사한 가게명 1개: ['숙']
# ' 뉴 ' 가장 유사한 가게명 1개: ['뉴']
# ' 류 ' 가장 유사한 가게명 1개: ['류']
# ' 섬 ' 가장 유사한 가게명 1개: ['섬']
# ' 성 ' 가장 유사한 가게명 1개: ['성']
# ' 립 ' 가장 유사한 가게명 1개: ['립']
# ' 딱 ' 가장 유사한 가게명 1개: ['딱']
# ' 티 ' 가장 유사한 가게명 1개: ['티']
# ' 독 ' 가장 유사한 가게명 1개: ['독']
# ' 딘 ' 가장 유사한 가게명 1개: ['딘']
# ' 맥 ' 가장 유사한 가게명 1개: ['맥']
# ' 규 ' 가장 유사한 가게명 1개: ['규']
# ' 죽 ' 가장 유사한 가게명 1개: ['죽']
# ' 헬 ' 가장 유사한 가게명 1개: ['헬']
# ' 범 ' 가장 유사한 가게명 1개: ['범']
# ' 경 ' 가장 유사한 가게명 1개: ['경']
# ' 준 ' 가장 유사한 가게명 1개: ['준']
# ' 업 ' 가장 유사한 가게명 1개: ['업']
# ' 랑 ' 가장 유사한 가게명 1개: ['랑']
# ' 위 ' 가장 유사한 가게명 1개: ['위']
# ' 쉬 ' 가장 유사한 가게명 1개: ['쉬']
# ' 쉼 ' 가장 유사한 가게명 1개: ['쉼']
# ' 벨 ' 가장 유사한 가게명 1개: ['벨']
# ' 퀵 ' 가장 유사한 가게명 1개: ['퀵']
# ' 딥 ' 가장 유사한 가게명 1개: ['딥']
# ' 향 ' 가장 유사한 가게명 1개: ['향']
# ' 오 ' 가장 유사한 가게명 1개: ['오']
# ' 곰 ' 가장 유사한 가게명 1개: ['곰']
# ' 형 ' 가장 유사한 가게명 1개: ['형']
# ' 취 ' 가장 유사한 가게명 1개: ['취']
# ' 혼 ' 가장 유사한 가게명 1개: ['혼']
# ' 소 ' 가장 유사한 가게명 1개: ['소']
# ' 솔 ' 가장 유사한 가게명 1개: ['솔']
# ' 탄 ' 가장 유사한 가게명 1개: ['탄']
# ' 송 ' 가장 유사한 가게명 1개: ['송']
# ' 늘 ' 가장 유사한 가게명 1개: ['늘']
# ' 잼 ' 가장 유사한 가게명 1개: ['잼']
# ' 애 ' 가장 유사한 가게명 1개: ['애']
# ' 림 ' 가장 유사한 가게명 1개: ['림']
# ' 쿤 ' 가장 유사한 가게명 1개: ['쿤']
# ' 틈 ' 가장 유사한 가게명 1개: ['틈']
# ' 쿨 ' 가장 유사한 가게명 1개: ['쿨']
# ' 학 ' 가장 유사한 가게명 1개: ['학']
# ' 장 ' 가장 유사한 가게명 1개: ['장']
# ' 비 ' 가장 유사한 가게명 1개: ['비']
# ' 수 ' 가장 유사한 가게명 1개: ['수']
# ' 주 ' 가장 유사한 가게명 1개: ['주']
# ' 옆 ' 가장 유사한 가게명 1개: ['옆']
# ' 문 ' 가장 유사한 가게명 1개: ['문']
# ' 맛 ' 가장 유사한 가게명 1개: ['맛']
# ' 칸 ' 가장 유사한 가게명 1개: ['칸']
# ' 미 ' 가장 유사한 가게명 1개: ['미']
# ' 구 ' 가장 유사한 가게명 1개: ['구']
# ' 다 ' 가장 유사한 가게명 1개: ['다']
# ' 댄 ' 가장 유사한 가게명 1개: ['댄']
# ' 율 ' 가장 유사한 가게명 1개: ['율']
# ' 달 ' 가장 유사한 가게명 1개: ['달']
# ' 단 ' 가장 유사한 가게명 1개: ['단']
# ' 집 ' 가장 유사한 가게명 1개: ['집']
# ' 뜰 ' 가장 유사한 가게명 1개: ['뜰']
# ' 컵 ' 가장 유사한 가게명 1개: ['컵']
# ' 루 ' 가장 유사한 가게명 1개: ['루']
# ' 별 ' 가장 유사한 가게명 1개: ['별']
# ' 선 ' 가장 유사한 가게명 1개: ['선']
# ' 밀 ' 가장 유사한 가게명 1개: ['밀']
# ' 왕 ' 가장 유사한 가게명 1개: ['왕']
# ' 슈 ' 가장 유사한 가게명 1개: ['슈']
# ' 앤 ' 가장 유사한 가게명 1개: ['앤']
# ' 맘 ' 가장 유사한 가게명 1개: ['맘']
# ' 터 ' 가장 유사한 가게명 1개: ['터']
# ' 덮 ' 가장 유사한 가게명 1개: ['덮']
# ' 무 ' 가장 유사한 가게명 1개: ['무']
# ' 물 ' 가장 유사한 가게명 1개: ['물']
# ' 썰 ' 가장 유사한 가게명 1개: ['썰']
# ' 찬 ' 가장 유사한 가게명 1개: ['찬']
# ' 돈 ' 가장 유사한 가게명 1개: ['돈']
# ' 엠 ' 가장 유사한 가게명 1개: ['엠']
# ' 판 ' 가장 유사한 가게명 1개: ['판']
# ' 인 ' 가장 유사한 가게명 1개: ['인']
# ' 화 ' 가장 유사한 가게명 1개: ['화']
# ' 뜸 ' 가장 유사한 가게명 1개: ['뜸']
# ' 담 ' 가장 유사한 가게명 1개: ['담']
# ' 감 ' 가장 유사한 가게명 1개: ['감']
# ' 웰 ' 가장 유사한 가게명 1개: ['웰']
# ' 몽 ' 가장 유사한 가게명 1개: ['몽']
# ' 렉 ' 가장 유사한 가게명 1개: ['렉']
# ' 강 ' 가장 유사한 가게명 1개: ['강']
# ' 려 ' 가장 유사한 가게명 1개: ['려']
# ' 벗 ' 가장 유사한 가게명 1개: ['벗']
# ' 센 ' 가장 유사한 가게명 1개: ['센']
# ' 원 ' 가장 유사한 가게명 1개: ['원']
# ' 궁 ' 가장 유사한 가게명 1개: ['궁']
# ' 덤 ' 가장 유사한 가게명 1개: ['덤']
# ' 지 ' 가장 유사한 가게명 1개: ['지']
# ' 유 ' 가장 유사한 가게명 1개: ['유']
# ' 붐 ' 가장 유사한 가게명 1개: ['붐']
# ' 엔 ' 가장 유사한 가게명 1개: ['엔']
# ' 웅 ' 가장 유사한 가게명 1개: ['웅']
# ' 열 ' 가장 유사한 가게명 1개: ['열']
# ' 엘 ' 가장 유사한 가게명 1개: ['엘']
# ' 줌 ' 가장 유사한 가게명 1개: ['줌']
# ' 밥 ' 가장 유사한 가게명 1개: ['밥']
# ' 산 ' 가장 유사한 가게명 1개: ['산']
# ' 8 ' 가장 유사한 가게명 1개: ['8']
# ' 켄 ' 가장 유사한 가게명 1개: ['켄']
# ' 한 ' 가장 유사한 가게명 1개: ['한']
# ' 닻 ' 가장 유사한 가게명 1개: ['닻']
# ' 쌩 ' 가장 유사한 가게명 1개: ['쌩']
# ' 봄 ' 가장 유사한 가게명 1개: ['봄']
# ' 리 ' 가장 유사한 가게명 1개: ['리']
# ' 톳 ' 가장 유사한 가게명 1개: ['톳']
# ' 샵 ' 가장 유사한 가게명 1개: ['샵']
# ' 환 ' 가장 유사한 가게명 1개: ['환']
# ' 난 ' 가장 유사한 가게명 1개: ['난']
# ' 겹 ' 가장 유사한 가게명 1개: ['겹']
# ' 큐 ' 가장 유사한 가게명 1개: ['큐']
# ' 명 ' 가장 유사한 가게명 1개: ['명']
# ' 본 ' 가장 유사한 가게명 1개: ['본']
# ' 곱 ' 가장 유사한 가게명 1개: ['곱']
# ' 나 ' 가장 유사한 가게명 1개: ['나']
# ' 결 ' 가장 유사한 가게명 1개: ['결']
# ' 국 ' 가장 유사한 가게명 1개: ['국']
# ' 띠 ' 가장 유사한 가게명 1개: ['띠']
# ' 련 ' 가장 유사한 가게명 1개: ['련']
# ' 탑 ' 가장 유사한 가게명 1개: ['탑']
# ' 쿡 ' 가장 유사한 가게명 1개: ['쿡']
# ' 쌈 ' 가장 유사한 가게명 1개: ['쌈']
# ' 탈 ' 가장 유사한 가게명 1개: ['탈']
# ' 빈 ' 가장 유사한 가게명 1개: ['빈']
# ' 락 ' 가장 유사한 가게명 1개: ['락']
# ' 술 ' 가장 유사한 가게명 1개: ['술']
# ' 턴 ' 가장 유사한 가게명 1개: ['턴']
# ' 참 ' 가장 유사한 가게명 1개: ['참']
# ' 쏠 ' 가장 유사한 가게명 1개: ['쏠']
# ' 와 ' 가장 유사한 가게명 1개: ['와']
# ' 뷰 ' 가장 유사한 가게명 1개: ['뷰']
# ' 안 ' 가장 유사한 가게명 1개: ['안']
# ' 운 ' 가장 유사한 가게명 1개: ['운']

# %% [markdown]
# 전체 가게명에 대해 정확도를 알아본다.

# %%
accurate = 0
for idx in storename_len.index:
    test_storename = y_storename[idx]
    sim_idx = get_similar_indices(idx)[0]
    sim_storename = y_storename[sim_idx]
    if test_storename == sim_storename:
        accurate += 1
accuracy = (accurate / len(storename_len)) * 100
print('전체 가게명 정확도:',str(accuracy), '%')
# Out:
# 전체 가게명 정확도: 99.99561056974805 %

# %%
accurate
# Out:
# 22781

# %% [markdown]
# ### 4. cosine 유사도 모델 생성 : 데이터 외부
# - df_storenames 데이터와 살짝 다른 가게명이 입력되었을 때, df_storenames 내에서 가장 비슷한 가게명은 무엇인지 찾는 모델 생성
# - [cosine_similarity](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.pairwise.cosine_similarity.html) 이용
#
# #### 가게명과 조사를 섞어서 테스트

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
def get_similar_storename(new_storename, tfidf_vectorizer, y_vectorized):
    """
        데이터에 없는 새로운 지역명 new_storename을 입력 받고, 
        new_storename과 가장 유사한 지역명 3개와 각각의 유사도를 데이터프레임 형태로 반환
    """
    
    # new_storename 형태소 분석
    new_storename_mecab = [text_prepare(new_storename)]
    
    # new_storename 벡터화
    new_storename_vectorized = tfidf_vectorizer.transform(new_storename_mecab)
    
    # 유사한 메뉴와 유사도를 저장
    sim_storename = {}

    for i in range(y_vectorized.shape[0]):
        curr_sim = cosine_similarity(y_vectorized[i], new_storename_vectorized)[0,0]
        if curr_sim > 0.2:
            sim_storename[y_storename[i]] = curr_sim

    sim_storename = pd.DataFrame(data=sim_storename.values()
                           ,index=sim_storename.keys()
                           ,columns=['cs']).sort_values('cs',ascending=False)

    return sim_storename[:3]

# %%
def get_similar_storename(new_storename, tfidf_vectorizer, y_vectorized):
    """
        데이터에 없는 새로운 지역명 new_storename을 입력 받고, 
        new_storename과 가장 유사한 지역명 3개와 각각의 유사도를 데이터프레임 형태로 반환
    """
    
    # new_storename 형태소 분석
    new_storename_mecab = [text_prepare(new_storename)]
    
    # new_storename 벡터화
    new_storename_vectorized = tfidf_vectorizer.transform(new_storename_mecab)
    
    # 유사한 메뉴와 유사도를 저장
    sim_storename = {}

    for i in range(y_vectorized.shape[0]):
        curr_sim = cosine_similarity(y_vectorized[i], new_storename_vectorized)[0,0]
        if curr_sim > 0.2:
            sim_storename[y_storename[i]] = curr_sim

    sim_storename = pd.DataFrame(data=sim_storename.values()
                           ,index=sim_storename.keys()
                           ,columns=['cs']).sort_values('cs',ascending=False)

    return sim_storename[:3]

# %%
new_storename = '서가앤 쿡'
# new_storename 형태소 분석
new_storename_mecab = [text_prepare(new_storename)]

# new_storename 벡터화
new_storename_vectorized = tfidf_vectorizer.transform(new_storename_mecab)

# %%
def cs(a):
    return cosine_similarity(a, new_storename_vectorized)[0,0]

# %%
y_vectorized.toarray().shape
# Out:
# (22782, 103122)

# %%
y_vectorized.toarray()[0]
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
# %%time
np.apply_along_axis(cs,0,y_vectorized.toarray())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <timed eval> in <module>
#
# <__array_function__ internals> in apply_along_axis(*args, **kwargs)
#
# /anaconda3/envs/text_anal/lib/python3.6/site-packages/numpy/lib/shape_base.py in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     377     except StopIteration:
#     378         raise ValueError('Cannot apply_along_axis when any iteration dimensions are 0')
# --> 379     res = asanyarray(func1d(inarr_view[ind0], *args, **kwargs))
#     380
#     381     # build a buffer for storing evaluations of func1d.
#
# <ipython-input-40-9c2345328b9d> in cs(a)
#       1 def cs(a):
# ----> 2     return cosine_similarity(a, new_storename_vectorized)[0,0]
#
# /anaconda3/envs/text_anal/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in cosine_similarity(X, Y, dense_output)
#    1025     # to avoid recursive import
#    1026
# -> 1027     X, Y = check_pairwise_arrays(X, Y)
#    1028
#    1029     X_normalized = normalize(X, copy=True)
#
# /anaconda3/envs/text_anal/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in check_pairwise_arrays(X, Y, precomputed, dtype)
#     110     else:
#     111         X = check_array(X, accept_sparse='csr', dtype=dtype,
# --> 112                         estimator=estimator)
#     113         Y = check_array(Y, accept_sparse='csr', dtype=dtype,
#     114                         estimator=estimator)
#
# /anaconda3/envs/text_anal/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     519                     "Reshape your data either using array.reshape(-1, 1) if "
#     520                     "your data has a single feature or array.reshape(1, -1) "
# --> 521                     "if it contains a single sample.".format(array))
#     522
#     523         # in the future np.flexible dtypes will be handled like object dtypes
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[0. 0. 0. ... 0. 0. 0.].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
# %%time
cosine_similarity(y_vectorized[1], new_storename_vectorized)[0,0]
# Out:
# CPU times: user 3.56 ms, sys: 8.88 ms, total: 12.4 ms
# Wall time: 12.6 ms
# 0.0

# %%
8.88*22800/1000/60
# Out:
# 3.3744000000000005

# %%
test_storenames = [
    '버거앤그릴', '놀부 부대찌개에', '서가앤 쿡으로', '맛있는 장충동왕족발보쌈'
]

print('가장 유사한 가게명 3가지')
for storename in test_storenames:
    print(storename,'\t:',get_similar_storename(storename,tfidf_vectorizer,y_vectorized).index.tolist())
    print('\tscore:',get_similar_storename(storename,tfidf_vectorizer,y_vectorized)['cs'].tolist())
# Out:
# 가장 유사한 가게명 3가지
# 버거앤그릴 	: ['그릴앤그릴', '포앤그릴', '그릴']
# 	score: [0.4422617134191459, 0.4289169571135475, 0.39445232576278483]
# 놀부 부대찌개에 	: ['놀부부대찌개', '부부부대찌개', '놀부보쌈놀부부대찌개']
# 	score: [0.9789485692646828, 0.7021773142495924, 0.6788828856255898]
# 서가앤 쿡으로 	: ['서가앤쿡목동점', '서가앤쿡부평점', '(주)에스앤에스컴퍼니서가앤쿡AK&기흥점']
# 	score: [0.5900494407645965, 0.5889505105376054, 0.31105292805161433]
# 맛있는 장충동왕족발보쌈 	: ['소문난장충동왕족발보쌈', '장충동왕족발보쌈(동탄점)', '본가장충동왕족발']
# 	score: [0.7152080335559895, 0.6305253434936038, 0.6054035913640307]

# %% [markdown]
# **pickle 저장**

# %%
tfidf_vectorizer
# Out:
# TfidfVectorizer(analyzer='char', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=1.0, max_features=None,
#                 min_df=1, ngram_range=(1, 4), norm='l2', preprocessor=None,
#                 smooth_idf=True, stop_words=None, strip_accents=None,
#                 sublinear_tf=False, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, use_idf=True, vocabulary=None)

# %%
import pickle

with open('./cosine_storename_tfidf_vectorizer.pickle', "wb") as f:
    pickle.dump(tfidf_vectorizer, f, pickle.HIGHEST_PROTOCOL)
with open('./cosine_storename_y.pickle', "wb") as f:
    pickle.dump(y_storename, f, pickle.HIGHEST_PROTOCOL)
with open('./cosine_storename_y_vectorized.pickle', "wb") as f:
    pickle.dump(y_vectorized, f, pickle.HIGHEST_PROTOCOL)
#with open('./cosine_storename_cosine_sim.pickle', "wb") as f:
#    pickle.dump(cosine_sim, f, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# **클래스 정리**
